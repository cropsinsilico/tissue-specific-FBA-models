# %% [markdown]
# # Does any transcript levels correlate with FBA-predicted metabolic fluxes?
#
# ## Introduction
#
# Transcriptomics dataset collected from multiple scenarios and published in [Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008) was provided from UoI-UC. FBA was used to predict metabolic fluxes under different scenarios and then transcript levels are compared to flux.

# %% [markdown]
# ## Processing transcript data

# %%
import pandas as pd
df = pd.read_csv("/home/sanu/Downloads/gmax_leaf_CO2_normExprn_1.txt",sep="\t")
# Out:
# /home/sanu/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (0,2,3,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df.columns) -17
# Out:
# 229

# %% [markdown]
# ### Seperating out different studies
#
# Data on light intensity (PPFD) during plant growth was avialable for 5 (of 8) studies. When \[CO2\] is not avilable, ambient levels were assumed. Where day-length is not mentioned, as assumption that daylength is 12h was assumed. In the case of studies involving biotic and abiotic treatments (other than high \[CO2\] treatments), only the WT/control data was used in this analysis.

# %%
amb_list = list(df.columns[0:17])
ele_list = list(df.columns[0:17])
for x in df.columns:
    if "Amb" in x:
        amb_list.append(x)
    elif "Ele" in x:
        ele_list.append(x)
    else:
        continue

budRemove_list = list(df.columns[0:17])+["GSM569808.CEL","GSM569809.CEL","GSM569810.CEL",
                                         "GSM569811.CEL","GSM569812.CEL","GSM569813.CEL",
                                         "GSM569814.CEL"]
heatShock_list = list(df.columns[0:17])+["GSM643115.CEL","GSM643116.CEL","GSM643117.CEL","GSM643118.CEL"]
mycInfect_list = list(df.columns[0:17])+["GSM1088939_Schaar_19_wt_c1_S.CEL",
                                         "GSM1088940_Schaar_20_wt_c2_S.CEL",
                                         "GSM1088954_Schaar_25_nts_c1_S.CEL",
                                         "GSM1088955_Schaar_26_nts_c2_S.CEL",
                                         "GSM1088956_Schaar_27_nts_c3_S.CEL"]

# %%
df_amb = df[amb_list]
df_ele = df[ele_list]
df_budRemove = df[budRemove_list]
df_heatShock = df[heatShock_list]
df_mycInfect = df[mycInfect_list]

# %% [markdown]
# ## Set up leaf model and add gene-protein-reaction (GPR) associations from PlantCyc

# %%
from cobra import io
from cobra.core import Metabolite
from cobra import flux_analysis
from IPython import display
import logging
logging.basicConfig()
logger = logging.getLogger('logger')

#import sbml file
fname = "/home/sanu/Documents/Scripts/git/plantcoremetabolism-model/PlantCoreMetabolism_v1_3_0.xml"
model = io.sbml.read_sbml_model(fname)
display.clear_output()

from sweetlovegroup.transform import fixModelCompatibilityIssueCobra015
model = fixModelCompatibilityIssueCobra015(model,fname)

# %%
len(model.reactions)
# Out:
# 892

# %%
len(model.metabolites)
# Out:
# 861

# %%
import pythoncyc
from Functions import *

soy = pythoncyc.select_organism("soy")

# %%
model = addGPR2Models(model,soy)
# Out:
# --------------
# This list of metabolic reactions are ignored
# ['RXN_9650_p', '2_KETO_ADIPATE_DEHYDROG_RXN_m', 'Phytol_biosynthesis_p', 'CYSTEINE_AMINOTRANSFERASE_RXN_m', 'GLYCINE_TRNA_LIGASE_RXN_c', 'RXN66_1_c', 'RXN_9648_p', 'RXN-9651', 'Plastidial_ATP_Synthase_p', 'GGPP_biosynthesis_p', 'RXN_9653_p', 'lycopene_biosynthesis_p', 'RXN_2141_p', 'SUCCINYL_COA_HYDROLASE_RXN_m', 'PROTON_ATPase_c', 'MDA_Fd_Ascorbate_p', 'MercaptoPyruvateSulfurtransferase_m', 'Phytol_degradation_p', 'RXN_9652_p', 'A_B_oxidation_x', 'unlProtHYPO_c', 'Mitochondrial_ATP_Synthase_m', 'IPP_biosynthesis_c', 'Mehler_Reaction_p', 'Beta_Oxidation_x', 'HMBPP_synthesis_p', 'OROTATE_REDUCTASE_NADH_RXN_p', 'Ferredoxin_Plastoquinone_Reductase_p', 'RXN_9651_p', 'NADPH_Dehydrogenase_p', 'Plastoquinol_Oxidase_p', 'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m', 'RXN_1781_v', 'PREPHENATE_DEHYDROGENASE_NADP_RXN_p', 'PREPHENATEDEHYDROG_RXN_p', 'MALEYLACETOACETATE_ISOMERASE_RXN_c', 'RXN_9654_p', 'LCYSDESULF_RXN_c', 'RXN_9958_NAD_m', 'HEXOKINASE_RXN_MANNOSE_c', 'PYRUVDEH_RXN_p', 'PYRUVDEH_RXN_m']
# --------------
# RXN_1826_p
# RXN_12486_c
# arachidate_biosynthesis_p
# docosanoate_biosynthesis_p
# gadoleic_acid_biosynthesis_p
# Arachidoyl_ACP_desaturase_p
# LPG_biosynthesis_c
# RXN_6884_m
# PHE_NH4_Lyase_c
# RXN_8871_c
# RXN490_3650_p
# Octadecadienoyl_ACP_desaturase_p
# RXN_8873_c
# ACETOVANILLONE_HYDROXYLASE_c
# 6PGLUCONDEHYDROG_RXN_c
# Octadecadienoyl_ACP_hydrolase_p
# Octadecatrienoyl_ACP_hydrolase_p
# palmitoyl_ACP_desaturase_p
# RXN1G_368_p
# palmitoleoyl_ACP_desaturase_p
# 6PGLUCONDEHYDROG_RXN_p
# hexadecadienoate_biosynthesis_p
# hexadecadienoate_ACP_desaturase_p
# RXN1G_445_p
# hexadecatrienoate_biosynthesis_p
# RXN_8872_c
# SYRINGICACID_BIOSYNTHESIS_c
# ACETOVANILLONE_SYNTHASE_c
# Oleoyl_ACP_desaturase_p
# VANILLICACID_BIOSYNTHESIS_c
# ACETOSYRINGONE_BIOSYNTHESIS_c
# hexadecenoate_biosynthesis_p
# SYRINGALDEHYDE_BIOSYNTHESIS_c

# %% [markdown]
# ## Modelling fluxes under different scenarios
#
# Create leaf model

# %%
########################################################
#This function was used to set up a C3 leaf diel model #
########################################################
def setupC3DielModel(core_model,transferMets,starch_sucrose_ratio=90.0/100):
    from cobra.core import Metabolite, Reaction
    import re

    #create two copies of model elements for day and night
    cobra_model2 = core_model.copy()
    for met in cobra_model2.metabolites:
        met.id = met.id+"1"
        met.compartment = met.compartment+"1"
    for rxn in cobra_model2.reactions:
        rxn.id = rxn.id+"1"

    cobra_model3 = core_model.copy()
    for met in cobra_model3.metabolites:
        met.id = met.id+"2"
        met.compartment = met.compartment+"2"
    for rxn in cobra_model3.reactions:
        rxn.id = rxn.id+"2"

    #merge the day and night model
    cobra_model = cobra_model2+cobra_model3
    for met in cobra_model3.metabolites:
        if not cobra_model.metabolites.__contains__(met.id):
            cobra_model.add_metabolites(met.copy())

    met1 = Metabolite("X_Phloem_contribution_t1",name="Phloem output during the day")
    cobra_model.reactions.get_by_id("Phloem_output_tx1").add_metabolites({met1:1})
    met2 = Metabolite("X_Phloem_contribution_t2",name="Phloem output during at night")
    cobra_model.reactions.get_by_id("Phloem_output_tx2").add_metabolites({met2:1})

    rxn = Reaction("diel_biomass")
    rxn.add_metabolites({met1:-3,met2:-1})
    rxn.lower_bound = 0
    rxn.upper_bound = 1000
    cobra_model.add_reaction(rxn)

    #Adding reactions to allow for day-night metabolite accumulations
    tmfile = open(transferMets,"r")
    tmset=set()
    for line in tmfile:
        tmset.add(line.replace("\n",""))

    for met in tmset:
        if met == "AMMONIUM_v" or met=="FRUCTAN_v":
            continue
        tempRxn = Reaction(met+"_dielTransfer")
        tempRxn.add_metabolites({cobra_model.metabolites.get_by_id(met+"1"):-1,cobra_model.metabolites.get_by_id(met+"2"):1})
        tempRxn.lower_bound=-1000
        if not ((met == "STARCH_p") or (met == "SUCROSE_v") or (met == "MAL_v") or (met == "aMAL_v") or (met == "NITRATE_v") or (met == "CIT_v") or (met == "aCIT_v") or (met == "PROTON_v")):
            tempRxn.lower_bound=0
        tempRxn.upper_bound=1000
        cobra_model.add_reaction(tempRxn)

    fractionMets=dict()
    for rxn in cobra_model.reactions:
        for met in rxn.metabolites.keys():
            prefix=""
            a=re.search("^a{1,3}",met.id)
            anion=""
            if a:
                anion=a.group(0)
                prefix=anion
            b=re.search("^b{1,3}",met.id)
            basic=""
            if b:
                basic=b.group(0)
                prefix=basic
            if ((not prefix == "") and met.compartment == "v1"):
                fractionMets[met]=prefix

    temp=cobra_model.copy()
    for met in fractionMets.keys():
        for rxn in met.reactions:
            if rxn.id.__contains__("_dielTransfer"):
                continue
            else:
                mainMet = met.id[len(fractionMets[met]):]
                coeff1 = temp.reactions.get_by_id(rxn.id).metabolites.get(temp.metabolites.get_by_id(mainMet))
                coeff2 = temp.reactions.get_by_id(rxn.id).metabolites.get(temp.metabolites.get_by_id(met.id))
                if not coeff1:
                    coeff1=0
                if not coeff2:
                    coeff2=0
                total = coeff1 + coeff2
                coeff1 = float(coeff1)/total
                coeff2 = float(coeff2)/total
                if cobra_model.reactions.has_id(met.id[0:len(met.id)-1]+"_dielTransfer"):
                    ub = temp.reactions.get_by_id(met.id[0:len(met.id)-1]+"_dielTransfer").upper_bound
                    lb = temp.reactions.get_by_id(met.id[0:len(met.id)-1]+"_dielTransfer").lower_bound
                    temp.reactions.get_by_id(met.id[0:len(met.id)-1]+"_dielTransfer").remove_from_model()
                    temp.reactions.get_by_id(mainMet[0:len(mainMet)-1]+"_dielTransfer").remove_from_model()
                    Reac = Reaction(mainMet[0:len(mainMet)-1]+"_dielTransfer",name=mainMet+"_dielTransfer")
                    Reac.add_metabolites({temp.metabolites.get_by_id(met.id[0:len(met.id)-1]+"1"):-coeff2,temp.metabolites.get_by_id(met.id[0:len(met.id)-1]+"2"):coeff2,temp.metabolites.get_by_id(mainMet[0:len(mainMet)-1]+"1"):-coeff1,temp.metabolites.get_by_id(mainMet[0:len(mainMet)-1]+"2"):coeff1})
                    Reac.lower_bound=lb
                    Reac.upper_bound=ub
                    temp.add_reaction(Reac)
                    print Reac.reaction
                break
    ####ADD CONSTRAINTS TO MODEL####
    cobra_model = temp.copy()

    #objective function
    cobra_model.reactions.get_by_id("diel_biomass").objective_coefficient=1
    #Leaves - light
    cobra_model.reactions.get_by_id("Sucrose_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("Sucrose_tx1").upper_bound=0
    cobra_model.reactions.get_by_id("GLC_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("GLC_tx1").upper_bound=0
    cobra_model.reactions.get_by_id("CO2_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("NH4_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("NH4_tx1").upper_bound=0
    #Leaves - dark
    cobra_model.reactions.get_by_id("Sucrose_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("Sucrose_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("GLC_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("GLC_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("Photon_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("Photon_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("NH4_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("NH4_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("CO2_tx2").upper_bound=0

    #Set pG6P transporter to 0
    cobra_model.reactions.get_by_id("G6P_Pi_pc1").lower_bound=0
    cobra_model.reactions.get_by_id("G6P_Pi_pc1").upper_bound=0
    cobra_model.reactions.get_by_id("G6P_Pi_pc2").lower_bound=0
    cobra_model.reactions.get_by_id("G6P_Pi_pc2").upper_bound=0

    #Turn off PTOX
    cobra_model.reactions.get_by_id("Plastoquinol_Oxidase_p1").lower_bound=0
    cobra_model.reactions.get_by_id("Plastoquinol_Oxidase_p1").upper_bound=0

    #nitrate uptake constrain
    Nitrate_balance = Metabolite("Nitrate_bal_c", name = "Weights to balance nitrate uptake", compartment = "c1")
    cobra_model.reactions.get_by_id("Nitrate_ec1").add_metabolites({Nitrate_balance:-2})
    cobra_model.reactions.get_by_id("Nitrate_ec2").add_metabolites({Nitrate_balance:3})

    #Rubisco balance
    Rubisco_balance = Metabolite("rubisco_bal_p1", name = "Weights to balance RuBP carboxygenase oxygenase balance", compartment = "p1")
    cobra_model.reactions.get_by_id("RXN_961_p1").add_metabolites({Rubisco_balance:3})
    cobra_model.reactions.get_by_id("RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p1").add_metabolites({Rubisco_balance:-1})

    #generic ATPase and NADPH oxidase
    Maintenance_constraint = Metabolite("ATPase_NADPHoxidase_constraint_c1",name =  "ATPase_NADPHoxidase_constraint_c1", compartment = "c1")
    Maintenance_constraint2 = Metabolite("ATPase_NADPHoxidase_constraint_c2",name =  "ATPase_NADPHoxidase_constraint_c2", compartment = "c2")
    Maintenance_constraint3 = Metabolite("Light_dark_maintainence_constraint",name =  "Light_dark_maintainence_constraint", compartment = "c1")
    cobra_model.reactions.get_by_id("ATPase_tx1").add_metabolites({Maintenance_constraint:1,Maintenance_constraint3:1})
    cobra_model.reactions.get_by_id("ATPase_tx2").add_metabolites({Maintenance_constraint2:1,Maintenance_constraint3:-1})
    cobra_model.reactions.get_by_id("NADPHoxc_tx1").add_metabolites({Maintenance_constraint:-3})
    cobra_model.reactions.get_by_id("NADPHoxc_tx2").add_metabolites({Maintenance_constraint2:-3})
    cobra_model.reactions.get_by_id("NADPHoxm_tx1").add_metabolites({Maintenance_constraint:-3})
    cobra_model.reactions.get_by_id("NADPHoxm_tx2").add_metabolites({Maintenance_constraint2:-3})
    cobra_model.reactions.get_by_id("NADPHoxp_tx1").add_metabolites({Maintenance_constraint:-3})
    cobra_model.reactions.get_by_id("NADPHoxp_tx2").add_metabolites({Maintenance_constraint2:-3})

    ##constrain sucrose and starch storage
    Sucorse_starch_balance = Metabolite("sucrose_starch_bal_c", name = "Weights to balance sucrose-starch uptake", compartment = "c1")
    cobra_model.reactions.get_by_id("SUCROSE_v_dielTransfer").add_metabolites({Sucorse_starch_balance:-1*starch_sucrose_ratio})
    cobra_model.reactions.get_by_id("STARCH_p_dielTransfer").add_metabolites({Sucorse_starch_balance:1})

    #Plastid enolase was not detected in Arabidopsis mesophyll tissue
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p1").lower_bound=0
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p1").upper_bound=0
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p2").lower_bound=0
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p2").upper_bound=0

    #Setting chloroplastic NADPH dehydrogenase to 0  ((Yamamoto et al., 2011)
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p1").lower_bound=0
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p1").upper_bound=0
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p2").lower_bound=0
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p2").upper_bound=0

    #ATP_ADP_Pi constrained to 0 because while there is evidence for its existance, it does not carry flux during the day
    cobra_model.reactions.get_by_id("ATP_ADP_Pi_pc1").lower_bound = 0
    cobra_model.reactions.get_by_id("ATP_ADP_Pi_pc1").upper_bound = 0

    return cobra_model

# %%
leaf_model = model.copy()

from sweetlovegroup import transform
leaf_model = setupC3DielModel(leaf_model,"MetabolitesToTransfer.txt",starch_sucrose_ratio=5)

for rxn in leaf_model.reactions:
    if rxn.lower_bound==-1000:
        rxn.lower_bound=-2000
    if rxn.upper_bound==1000:
        rxn.upper_bound=2000
        
leaf_model.reactions.diel_biomass.objective_coefficient=1
sol = flux_analysis.parsimonious.pfba(leaf_model)
# Out:
# 0.7 MAL_v1 + 0.3 aMAL_v1 <=> 0.7 MAL_v2 + 0.3 aMAL_v2
# 0.5 CIT_v1 + 0.5 aCIT_v1 <=> 0.5 CIT_v2 + 0.5 aCIT_v2
# bHIS_v1 --> bHIS_v2

# %% [markdown]
# ### Scenario 1
#
# PPFD = 1500 ([Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008))
# \[CO2\] = 380  ([Leakey et al 2009](https://doi.org/10.1073/pnas.0810955106))
# net CO2 uptake rate = 29.85 ([Leakey et al 2009](https://doi.org/10.1073/pnas.0810955106))
# daylength = 14h ([Leakey et al 2009](https://doi.org/10.1073/pnas.0810955106))
#
#
# |sampling time|day length|
# |-|-|
# |11/07/2005|14h50m|
# |01/08/2005|14h17m|
# |02/08/2005|14h15m|
# |23/08/2005|13h28m|
# |24/08/2005|13h25m|
# |07/09/2005|12h50m|
# |18/07/2006|14h42m|
# |02/08/2006|14h16m|
# |25/08/2006|13h24m|

# %%
PPFD = 1500
daylength = 14
ATPase = (0.0049*PPFD) + 2.7851
scale = float(60*60*daylength)/1000000

from sweetlovegroup import analysis
temp = leaf_model.copy()
from Functions import adjustObjectiveBasedOnDaylength
temp = adjustObjectiveBasedOnDaylength(temp,daylength)
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
temp.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
temp.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
temp.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
out_400 = analysis.estimateOutputFromNetCO2(temp,29.85*scale)

leaf_model_400 = leaf_model.copy()
leaf_model_400 = adjustObjectiveBasedOnDaylength(leaf_model_400,daylength)
leaf_model_400.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_400.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
leaf_model_400.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
leaf_model_400.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
leaf_model_400.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
leaf_model_400.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
leaf_model_400.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale

leaf_model_400.reactions.diel_biomass.lower_bound = out_400
leaf_model_400.reactions.diel_biomass.upper_bound = out_400
sol = flux_analysis.parsimonious.pfba(leaf_model_400)
print("Phloem output = ")
print(leaf_model_400.reactions.diel_biomass.flux)
# Out:
# 75.6
# 0.0504
# 1.50444
# Phloem output =
# 0.0281640962762

# %%
import numpy as np


totalTranscript_400 = dict()
for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(df_amb.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(df_amb["Glyma2.0"]):
            #print gene
            if count==0:
                x = df_amb[df_amb["Glyma2.0"]==gene.id][df_amb.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = df_amb[df_amb["Glyma2.0"]==gene.id][df_amb.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_400[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 2
#
# PPFD = 1500 ([Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008))
# \[CO2\] = 550 ([Leakey et al 2009](https://doi.org/10.1073/pnas.0810955106))
# net CO2 uptake rate = 36.36 ([Leakey et al 2009](https://doi.org/10.1073/pnas.0810955106))
# daylength = 14h ([Leakey et al 2009](https://doi.org/10.1073/pnas.0810955106))

# %%
PPFD = 1500
daylength = 14
ATPase = (0.0049*PPFD) + 2.7851
scale = float(60*60*daylength)/1000000

from sweetlovegroup import analysis
temp = leaf_model.copy()
from Functions import adjustObjectiveBasedOnDaylength
temp = adjustObjectiveBasedOnDaylength(temp,daylength)
temp.reactions.get_by_id("RXN_961_p1").add_metabolites({temp.metabolites.get_by_id("rubisco_bal_p1"):1.35})

temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
temp.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
temp.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
temp.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
out_550 = analysis.estimateOutputFromNetCO2(temp,36.36*scale)

leaf_model_550 = leaf_model.copy()
leaf_model_550 = adjustObjectiveBasedOnDaylength(leaf_model_550,daylength)
leaf_model_550.reactions.get_by_id("RXN_961_p1").add_metabolites({leaf_model_550.metabolites.get_by_id("rubisco_bal_p1"):1.35})
leaf_model_550.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_550.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
leaf_model_550.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
leaf_model_550.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
leaf_model_550.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
leaf_model_550.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
leaf_model_550.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
leaf_model_550.reactions.diel_biomass.lower_bound = out_550
leaf_model_550.reactions.diel_biomass.upper_bound = out_550
sol = flux_analysis.parsimonious.pfba(leaf_model_550)
print("Phloem output = ")
print(leaf_model_550.reactions.diel_biomass.flux)
# Out:
# 75.6
# 0.0504
# 1.832544
# Phloem output =
# 0.0339353990711

# %%
totalTranscript_550 = dict()
temp = df_ele

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_550[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 3
#
# PPFD = 400 ([Turner et al 2012](https://doi.org/10.1007/s00425-011-1551-4))
# \[CO2\] = 370  (ambient [CO2] assumed)
# net CO2 uptake rate = 23.86 (Predicted according to [Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008))
# daylength = 16h ([Turner et al 2012](https://doi.org/10.1007/s00425-011-1551-4))

# %%
PPFD = 400
daylength = 16
ATPase = (0.0049*PPFD) + 2.7851
scale = float(60*60*daylength)/1000000

from sweetlovegroup import analysis
temp = leaf_model.copy()
from Functions import adjustObjectiveBasedOnDaylength
temp = adjustObjectiveBasedOnDaylength(temp,daylength)
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
temp.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
temp.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
temp.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
out_400 = analysis.estimateOutputFromNetCO2(temp,23.86*scale)

leaf_model_budRemove = leaf_model.copy()
leaf_model_budRemove = adjustObjectiveBasedOnDaylength(leaf_model_budRemove,daylength)
leaf_model_budRemove.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_budRemove.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
leaf_model_budRemove.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
leaf_model_budRemove.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
leaf_model_budRemove.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
leaf_model_budRemove.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
leaf_model_budRemove.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
leaf_model_budRemove.reactions.diel_biomass.lower_bound = out_400
leaf_model_budRemove.reactions.diel_biomass.upper_bound = out_400
sol = flux_analysis.parsimonious.pfba(leaf_model_budRemove)
print("Phloem output = ")
print(leaf_model_budRemove.reactions.diel_biomass.flux)
# Out:
# 23.04
# 0.0576
# 1.374336
# Phloem output =
# 0.0190870137859

# %%
totalTranscript_budRemove = dict()
temp = df_budRemove

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_budRemove[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 4
#
# PPFD = 350 ([Weston et al 2011](https://doi.org/10.1111/j.1365-3040.2011.02347.x))
# \[CO2\] = 380 ([Weston et al 2011](https://doi.org/10.1111/j.1365-3040.2011.02347.x))
# net CO2 uptake rate = 13.98 (Average of 14.55 and 13.40 \[CO2\]=370) ([Haile nd Higley 2003](https://doi.org/10.1603/0046-225x-32.3.433))
# daylength = 10h ([Weston et al 2011](https://doi.org/10.1111/j.1365-3040.2011.02347.x))

# %%
PPFD = 350
daylength = 10
ATPase = (0.0049*PPFD) + 2.7851
scale = float(60*60*daylength)/1000000

from sweetlovegroup import analysis
temp = leaf_model.copy()
from Functions import adjustObjectiveBasedOnDaylength
temp = adjustObjectiveBasedOnDaylength(temp,daylength)
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
temp.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
temp.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
temp.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
out_370 = analysis.estimateOutputFromNetCO2(temp,13.98*scale)

leaf_model_heatShock = leaf_model.copy()
leaf_model_heatShock = adjustObjectiveBasedOnDaylength(leaf_model_heatShock,daylength)
leaf_model_heatShock.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_heatShock.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
leaf_model_heatShock.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
leaf_model_heatShock.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
leaf_model_heatShock.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
leaf_model_heatShock.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
leaf_model_heatShock.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
leaf_model_heatShock.reactions.diel_biomass.lower_bound = out_370
leaf_model_heatShock.reactions.diel_biomass.upper_bound = out_370
sol = flux_analysis.parsimonious.pfba(leaf_model_heatShock)
print("Phloem output = ")
print(leaf_model_heatShock.reactions.diel_biomass.flux)
# Out:
# 12.6
# 0.036
# 0.50328
# Phloem output =
# 0.0153346274356

# %%
totalTranscript_heatShock = dict()
temp = df_heatShock

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_heatShock[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 5
#
# PPFD = 200
# \[CO2\] = ? , assuming 390 based on publication date and CO2 data from the year (https://www.co2.earth/monthly-co2)
# net CO2 uptake rate = 13.73 (Predicted according to [Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008) which models [CO2]=370)
# daylength = 16h

# %%
PPFD = 200
daylength = 16
ATPase = (0.0049*PPFD) + 2.7851
scale = float(60*60*daylength)/1000000

from sweetlovegroup import analysis
temp = leaf_model.copy()
from Functions import adjustObjectiveBasedOnDaylength
temp = adjustObjectiveBasedOnDaylength(temp,daylength)
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
temp.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
temp.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
temp.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
out_370 = analysis.estimateOutputFromNetCO2(temp,13.73*scale)

leaf_model_mycInfect = leaf_model.copy()
leaf_model_mycInfect = adjustObjectiveBasedOnDaylength(leaf_model_mycInfect,daylength)
leaf_model_mycInfect.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_mycInfect.reactions.get_by_id("Photon_tx1").upper_bound = PPFD*scale
leaf_model_mycInfect.reactions.get_by_id("ATPase_tx1").lower_bound = 1*scale
leaf_model_mycInfect.reactions.get_by_id("ATPase_tx1").upper_bound = 1*scale
leaf_model_mycInfect.reactions.get_by_id("PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1").upper_bound = 0.034*scale
leaf_model_mycInfect.reactions.get_by_id("OAA_MAL_pc1").upper_bound = 0.75*scale
leaf_model_mycInfect.reactions.get_by_id("OAA_MAL_pc1").lower_bound = -0.75*scale
leaf_model_mycInfect.reactions.diel_biomass.lower_bound = out_370
leaf_model_mycInfect.reactions.diel_biomass.upper_bound = out_370
sol = flux_analysis.parsimonious.pfba(leaf_model_mycInfect)
print("Phloem output = ")
print(leaf_model_mycInfect.reactions.diel_biomass.flux)
# Out:
# 11.52
# 0.0576
# 0.790848
# Phloem output =
# 0.0108700826235

# %%
0.75*scale
# Out:
# 0.0432

# %%
leaf_model_mycInfect.reactions.get_by_id("OAA_MAL_pc1").flux/scale
# Out:
# -0.7500000000000001

# %%
totalTranscript_mycInfect = dict()
temp = df_mycInfect

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_mycInfect[rxn.id]=x[0]

# %%
modelDict = dict()
modelDict[1] = leaf_model_400
modelDict[2] = leaf_model_550
modelDict[3] = leaf_model_budRemove
modelDict[4] = leaf_model_heatShock
modelDict[5] = leaf_model_mycInfect

totalTranscriptDict = dict()
totalTranscriptDict[1] = totalTranscript_400
totalTranscriptDict[2] = totalTranscript_550
totalTranscriptDict[3] = totalTranscript_budRemove
totalTranscriptDict[4] = totalTranscript_heatShock
totalTranscriptDict[5] = totalTranscript_mycInfect

# %%
def generateFluxDictIgnoringCompartmentalization(model):
    fluxes = dict()
    for r in model.reactions:
        fluxes[r.id] = r.flux
    fluxes_new = dict()
    processedRxn = set()
    for rxn in fluxes:
        RXN = str(rxn[:rxn.rindex("_")]+rxn[len(rxn)-1]).replace("_NADP","").replace("_NAD","")
        if RXN in  processedRxn:
            continue
        else:
            processedRxn.add(RXN)
        tot = 0
        for rxn2 in fluxes:
            if RXN == str(rxn2[:rxn2.rindex("_")]+rxn2[len(rxn2)-1]).replace("_NADP","").replace("_NAD",""):
                if "RXN_9958" in RXN:
                    print rxn2
                    print abs(fluxes[rxn2])
                    print RXN
                tot = tot+abs(fluxes[rxn2])
        fluxes_new[RXN]=tot
    return fluxes_new
                



modelDictNonCompartmentalized = dict()
for i in range(1,6):
    modelDictNonCompartmentalized[i] = generateFluxDictIgnoringCompartmentalization(modelDict[i])
# Out:
# RXN_9958_NAD_m1
# 0.0
# RXN_99581
# RXN_9958_NAD_m2
# 0.0
# RXN_99582
# RXN_9958_NAD_m1
# 0.0
# RXN_99581
# RXN_9958_NAD_m2
# 0.0
# RXN_99582
# RXN_9958_NAD_m1
# 0.0
# RXN_99581
# RXN_9958_NAD_m2
# 0.0
# RXN_99582
# RXN_9958_NAD_m1
# 0.0
# RXN_99581
# RXN_9958_NAD_m2
# 0.0
# RXN_99582
# RXN_9958_NAD_m1
# 0.0
# RXN_99581
# RXN_9958_NAD_m2
# 0.0
# RXN_99582

# %%
modelDictNonCompartmentalized[1]['RXN_99582']
# Out:
# 0.0

# %%
PCCdict=dict()

# %%
from scipy.stats import pearsonr

processedRxn = set()
for rxn in totalTranscriptDict[1].keys():
    R = str(rxn[:rxn.rindex("_")]+rxn[len(rxn)-1]).replace("_NADP","").replace("_NAD","")
    if R in processedRxn:
        continue
    else:
        processedRxn.add(R)
    xlist = list()
    ylist = list()
    for i in range(1,6):
        #print rxn
        for j in range(0,len(totalTranscriptDict[i][rxn])):
            xlist.append(modelDictNonCompartmentalized[i][R])
            ylist.append(totalTranscriptDict[i][rxn][j])
    ans = pearsonr(xlist,ylist)  
    PCCdict[rxn]=ans

# %%
PCCdict
# Out:
# {'METHYLCROTONYL_COA_CARBOXYLASE_RXN_m2': (nan, 1.0),
#  'METHYLCROTONYL_COA_CARBOXYLASE_RXN_m1': (nan, 1.0),
#  'H_mc1': (nan, 1.0),
#  'H_mc2': (nan, 1.0),
#  'Protein_Processing_c1': (nan, 1.0),
#  'Protein_Processing_c2': (nan, 1.0),
#  'Mg_biomass2': (nan, 1.0),
#  'Mg_biomass1': (nan, 1.0),
#  'AMP_pc1': (nan, 1.0),
#  'RXN_9958_NAD_m2': (nan, 1.0),
#  'RXN_6884_m1': (nan, 1.0),
#  'RXN_6884_m2': (nan, 1.0),
#  'pTYR_biomass2': (nan, 1.0),
#  'pTYR_biomass1': (nan, 1.0),
#  'MDA_Fd_Ascorbate_p2': (nan, 1.0),
#  'MDA_Fd_Ascorbate_p1': (nan, 1.0),
#  '2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p2': (nan, 1.0),
#  '2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p1': (nan, 1.0),
#  'RXN_6902_m1': (nan, 1.0),
#  'RXN_6902_m2': (nan, 1.0),
#  'pTHR_biomass2': (nan, 1.0),
#  'pTHR_biomass1': (nan, 1.0),
#  'ASPARAGHYD_RXN_c1': (nan, 1.0),
#  'ASPARAGHYD_RXN_c2': (nan, 1.0),
#  '2KG_SUC_mc1': (nan, 1.0),
#  'HIS_ORNITHINE_mc2': (nan, 1.0),
#  'HIS_ORNITHINE_mc1': (nan, 1.0),
#  'RXN_11832_m1': (nan, 1.0),
#  'RXN_11832_m2': (nan, 1.0),
#  'GLUTDECARBOX_RXN_c1': (-0.5191227391399041, 0.0023309916567849334),
#  'GLYOHMETRANS_RXN_c1': (-0.660817486492378, 3.845116918835141e-05),
#  'RXN66_1_c2': (nan, 1.0),
#  'GLYOHMETRANS_RXN_c2': (-0.8888984348004929, 1.0871841744300075e-11),
#  'GLUTAMINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'GLUTAMINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'LYS_pc2': (nan, 1.0),
#  'LYS_pc1': (nan, 1.0),
#  'FORMATETHFLIG_RXN_p1': (nan, 1.0),
#  'FORMATETHFLIG_RXN_p2': (nan, 1.0),
#  'Photon_tx1': (nan, 1.0),
#  'FUMARYLACETOACETASE_RXN_c2': (nan, 1.0),
#  'FUMARYLACETOACETASE_RXN_c1': (nan, 1.0),
#  'Photon_tx2': (nan, 1.0),
#  'Starch_biomass1': (nan, 1.0),
#  'ACSERLY_RXN_c2': (nan, 1.0),
#  'ACSERLY_RXN_c1': (-0.45409758477113293, 0.00903639935426532),
#  'Starch_biomass2': (nan, 1.0),
#  'TRP_PROTON_vc1': (nan, 1.0),
#  'RXN_9958_NAD_m1': (nan, 1.0),
#  'TRP_PROTON_vc2': (nan, 1.0),
#  '2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c1': (nan, 1.0),
#  '2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c2': (nan, 1.0),
#  'O2_tx1': (nan, 1.0),
#  'O2_tx2': (nan, 1.0),
#  'AMP_pc2': (nan, 1.0),
#  'PRPPAMIDOTRANS_RXN_p1': (-0.7886874094378756, 8.257405040207659e-08),
#  'PRPPAMIDOTRANS_RXN_p2': (0.1924574245777729, 0.2912909091772444),
#  'DUMP_pc2': (nan, 1.0),
#  'THREDEHYD_RXN_p2': (0.3611337174894579, 0.042284055647694836),
#  'THREDEHYD_RXN_p1': (nan, 1.0),
#  '3_ISOPROPYLMALDEHYDROG_RXN_p1': (-0.8852634169910315, 1.718399720870457e-11),
#  '3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m2': (0.5867017547065178,
#   0.0004166359359108814),
#  '3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m1': (nan, 1.0),
#  'INORGPYROPHOSPHAT_RXN_p1': (0.5236765889987743, 0.0020984959219726264),
#  'INORGPYROPHOSPHAT_RXN_p2': (-0.4330540781688674, 0.013295674258123145),
#  'RXN_9633_p1': (nan, 1.0),
#  'pARG_biomass1': (nan, 1.0),
#  'pARG_biomass2': (nan, 1.0),
#  'RXN_9633_p2': (nan, 1.0),
#  'FERULIC_ACID_pc1': (nan, 1.0),
#  'LYS_PROTON_vc2': (nan, 1.0),
#  'LYS_PROTON_vc1': (nan, 1.0),
#  'LEU_PROTON_rev_vc1': (nan, 1.0),
#  'PRIBFAICARPISOM_RXN_p2': (-0.9439404241484003, 5.535570591004293e-16),
#  'PRIBFAICARPISOM_RXN_p1': (-0.8560819143617919, 4.1986677345018864e-10),
#  'sALA_biomass2': (nan, 1.0),
#  'sALA_biomass1': (nan, 1.0),
#  'ACETOVANILLONE_SYNTHASE_c1': (nan, 1.0),
#  'RXN_1841_v1': (nan, 1.0),
#  'VAL_PROTON_rev_vc1': (nan, 1.0),
#  'GLY_pc1': (nan, 1.0),
#  'GLY_pc2': (nan, 1.0),
#  'CITSYN_RXN_x2': (-0.1919002437155611, 0.2927167509036614),
#  'RXN_15130_p2': (nan, 1.0),
#  'RXN_15130_p1': (nan, 1.0),
#  'RXN_6383_x2': (nan, 1.0),
#  'RXN_6383_x1': (nan, 1.0),
#  'RIBULP3EPIM_RXN_p1': (-0.41381791657510203, 0.01855179049499982),
#  'RIBULP3EPIM_RXN_p2': (0.4836194223427465, 0.005043805265360276),
#  'ARG_pc2': (nan, 1.0),
#  'ARG_pc1': (nan, 1.0),
#  'ASPAMINOTRANS_RXN_c1': (0.5451911373880751, 0.0012518460709565525),
#  'ACONITATEHYDR_RXN_c1': (-0.5547765676628739, 0.0009833406887284574),
#  'ACONITATEHYDR_RXN_c2': (-0.45221365491233345, 0.009363304845456706),
#  'ASPAMINOTRANS_RXN_c2': (-0.857080283676286, 3.808912594770202e-10),
#  'THREO_DS_ISO_CITRATE_xc2': (nan, 1.0),
#  'THREO_DS_ISO_CITRATE_xc1': (nan, 1.0),
#  'NADPHoxm_tx1': (nan, 1.0),
#  'PEPCARBOXYKIN_RXN_c1': (nan, 1.0),
#  'PEPCARBOXYKIN_RXN_c2': (nan, 1.0),
#  '6PGLUCONDEHYDROG_RXN_c2': (nan, 1.0),
#  '6PGLUCONDEHYDROG_RXN_c1': (nan, 1.0),
#  'PYRUVDEH_RXN_p2': (nan, 1.0),
#  'PYRUVDEH_RXN_p1': (nan, 1.0),
#  '2KG_ACONITATE_mc1': (nan, 1.0),
#  'MANNPGUANYLTRANGDP_RXN_c2': (nan, 1.0),
#  'MANNPGUANYLTRANGDP_RXN_c1': (nan, 1.0),
#  '2KG_ACONITATE_mc2': (nan, 1.0),
#  'GAP_Pi_pc1': (nan, 1.0),
#  'GAP_Pi_pc2': (nan, 1.0),
#  'sTHR_biomass1': (nan, 1.0),
#  'sTHR_biomass2': (nan, 1.0),
#  'GCVMULTI_RXN_m1': (-0.46679119094686067, 0.0070758160068118735),
#  'GCVMULTI_RXN_m2': (-0.8729538927229212, 7.276974599152532e-11),
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2': (-0.6751905835114486,
#   2.2425682450596566e-05),
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc1': (0.20270975027102286,
#   0.26584683305156676),
#  'CYSPH_RXN_p1': (-0.31971437354413973, 0.07446069729301044),
#  'CYSPH_RXN_p2': (nan, 1.0),
#  'ADPREDUCT_RXN_p2': (nan, 1.0),
#  'ADPREDUCT_RXN_p1': (nan, 1.0),
#  'L_ASCORBATE_PEROXIDASE_RXN_m1': (-0.08472107848145302, 0.644785978493703),
#  'L_ASCORBATE_PEROXIDASE_RXN_m2': (nan, 1.0),
#  'TYR_PROTON_rev_vc2': (nan, 1.0),
#  'TYR_PROTON_rev_vc1': (nan, 1.0),
#  'pGLU_biomass2': (nan, 1.0),
#  'pGLU_biomass1': (nan, 1.0),
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p1': (nan, 1.0),
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p2': (nan, 1.0),
#  'NADH_DEHYDROG_A_RXN_mi2': (-0.7291667447491005, 2.2067282934446483e-06),
#  'NADH_DEHYDROG_A_RXN_mi1': (0.10260998591034175, 0.5762746428711668),
#  '10_FORMYL_THF_pc1': (nan, 1.0),
#  'GGPP_biosynthesis_p1': (nan, 1.0),
#  'GGPP_biosynthesis_p2': (nan, 1.0),
#  '10_FORMYL_THF_pc2': (nan, 1.0),
#  'ADP_pc2': (nan, 1.0),
#  'ADP_pc1': (nan, 1.0),
#  'pVAL_biomass2': (nan, 1.0),
#  'pVAL_biomass1': (nan, 1.0),
#  'Mitochondrial_ATP_Synthase_m1': (nan, 1.0),
#  'Mitochondrial_ATP_Synthase_m2': (nan, 1.0),
#  'LPG_biosynthesis_c2': (nan, 1.0),
#  'LPG_biosynthesis_c1': (nan, 1.0),
#  'GART_RXN_p1': (-0.3659236579339913, 0.03943004512043868),
#  'GART_RXN_p2': (-0.5010439966054255, 0.0034886853834862454),
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p2': (0.3630576074565372,
#   0.041118446118825425),
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p1': (0.3923733345508538, 0.02633595000816246),
#  'AIRCARBOXY_RXN_p2': (-0.0514504786615958, 0.7797434176114054),
#  'AIRCARBOXY_RXN_p1': (0.32179689994194804, 0.07248665328653353),
#  'THF_mc1': (nan, 1.0),
#  'GLUTACONYL_COA_DECARBOXYLASE_RXN_x1': (nan, 1.0),
#  'GLUTACONYL_COA_DECARBOXYLASE_RXN_x2': (nan, 1.0),
#  'THF_mc2': (nan, 1.0),
#  'ADENOSYLHOMOCYSTEINASE_RXN_c1': (nan, 1.0),
#  'ADENOSYLHOMOCYSTEINASE_RXN_c2': (0.07214732517470816, 0.6947617566871495),
#  'FORMATE_pc1': (nan, 1.0),
#  'FORMATE_pc2': (nan, 1.0),
#  'RXN0_5224_c2': (nan, 1.0),
#  'GLUCURONOKINASE_RXN_c1': (nan, 1.0),
#  'GLUCURONOKINASE_RXN_c2': (nan, 1.0),
#  'DUDPKIN_RXN_p1': (nan, 1.0),
#  'DUDPKIN_RXN_p2': (nan, 1.0),
#  'THR_PROTON_rev_vc2': (nan, 1.0),
#  'THR_PROTON_rev_vc1': (nan, 1.0),
#  'PEPDEPHOS_RXN_p1': (nan, 1.0),
#  'PEPDEPHOS_RXN_p2': (-0.7621327483694249, 4.0179515241136187e-07),
#  'ORNCARBAMTRANSFER_RXN_p1': (-0.793895595987502, 5.896814674064362e-08),
#  'L_ALPHA_ALANINE_PROTON_vc1': (nan, 1.0),
#  'SUC_ISOCITRATE_mc2': (nan, 1.0),
#  'SUC_ISOCITRATE_mc1': (nan, 1.0),
#  'GAPOXNPHOSPHN_RXN_c1': (-0.5817543254735748, 0.00047871099273216863),
#  'RXN0_5330_NAD_mi1': (nan, 1.0),
#  'ISOCITDEH_RXN_x1': (0.37770177610417816, 0.03306806678645236),
#  'ISOCITDEH_RXN_x2': (-0.5035050497587761, 0.003306554514868215),
#  'NH4_ec1': (nan, 1.0),
#  '2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m1': (nan, 1.0),
#  '2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m2': (nan, 1.0),
#  'HOMOCYSMETB12_RXN_c1': (nan, 1.0),
#  '2_KETO_ADIPATE_DEHYDROG_RXN_m1': (nan, 1.0),
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2': (nan, 1.0),
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1': (nan, 1.0),
#  'GLUCOKIN_RXN_p1': (nan, 1.0),
#  'LEUCINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'LEUCINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'GLUCOKIN_RXN_p2': (nan, 1.0),
#  'RXN_3523_p2': (nan, 1.0),
#  'RXN_3523_p1': (nan, 1.0),
#  'RXN_9549_p1': (0.03858165042071638, 0.8339445131333396),
#  'RXN_9549_p2': (nan, 1.0),
#  'GLYCINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'CHORISMATEMUT_RXN_p1': (0.02670022796120972, 0.8846668971678491),
#  'GLUTAMIDOTRANS_RXN_p1': (-0.784624065666748, 1.0669395116707849e-07),
#  'GLUTAMIDOTRANS_RXN_p2': (-0.9292230961496135, 1.654356574205907e-14),
#  '2TRANSKETO_RXN_p1': (nan, 1.0),
#  'RXN_9659_p1': (-0.028007694807174827, 0.8790595043173559),
#  'RXN_9659_p2': (-0.2797032676502659, 0.12104066029338631),
#  'HIS_PROTON_vc2': (nan, 1.0),
#  'HIS_PROTON_vc1': (nan, 1.0),
#  'ACET_pc1': (nan, 1.0),
#  'sFUM_biomass2': (nan, 1.0),
#  'sFUM_biomass1': (nan, 1.0),
#  'RXN1G_349_p2': (nan, 1.0),
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p1': (-0.7382921780014017,
#   1.412267386808437e-06),
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2': (nan, 1.0),
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1': (-0.2703220063803485,
#   0.13456222033886095),
#  '3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x1': (nan, 1.0),
#  'ARG_LYS_mc1': (nan, 1.0),
#  '2KG_CIT_mc1': (nan, 1.0),
#  'N_ACETYLGLUTPREDUCT_RXN_p1': (0.5587146017170402, 0.0008886137982872845),
#  'N_ACETYLGLUTPREDUCT_RXN_p2': (nan, 1.0),
#  'L_ALPHA_ALANINE_v_dielTransfer': (nan, 1.0),
#  'PALMITATE_pc1': (nan, 1.0),
#  'PALMITATE_pc2': (nan, 1.0),
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p1': (-0.31227237416045317,
#   0.0818572057089132),
#  'Phloem_output_tx2': (nan, 1.0),
#  'Phloem_output_tx1': (nan, 1.0),
#  'FGAMSYN_RXN_p2': (0.29085719417284367, 0.10630837400615588),
#  'FGAMSYN_RXN_p1': (-0.6955761294068876, 9.90519323882973e-06),
#  'RXN_9651_p1': (nan, 1.0),
#  'RXN_9651_p2': (nan, 1.0),
#  'MALSYN_RXN_x1': (-0.1291262911662983, 0.4812183648864825),
#  'PHOSGLYPHOS_RXN_p1': (nan, 1.0),
#  'PHOSGLYPHOS_RXN_p2': (nan, 1.0),
#  '3PGAREARR_RXN_c1': (0.5677600350650885, 0.0007007815595027012),
#  '3PGAREARR_RXN_c2': (-0.7813656222572966, 1.3052444564420525e-07),
#  'RXN_3521_p1': (nan, 1.0),
#  'OROTPDECARB_RXN_p1': (nan, 1.0),
#  'ALANINE_AMINOTRANSFERASE_RXN_c2': (-0.6514891897916363,
#   5.3749442822635145e-05),
#  'ALANINE_AMINOTRANSFERASE_RXN_c1': (-0.8424845678990908,
#   1.4781228641929706e-09),
#  'ASPARAGINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'Ferredoxin_Plastoquinone_Reductase_p2': (nan, 1.0),
#  'RXN_9540_p2': (nan, 1.0),
#  'RXN_9540_p1': (nan, 1.0),
#  'Ferredoxin_Plastoquinone_Reductase_p1': (nan, 1.0),
#  'RXN_1104_p2': (nan, 1.0),
#  'RXN_1104_p1': (-0.43071114147179634, 0.013859956946581126),
#  'DIHYDROPICRED_RXN_NADP_p2': (nan, 1.0),
#  'DIHYDROPICRED_RXN_NADP_p1': (-0.5600644952841839, 0.0008580414973980897),
#  'PRO_v_dielTransfer': (nan, 1.0),
#  'ARG_PROTON_vc2': (nan, 1.0),
#  'RXN0_2382_p1': (-0.6182264469082813, 0.00016273836942113328),
#  'SUC_SO4_mc2': (nan, 1.0),
#  'SUC_SO4_mc1': (nan, 1.0),
#  'RXN_9650_p2': (nan, 1.0),
#  'RXN_9650_p1': (nan, 1.0),
#  'Octadecadienoyl_ACP_hydrolase_p1': (nan, 1.0),
#  'Octadecadienoyl_ACP_hydrolase_p2': (nan, 1.0),
#  'ARG_ORNITHINE_mc2': (nan, 1.0),
#  'ARG_ORNITHINE_mc1': (nan, 1.0),
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2': (nan, 1.0),
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1': (-0.5153378006784595,
#   0.002540937206598889),
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m1': (0.18296847409657188,
#   0.31617904287050264),
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2': (nan, 1.0),
#  'Glycerate_xc1': (nan, 1.0),
#  'Glycerate_xc2': (nan, 1.0),
#  'RXN_9653_p2': (nan, 1.0),
#  'RXN_9653_p1': (nan, 1.0),
#  'LEU_mc1': (nan, 1.0),
#  'LEU_mc2': (nan, 1.0),
#  'RXN_9657_p2': (-0.2797032676502659, 0.12104066029338631),
#  'RXN_9657_p1': (-0.028007694807174827, 0.8790595043173559),
#  'GLT_xc1': (nan, 1.0),
#  'GLT_xc2': (nan, 1.0),
#  'RXN_9654_p2': (nan, 1.0),
#  'RXN_9654_p1': (nan, 1.0),
#  'Fatty_Acids_pc1': (nan, 1.0),
#  'Fatty_Acids_pc2': (nan, 1.0),
#  'RXN_9655_p1': (nan, 1.0),
#  'RXN_9655_p2': (nan, 1.0),
#  'SO4_pc1': (nan, 1.0),
#  'SO4_pc2': (nan, 1.0),
#  'RXN_9528_p1': (nan, 1.0),
#  'RXN_9528_p2': (nan, 1.0),
#  'THR_pc1': (nan, 1.0),
#  'THR_pc2': (nan, 1.0),
#  'Cellulose_biomass1': (nan, 1.0),
#  'METHYLACYLYLCOA_HYDROXY_RXN_m2': (nan, 1.0),
#  'METHYLACYLYLCOA_HYDROXY_RXN_m1': (nan, 1.0),
#  'Cellulose_biomass2': (nan, 1.0),
#  '2_METHYL_ACETO_ACETYL_COA_mc1': (nan, 1.0),
#  '2_METHYL_ACETO_ACETYL_COA_mc2': (nan, 1.0),
#  'DUTP_PYROP_RXN_p1': (nan, 1.0),
#  'DUTP_PYROP_RXN_p2': (nan, 1.0),
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p1': (-0.44152456476311225,
#   0.011413616802725826),
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p2': (-0.3526228966683107, 0.0477623834282189),
#  'ACETYL_COA_ACETYLTRANSFER_RXN_x1': (nan, 1.0),
#  'ACETYL_COA_ACETYLTRANSFER_RXN_x2': (0.09076237673029434, 0.621289215899055),
#  'CO2_tx1': (nan, 1.0),
#  'MercaptoPyruvateSulfurtransferase_m2': (nan, 1.0),
#  'MercaptoPyruvateSulfurtransferase_m1': (nan, 1.0),
#  'AMP_DEAMINASE_RXN_c1': (-0.3492881507518599, 0.050057364794861656),
#  'AMP_DEAMINASE_RXN_c2': (nan, 1.0),
#  'ACETOVANILLONE_SYNTHASE_c2': (nan, 1.0),
#  'RXN0_5224_c1': (nan, 1.0),
#  'DSERDEAM_RXN_c1': (-0.1431732555857289, 0.4343748575522093),
#  'DSERDEAM_RXN_c2': (nan, 1.0),
#  'HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m1': (nan, 1.0),
#  'HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m2': (nan, 1.0),
#  '2_PERIOD_3_PERIOD_1_PERIOD_133_RXN_c2': (nan, 1.0),
#  '2_PERIOD_3_PERIOD_1_PERIOD_133_RXN_c1': (nan, 1.0),
#  'MALEYLACETOACETATE_ISOMERASE_RXN_c2': (nan, 1.0),
#  'HOMOSERKIN_RXN_p1': (-0.5618140063997592, 0.0008197967049687572),
#  'HOMOSERKIN_RXN_p2': (nan, 1.0),
#  'MALEYLACETOACETATE_ISOMERASE_RXN_c1': (nan, 1.0),
#  '3_ISOPROPYLMALDEHYDROG_RXN_p2': (-0.9070848140004575, 8.435005372865012e-13),
#  'GLUC1PURIDYLTRANS_RXN_p1': (-0.7007513808844454, 7.964508831275031e-06),
#  'GLUC1PURIDYLTRANS_RXN_p2': (-0.7788715350944653, 1.5195511894006942e-07),
#  'RXN1G_445_p2': (nan, 1.0),
#  'RXN1G_445_p1': (nan, 1.0),
#  'H2O_xc1': (nan, 1.0),
#  'MAL_PROTON_rev_vc2': (nan, 1.0),
#  'MAL_PROTON_rev_vc1': (nan, 1.0),
#  'DUMP_pc1': (nan, 1.0),
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m2': (0.7283486431123286,
#   2.2948315228969645e-06),
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m1': (-0.6844388125698416,
#   1.5603289240221343e-05),
#  'Nitrate_tx1': (nan, 1.0),
#  '1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x2': (nan, 1.0),
#  '1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x1': (nan, 1.0),
#  'Nitrate_tx2': (nan, 1.0),
#  'FUM_PROTON_vc2': (nan, 1.0),
#  'FUM_PROTON_vc1': (nan, 1.0),
#  'NADPHoxc_tx2': (nan, 1.0),
#  'NADPHoxc_tx1': (nan, 1.0),
#  'HOMOCYSMETB12_RXN_p2': (nan, 1.0),
#  'METHYLENE_THF_mc2': (nan, 1.0),
#  'RXN_13202_p1': (nan, 1.0),
#  'RXN_13202_p2': (nan, 1.0),
#  'METHYLENE_THF_mc1': (nan, 1.0),
#  'SER_v_dielTransfer': (nan, 1.0),
#  'PYRUVATE_pc1': (nan, 1.0),
#  'PYRUVATE_pc2': (nan, 1.0),
#  'SHIKIMATE_KINASE_RXN_p2': (nan, 1.0),
#  'SHIKIMATE_KINASE_RXN_p1': (0.12786711642533213, 0.4855408985620753),
#  'SUPEROX_DISMUT_RXN_c2': (nan, 1.0),
#  'SUPEROX_DISMUT_RXN_c1': (nan, 1.0),
#  'pTRP_biomass2': (nan, 1.0),
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p2': (nan, 1.0),
#  'RXN_9660_p1': (-0.028007694807174827, 0.8790595043173559),
#  'Pi_PROTON_mc1': (nan, 1.0),
#  'Pi_PROTON_mc2': (nan, 1.0),
#  'RXN_9520_p1': (nan, 1.0),
#  'RXN_9520_p2': (nan, 1.0),
#  'RXN_12486_c2': (nan, 1.0),
#  'RXN_6384_x1': (nan, 1.0),
#  'RXN_9635_p1': (-0.2797032676502659, 0.12104066029338631),
#  'IPP_biosynthesis_c1': (nan, 1.0),
#  'IPP_biosynthesis_c2': (nan, 1.0),
#  'ARGSUCCINLYA_RXN_p2': (nan, 1.0),
#  'pALA_biomass1': (nan, 1.0),
#  'pALA_biomass2': (nan, 1.0),
#  'ARGSUCCINLYA_RXN_p1': (0.34142843058847183, 0.05581390766208836),
#  'DIHYDROOROT_RXN_p2': (nan, 1.0),
#  'DIHYDROOROT_RXN_p1': (nan, 1.0),
#  'GLUTAMINESYN_RXN_p2': (-0.46286185883930314, 0.007639704667899129),
#  'GLUTAMINESYN_RXN_p1': (0.4374900573123, 0.012279979491029552),
#  'HOMOGENTISATE_12_DIOXYGENASE_RXN_c2': (nan, 1.0),
#  'HOMOGENTISATE_12_DIOXYGENASE_RXN_c1': (nan, 1.0),
#  'IMPCYCLOHYDROLASE_RXN_p2': (-0.6302515861201856, 0.0001106542947449623),
#  'IMPCYCLOHYDROLASE_RXN_p1': (-0.7851162004628333, 1.0346336034563059e-07),
#  'RXN_7978_p2': (nan, 1.0),
#  'RXN_7978_p1': (nan, 1.0),
#  'TYROSINE_AMINOTRANSFERASE_RXN_p2': (nan, 1.0),
#  'TYROSINE_AMINOTRANSFERASE_RXN_p1': (nan, 1.0),
#  'METHENYLTHFCYCLOHYDRO_RXN_c1': (-0.3446719931238632, 0.05337799678296207),
#  'RXN_9623_p2': (nan, 1.0),
#  'RXN_11213_m2': (nan, 1.0),
#  'GLN_PROTON_vc2': (nan, 1.0),
#  'GLYC3PDEHYDROGBIOSYN_RXN_c2': (nan, 1.0),
#  '2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p1': (nan, 1.0),
#  '2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p2': (nan, 1.0),
#  'GLYC3PDEHYDROGBIOSYN_RXN_c1': (nan, 1.0),
#  'sGLN_biomass1': (nan, 1.0),
#  'sGLN_biomass2': (nan, 1.0),
#  'PREPHENATE_TRANSAMINE_RXN_p1': (-0.6954646241335706, 9.951350006477724e-06),
#  'PRO_mc2': (nan, 1.0),
#  'PRO_mc1': (nan, 1.0),
#  'PREPHENATE_TRANSAMINE_RXN_p2': (0.8086298942596717, 2.154975933959805e-08),
#  '1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m2': (0.7050814285643691,
#   6.612931802989648e-06),
#  '1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m1': (nan, 1.0),
#  'GLYCERATE_GLYCOLLATE_pc2': (nan, 1.0),
#  'GLYCERATE_GLYCOLLATE_pc1': (nan, 1.0),
#  'IMP_DEHYDROG_RXN_c1': (-0.30382735505080033, 0.09092160758839185),
#  'HIS_pc2': (nan, 1.0),
#  'HIS_pc1': (nan, 1.0),
#  'IMP_DEHYDROG_RXN_c2': (nan, 1.0),
#  'HISTIDPHOS_RXN_p2': (-0.9134852546983495, 3.020880742661018e-13),
#  'HISTIDPHOS_RXN_p1': (-0.7190694170577252, 3.5437844519808615e-06),
#  'PHOSPHOLIPASE_A2_RXN_c1': (nan, 1.0),
#  'PHOSPHOLIPASE_A2_RXN_c2': (nan, 1.0),
#  'SUC_FUM_mc1': (nan, 1.0),
#  'SUC_FUM_mc2': (nan, 1.0),
#  'UREA_mc2': (nan, 1.0),
#  'DHAP_3PGA_pc1': (nan, 1.0),
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m1': (-0.6716140952352478,
#   2.5715494914158108e-05),
#  'SUCROSE_SYNTHASE_RXN_c1': (-0.8000271482894776, 3.9180070945441705e-08),
#  'SUCROSE_SYNTHASE_RXN_c2': (-0.7774127731004427, 1.659365228997339e-07),
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m2': (-0.5197600841369852,
#   0.0022971630998724693),
#  '6PFRUCTPHOS_RXN_c2': (-0.7936313032980635, 5.999806513701933e-08),
#  '6PFRUCTPHOS_RXN_c1': (nan, 1.0),
#  'RXN_1781_v1': (nan, 1.0),
#  'RXN490_3650_p1': (nan, 1.0),
#  'sGABA_biomass2': (nan, 1.0),
#  'sGABA_biomass1': (nan, 1.0),
#  'CIT_xc2': (nan, 1.0),
#  'CIT_xc1': (nan, 1.0),
#  'gadoleic_acid_biosynthesis_p1': (nan, 1.0),
#  'gadoleic_acid_biosynthesis_p2': (nan, 1.0),
#  'GDPREDUCT_RXN_p1': (nan, 1.0),
#  'GDPREDUCT_RXN_p2': (nan, 1.0),
#  'PHE_PROTON_rev_vc2': (nan, 1.0),
#  'PHE_PROTON_rev_vc1': (nan, 1.0),
#  'MANNITOL_1_PHOSPHATASE_RXN_c1': (nan, 1.0),
#  'MANNITOL_1_PHOSPHATASE_RXN_c2': (nan, 1.0),
#  'sGLU_biomass1': (nan, 1.0),
#  'sGLU_biomass2': (nan, 1.0),
#  'ASN_v_dielTransfer': (nan, 1.0),
#  'RXN_1381_p2': (nan, 1.0),
#  'RXN_1381_p1': (nan, 1.0),
#  'AICARSYN_RXN_p1': (-0.18210440100659941, 0.3185092459314527),
#  'AICARSYN_RXN_p2': (-0.6701630688490441, 2.7169825249464858e-05),
#  'ACETOOHBUTSYN_RXN_p2': (nan, 1.0),
#  'K_ec2': (nan, 1.0),
#  'K_ec1': (nan, 1.0),
#  'ACETOOHBUTSYN_RXN_p1': (nan, 1.0),
#  'RXN_8001_p2': (-0.913660100793923, 2.9340857565428683e-13),
#  'RXN_8001_p1': (-0.7496213125452771, 7.906854193265499e-07),
#  'DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p2': (nan, 1.0),
#  'DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p1': (nan, 1.0),
#  'GLT_PROTON_vc2': (nan, 1.0),
#  'GLT_PROTON_vc1': (nan, 1.0),
#  'RXN66_3_m1': (-0.5480311969557085, 0.001166300826409358),
#  'RXN66_3_m2': (nan, 1.0),
#  'sSUCROSE_biomass1': (nan, 1.0),
#  'hexadecadienoate_ACP_desaturase_p1': (nan, 1.0),
#  'hexadecadienoate_ACP_desaturase_p2': (nan, 1.0),
#  'sSUCROSE_biomass2': (nan, 1.0),
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p1': (-0.7388478565897566,
#   1.3735966528726887e-06),
#  'MAL_ISOCITRATE_mc1': (nan, 1.0),
#  'ACET_xc2': (nan, 1.0),
#  'MAL_ISOCITRATE_mc2': (nan, 1.0),
#  'lycopene_biosynthesis_p2': (nan, 1.0),
#  'lycopene_biosynthesis_p1': (nan, 1.0),
#  'pTRP_biomass1': (nan, 1.0),
#  '4_AMINO_BUTYRATE_PROTON_rev_vc2': (nan, 1.0),
#  '4_AMINO_BUTYRATE_PROTON_rev_vc1': (nan, 1.0),
#  'RXN_6883_mi2': (nan, 1.0),
#  'ASPARTATEKIN_RXN_p1': (-0.7633308693890106, 3.7576931411207885e-07),
#  'ASPARTATEKIN_RXN_p2': (nan, 1.0),
#  'RXN_7677_p2': (nan, 1.0),
#  'RXN_7677_p1': (0.061856894133544935, 0.736632569089071),
#  'pHIS_biomass1': (nan, 1.0),
#  '2_METHYL_3_HYDROXY_BUTYRYL_COA_xc2': (nan, 1.0),
#  '2_METHYL_3_HYDROXY_BUTYRYL_COA_xc1': (nan, 1.0),
#  'RXN0_5260_m1': (nan, 1.0),
#  'RXN0_5260_m2': (nan, 1.0),
#  '3_PERIOD_1_PERIOD_2_PERIOD_14_RXN_p1': (nan, 1.0),
#  'GLYCINE_AMINOTRANSFERASE_RXN_x1': (-0.4378457780643774,
#   0.012201435665323373),
#  'RXN_7676_p1': (0.06185689413354501, 0.736632569089071),
#  'RXN_7676_p2': (nan, 1.0),
#  'sMAL_biomass1': (nan, 1.0),
#  'sMAL_biomass2': (nan, 1.0),
#  'pGLY_biomass2': (nan, 1.0),
#  'pGLY_biomass1': (nan, 1.0),
#  'RXN_7674_p2': (nan, 1.0),
#  'RXN_7674_p1': (nan, 1.0),
#  '3_PERIOD_2_PERIOD_1_PERIOD_48_RXN_v1': (nan, 1.0),
#  'VANILLICACID_BIOSYNTHESIS_c1': (nan, 1.0),
#  'VANILLICACID_BIOSYNTHESIS_c2': (nan, 1.0),
#  '3_PERIOD_2_PERIOD_1_PERIOD_48_RXN_v2': (nan, 1.0),
#  '4_AMINO_BUTYRATE_PROTON_vc1': (nan, 1.0),
#  '4_AMINO_BUTYRATE_PROTON_vc2': (nan, 1.0),
#  'ILE_pc2': (nan, 1.0),
#  'ILE_pc1': (nan, 1.0),
#  'GMP_SYN_GLUT_RXN_c2': (nan, 1.0),
#  'GMP_SYN_GLUT_RXN_c1': (0.2951495561736218, 0.1010137967726792),
#  'PHE_v_dielTransfer': (nan, 1.0),
#  'RXN_7985_p2': (nan, 1.0),
#  'RXN_7985_p1': (nan, 1.0),
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c1': (nan, 1.0),
#  'sCIT_biomass2': (nan, 1.0),
#  'sCIT_biomass1': (nan, 1.0),
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c2': (nan, 1.0),
#  'RXN_7679_p1': (nan, 1.0),
#  'RXN_7679_p2': (nan, 1.0),
#  'GUANYL_KIN_RXN_c2': (nan, 1.0),
#  'GUANYL_KIN_RXN_c1': (0.31262580855390837, 0.0814936141848808),
#  'RXN_6384_x2': (nan, 1.0),
#  'RXN_12486_c1': (nan, 1.0),
#  'RXN_8871_c1': (nan, 1.0),
#  'RXN_8871_c2': (nan, 1.0),
#  'VAL_PROTON_rev_vc2': (nan, 1.0),
#  'UDPKIN_RXN_p2': (-0.9172186800089519, 1.598902466563797e-13),
#  'SYRINGICACID_BIOSYNTHESIS_c2': (nan, 1.0),
#  'ACETOLACTSYN_RXN_p1': (-0.1323398740208633, 0.4702774326791379),
#  'MALSYN_RXN_x2': (nan, 1.0),
#  'UDPKIN_RXN_p1': (-0.7657167319435346, 3.2847400284184613e-07),
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c1': (-0.0970888166733911,
#   0.5970706206576805),
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c2': (0.0002987531923636657,
#   0.9987052240869476),
#  'GLT_MAL_pc2': (nan, 1.0),
#  'GLT_MAL_pc1': (nan, 1.0),
#  'Beta_Oxidation_x1': (nan, 1.0),
#  'Beta_Oxidation_x2': (nan, 1.0),
#  'MET_PROTON_rev_vc2': (nan, 1.0),
#  '2K_ADIPATE_mc2': (nan, 1.0),
#  '2K_ADIPATE_mc1': (nan, 1.0),
#  'MET_PROTON_rev_vc1': (nan, 1.0),
#  'GLY_v_dielTransfer': (nan, 1.0),
#  'NITRATE_vc2': (nan, 1.0),
#  'NITRATE_vc1': (nan, 1.0),
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p2': (nan, 1.0),
#  '1_PERIOD_5_PERIOD_1_PERIOD_8_RXN_c1': (nan, 1.0),
#  '1_PERIOD_5_PERIOD_1_PERIOD_8_RXN_c2': (-0.40914232459241495,
#   0.02006144933306155),
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p1': (-0.29463317163417707,
#   0.1016399878043717),
#  'NITRATE_v_dielTransfer': (nan, 1.0),
#  'GMP_pc2': (nan, 1.0),
#  'GMP_pc1': (nan, 1.0),
#  'CIT_ISOCITRATE_mc2': (nan, 1.0),
#  'CIT_ISOCITRATE_mc1': (nan, 1.0),
#  'GLC_pc2': (nan, 1.0),
#  'GLC_pc1': (nan, 1.0),
#  'TYR_PROTON_vc1': (nan, 1.0),
#  'TYR_PROTON_vc2': (nan, 1.0),
#  'GLU6PDEHYDROG_RXN_p1': (nan, 1.0),
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m2': (nan, 1.0),
#  'DIHYDROFOLATEREDUCT_RXN_m1': (nan, 1.0),
#  'DIHYDROFOLATEREDUCT_RXN_m2': (-0.1256572969275465, 0.49317476793094883),
#  'HISTAMINOTRANS_RXN_p1': (-0.4501726581525776, 0.009728702600164767),
#  'HISTAMINOTRANS_RXN_p2': (-0.7461157420069634, 9.491727027552207e-07),
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p1': (nan, 1.0),
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p2': (nan, 1.0),
#  'RXN0_5184_c1': (nan, 1.0),
#  'RXN0_5184_c2': (-0.6749178612789734, 2.2662471149173316e-05),
#  'MEPROPCOA_FAD_RXN_m2': (nan, 1.0),
#  'MEPROPCOA_FAD_RXN_m1': (nan, 1.0),
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p1': (-0.5020871577564023,
#   0.0034104556256736003),
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p2': (nan, 1.0),
#  'PHE_PROTON_vc1': (nan, 1.0),
#  'PHE_PROTON_vc2': (nan, 1.0),
#  'RIB5PISOM_RXN_p1': (-0.620463185469249, 0.00015165287528878793),
#  'ORNITHINE_CITRULLINE_mc2': (nan, 1.0),
#  'ORNITHINE_CITRULLINE_mc1': (nan, 1.0),
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p2': (nan, 1.0),
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p1': (nan, 1.0),
#  'Plastoquinol_Oxidase_p1': (nan, 1.0),
#  'Plastoquinol_Oxidase_p2': (nan, 1.0),
#  'VAL_PROTON_vc1': (nan, 1.0),
#  'VAL_PROTON_vc2': (nan, 1.0),
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p2': (nan, 1.0),
#  'NH4_tx2': (nan, 1.0),
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc1': (nan, 1.0),
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc2': (-0.37636629906644636,
#   0.033744536034857095),
#  'DTMP_mc2': (nan, 1.0),
#  'DTMP_mc1': (nan, 1.0),
#  'CHORISMATEMUT_RXN_p2': (0.2972923337385764, 0.09844648642970709),
#  'GLYCINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'sSER_biomass1': (nan, 1.0),
#  'sSER_biomass2': (nan, 1.0),
#  'ARG_LYS_mc2': (nan, 1.0),
#  '3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x2': (-0.09304134346825738,
#   0.6125182455105309),
#  'CYS_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'ACETYLGLUTKIN_RXN_p1': (0.4301602380596847, 0.01399551149698864),
#  'ACETYLGLUTKIN_RXN_p2': (nan, 1.0),
#  'RXN_1121_c2': (nan, 1.0),
#  'RXN_1121_c1': (nan, 1.0),
#  'RXN_961_p1': (nan, 1.0),
#  'RXN_961_p2': (nan, 1.0),
#  '2_PERIOD_7_PERIOD_8_PERIOD_11_RXN_r2': (nan, 1.0),
#  '2_PERIOD_7_PERIOD_8_PERIOD_11_RXN_r1': (nan, 1.0),
#  'sILE_biomass2': (nan, 1.0),
#  'sILE_biomass1': (nan, 1.0),
#  'ARGININE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'ARGININE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'MET_PROTON_vc1': (nan, 1.0),
#  'MET_PROTON_vc2': (nan, 1.0),
#  'DIAMINOPIMDECARB_RXN_p2': (nan, 1.0),
#  'DIAMINOPIMDECARB_RXN_p1': (-0.39588992571355514, 0.024901844776114422),
#  '2_PERIOD_7_PERIOD_7_PERIOD_14_RXN_m2': (nan, 1.0),
#  'Xylan_biomass1': (nan, 1.0),
#  'Xylan_biomass2': (nan, 1.0),
#  'RXN_1225_p2': (nan, 1.0),
#  'RXN_1225_p1': (nan, 1.0),
#  'RXN_1103_c2': (nan, 1.0),
#  'RXN_1103_c1': (nan, 1.0),
#  'TYR_v_dielTransfer': (nan, 1.0),
#  'PHOSPHAGLYPSYN_RXN_m1': (nan, 1.0),
#  'RXN_3522_p1': (nan, 1.0),
#  'RXN_3522_p2': (nan, 1.0),
#  'GLUC1PADENYLTRANS_RXN_p1': (-0.7654600868426799, 3.332865812408663e-07),
#  'GLUC1PADENYLTRANS_RXN_p2': (nan, 1.0),
#  'SER_PROTON_vc1': (nan, 1.0),
#  'SER_PROTON_vc2': (nan, 1.0),
#  'GLN_GLU_mc1': (nan, 1.0),
#  'GLN_GLU_mc2': (nan, 1.0),
#  'ALCOHOL_DEHYDROG_RXN_c1': (nan, 1.0),
#  'ALCOHOL_DEHYDROG_RXN_c2': (nan, 1.0),
#  'Biomass_tx2': (nan, 1.0),
#  'CYSTATHIONINE_BETA_LYASE_RXN_p2': (nan, 1.0),
#  'CYSTATHIONINE_BETA_LYASE_RXN_p1': (-0.06130096418689048, 0.7389171299457752),
#  'RXN_7903_p1': (nan, 1.0),
#  'RXN_7903_p2': (nan, 1.0),
#  'SAICARSYN_RXN_p2': (0.7077542677565938, 5.886080742164395e-06),
#  'SAICARSYN_RXN_p1': (-0.20348962224586034, 0.26397277021519794),
#  'METHENYLTHFCYCLOHYDRO_RXN_c2': (-0.5369167473295714, 0.0015331718856542666),
#  'GLN_PROTON_vc1': (nan, 1.0),
#  'UGD_RXN_c2': (nan, 1.0),
#  'UGD_RXN_c1': (nan, 1.0),
#  'RXN_11213_m1': (nan, 1.0),
#  'pASP_biomass1': (nan, 1.0),
#  'pASP_biomass2': (nan, 1.0),
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c1': (nan, 1.0),
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c2': (-0.9334946620478026,
#   6.6935998010794084e-15),
#  'OAA_MAL_pc1': (nan, 1.0),
#  'OAA_MAL_pc2': (nan, 1.0),
#  'PYRROLINECARBREDUCT_RXN_NAD_c1': (-0.0023633807440506713,
#   0.9897575321363832),
#  'PYRROLINECARBREDUCT_RXN_NAD_c2': (nan, 1.0),
#  'RXN_9658_p2': (-0.2797032676502659, 0.12104066029338631),
#  'RXN_9658_p1': (-0.028007694807174827, 0.8790595043173559),
#  'RXN_5682_p1': (nan, 1.0),
#  'RXN_5682_p2': (nan, 1.0),
#  'RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p1': (0.11465989978257314,
#   0.5320531701089601),
#  'PHOSPHORYL_CHOLINE_mc2': (nan, 1.0),
#  'ATP_AMP_mc2': (nan, 1.0),
#  'PHOSPHORYL_CHOLINE_mc1': (nan, 1.0),
#  'RXN_7737_p1': (-0.1623050684322632, 0.37480303003162085),
#  'Glycerol_biomass2': (nan, 1.0),
#  'Glycerol_biomass1': (nan, 1.0),
#  'RXN_7737_p2': (nan, 1.0),
#  'GLY_PROTON_rev_vc2': (nan, 1.0),
#  'GLY_PROTON_rev_vc1': (nan, 1.0),
#  'ISOCIT_CLEAV_RXN_x2': (nan, 1.0),
#  'GLN_v_dielTransfer': (nan, 1.0),
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c2': (nan, 1.0),
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c1': (nan, 1.0),
#  'ISOCIT_CLEAV_RXN_x1': (-0.0013491432972277308, 0.9941529524110087),
#  'ISOBUTYRYL_COA_xc2': (nan, 1.0),
#  'ISOBUTYRYL_COA_xc1': (nan, 1.0),
#  'RXN_9548_p2': (nan, 1.0),
#  'RXN_9548_p1': (nan, 1.0),
#  'CDPDIGLYSYN_RXN_p1': (nan, 1.0),
#  'CDPDIGLYSYN_RXN_p2': (nan, 1.0),
#  'FattyAcid_biomass2': (nan, 1.0),
#  'FattyAcid_biomass1': (nan, 1.0),
#  'AICARTRANSFORM_RXN_p1': (-0.7851162004628333, 1.0346336034563059e-07),
#  'AICARTRANSFORM_RXN_p2': (-0.6302515861201856, 0.0001106542947449623),
#  'hexadecatrienoate_biosynthesis_p2': (nan, 1.0),
#  'hexadecatrienoate_biosynthesis_p1': (nan, 1.0),
#  'PGPPHOSPHA_RXN_p1': (nan, 1.0),
#  'PGPPHOSPHA_RXN_p2': (nan, 1.0),
#  'MAL_v_dielTransfer': (nan, 1.0),
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_m1': (-0.14430209275587216,
#   0.43072245260092756),
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_m2': (0.05771551978272384,
#   0.7537031048800825),
#  'sLEU_biomass1': (nan, 1.0),
#  'RXN0_1483_c2': (nan, 1.0),
#  'RXN0_1483_c1': (nan, 1.0),
#  'sLEU_biomass2': (nan, 1.0),
#  'F16BDEPHOS_RXN_p1': (-0.6258954157905647, 0.00012748397739299248),
#  'F16BDEPHOS_RXN_p2': (nan, 1.0),
#  'LYS_PROTON_rev_vc1': (nan, 1.0),
#  'FUMHYDR_RXN_m1': (-0.7400082546841971, 1.29593391650412e-06),
#  'FUMHYDR_RXN_m2': (-0.726076004068616, 2.5566232140779066e-06),
#  'LYS_PROTON_rev_vc2': (nan, 1.0),
#  'IMIDPHOSDEHYD_RXN_p2': (-0.8598556103753544, 2.8939572126986355e-10),
#  'IMIDPHOSDEHYD_RXN_p1': (-0.646731186960318, 6.348920492536697e-05),
#  'RXN_9652_p1': (nan, 1.0),
#  'RXN_9652_p2': (nan, 1.0),
#  'Protein_Polymerisation_c1': (nan, 1.0),
#  'Protein_Polymerisation_c2': (nan, 1.0),
#  'L_ASPARTATE_GLU_mc2': (nan, 1.0),
#  'THR_PROTON_vc1': (nan, 1.0),
#  'THR_PROTON_vc2': (nan, 1.0),
#  'SER_mc1': (nan, 1.0),
#  'SER_mc2': (nan, 1.0),
#  '2KG_SUC_mc2': (nan, 1.0),
#  'UDPREDUCT_RXN_p2': (nan, 1.0),
#  'UDPREDUCT_RXN_p1': (nan, 1.0),
#  'ALLYSINE_DEHYDROG_RXN_c1': (nan, 1.0),
#  'ALLYSINE_DEHYDROG_RXN_c2': (nan, 1.0),
#  'RXN_9632_p2': (nan, 1.0),
#  'RXN_9632_p1': (nan, 1.0),
#  'PROPCOASYN_RXN_x1': (nan, 1.0),
#  'PROPCOASYN_RXN_x2': (nan, 1.0),
#  'ACETOSYRINGONE_BIOSYNTHESIS_c1': (nan, 1.0),
#  'ACETOSYRINGONE_BIOSYNTHESIS_c2': (nan, 1.0),
#  'RXN_9531_p2': (nan, 1.0),
#  'RXN_9531_p1': (nan, 1.0),
#  'PSERTRANSAM_RXN_p1': (nan, 1.0),
#  'PSERTRANSAM_RXN_p2': (0.5269442767767181, 0.0019443470528710902),
#  'CDPREDUCT_RXN_p1': (nan, 1.0),
#  'CDPREDUCT_RXN_p2': (nan, 1.0),
#  'SUC_xc1': (nan, 1.0),
#  'SUC_xc2': (nan, 1.0),
#  '2KG_MAL_pc1': (nan, 1.0),
#  'HOMOSERDEHYDROG_RXN_NADP_p2': (nan, 1.0),
#  'HOMOSERDEHYDROG_RXN_NADP_p1': (-0.7456111116149027, 9.742308493114063e-07),
#  '1TRANSKETO_RXN_p2': (-0.5482626688560506, 0.00115956000739792),
#  '1TRANSKETO_RXN_p1': (0.036781775288167305, 0.8415913823060375),
#  'Biomass_tx1': (nan, 1.0),
#  'RXN_9537_p2': (nan, 1.0),
#  'PGLUCISOM_RXN_p2': (-0.7147542203318837, 4.312513208176001e-06),
#  'PGLUCISOM_RXN_p1': (-0.7145356317303749, 4.3552053764867046e-06),
#  'ARGSUCCINSYN_RXN_p2': (nan, 1.0),
#  'ARGSUCCINSYN_RXN_p1': (-0.8676029467460734, 1.3017474413293589e-10),
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p2': (nan, 1.0),
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p1': (-0.7857437158923225,
#   9.947407980618898e-08),
#  'ILE_v_dielTransfer': (nan, 1.0),
#  'HS_pc1': (nan, 1.0),
#  'HS_pc2': (nan, 1.0),
#  'RXN_9535_p2': (nan, 1.0),
#  'RXN_9535_p1': (nan, 1.0),
#  '3PGA_Pi_pc2': (nan, 1.0),
#  'GLY_PROTON_vc1': (nan, 1.0),
#  'GLUTACONYL_COA_mc2': (nan, 1.0),
#  'GLUTACONYL_COA_mc1': (nan, 1.0),
#  'GLY_PROTON_vc2': (nan, 1.0),
#  'SYRINGALDEHYDE_BIOSYNTHESIS_c1': (nan, 1.0),
#  'SYRINGALDEHYDE_BIOSYNTHESIS_c2': (nan, 1.0),
#  'DHAP_3PGA_pc2': (nan, 1.0),
#  'UREA_mc1': (nan, 1.0),
#  'ALANINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'ALANINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'THR_v_dielTransfer': (nan, 1.0),
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_c1': (-0.5016076645907863,
#   0.0034462241227592822),
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_c2': (nan, 1.0),
#  'MAL_CIT_rev_vc1': (nan, 1.0),
#  'MAL_CIT_rev_vc2': (nan, 1.0),
#  'RXN_10773_c1': (nan, 1.0),
#  '1_PERIOD_5_PERIOD_1_PERIOD_9_RXN_c2': (-0.40914232459241495,
#   0.02006144933306155),
#  '1_PERIOD_5_PERIOD_1_PERIOD_9_RXN_c1': (nan, 1.0),
#  'RXN_10773_c2': (nan, 1.0),
#  'CATAL_RXN_x1': (-0.5401370059875392, 0.0014177295298990163),
#  'SEDOBISALDOL_RXN_p1': (nan, 1.0),
#  'SUC_Pi_mc2': (nan, 1.0),
#  'CATAL_RXN_x2': (nan, 1.0),
#  'PRO_GLU_mc1': (nan, 1.0),
#  'PRO_GLU_mc2': (nan, 1.0),
#  'PGLYCDEHYDROG_RXN_p2': (-0.2511197272855026, 0.16563627757013574),
#  'PGLYCDEHYDROG_RXN_p1': (nan, 1.0),
#  'MALATE_DEH_RXN_p1': (-0.5520935071074946, 0.001052852114310601),
#  'sASP_biomass2': (nan, 1.0),
#  'sASP_biomass1': (nan, 1.0),
#  'MALATE_DEH_RXN_p2': (-0.4190211608122825, 0.01698385752959095),
#  'S_ADENMETSYN_RXN_c2': (nan, 1.0),
#  'sTYR_biomass1': (nan, 1.0),
#  'sTYR_biomass2': (nan, 1.0),
#  'S_ADENMETSYN_RXN_c1': (nan, 1.0),
#  'RXN_1781_v2': (nan, 1.0),
#  'ASPARTATE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'ASPARTATE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'CELLULOSE_SYNTHASE_GDP_FORMING_RXN_c1': (nan, 1.0),
#  'CELLULOSE_SYNTHASE_GDP_FORMING_RXN_c2': (nan, 1.0),
#  'RXN_2621_c1': (nan, 1.0),
#  'RXN_2621_c2': (nan, 1.0),
#  '2KG_ISOCITRATE_mc2': (nan, 1.0),
#  '2KG_ISOCITRATE_mc1': (nan, 1.0),
#  'ACONITATEDEHYDR_RXN_c1': (-0.5547765676628729, 0.0009833406887284825),
#  'LYS_ORNITHINE_mc1': (nan, 1.0),
#  'ACONITATEDEHYDR_RXN_c2': (-0.45221365491233345, 0.009363304845456706),
#  'ADENYL_KIN_RXN_m1': (0.6451820387978505, 6.698591909322532e-05),
#  'ADENYL_KIN_RXN_m2': (-0.493737878210667, 0.004081279442494503),
#  'SUCROSE_PROTON_vc1': (nan, 1.0),
#  'HMBPP_synthesis_p2': (nan, 1.0),
#  'HMBPP_synthesis_p1': (nan, 1.0),
#  'SUCROSE_PROTON_vc2': (nan, 1.0),
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p2': (nan, 1.0),
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p1': (-0.7348452012822128,
#   1.6751392556310074e-06),
#  'sARG_biomass2': (nan, 1.0),
#  'sARG_biomass1': (nan, 1.0),
#  'ACETOVANILLONE_HYDROXYLASE_c1': (nan, 1.0),
#  'K_rev_vc2': (nan, 1.0),
#  'sCYS_biomass1': (nan, 1.0),
#  'OAA_xc2': (nan, 1.0),
#  'OAA_xc1': (nan, 1.0),
#  'PHOSPHOGLUCMUT_RXN_c2': (-0.7070008788444824, 6.083248726713506e-06),
#  'PHOSPHOGLUCMUT_RXN_c1': (-0.6853653545724282, 1.5035681728927685e-05),
#  'pASN_biomass2': (nan, 1.0),
#  'Arachidoyl_ACP_desaturase_p1': (nan, 1.0),
#  'pMET_biomass2': (nan, 1.0),
#  'pMET_biomass1': (nan, 1.0),
#  'SUC_ACONITATE_mc2': (nan, 1.0),
#  'SUC_ACONITATE_mc1': (nan, 1.0),
#  'PHOSPHORIBULOKINASE_RXN_p1': (-0.7015678323149952, 7.691981733059328e-06),
#  'sHIS_biomass2': (nan, 1.0),
#  'sHIS_biomass1': (nan, 1.0),
#  'DIAMINOPIMEPIM_RXN_p1': (-0.6660351824254975, 3.17212220435814e-05),
#  'DIAMINOPIMEPIM_RXN_p2': (nan, 1.0),
#  'RXN0_884_p2': (nan, 1.0),
#  'RXN0_884_p1': (nan, 1.0),
#  'PHOSPHORIBULOKINASE_RXN_p2': (nan, 1.0),
#  '1_PERIOD_1_PERIOD_1_PERIOD_39_RXN_m1': (nan, 1.0),
#  '1_PERIOD_1_PERIOD_1_PERIOD_39_RXN_m2': (nan, 1.0),
#  'CDPKIN_RXN_m2': (nan, 1.0),
#  'CDPKIN_RXN_m1': (nan, 1.0),
#  'Ca_biomass2': (nan, 1.0),
#  'Ca_biomass1': (nan, 1.0),
#  'PYRUVATE_PROTON_mc1': (nan, 1.0),
#  'PYRUVATE_PROTON_mc2': (nan, 1.0),
#  'RXN_9516_p1': (nan, 1.0),
#  'RXN_9516_p2': (nan, 1.0),
#  'TRIOSEPISOMERIZATION_RXN_c1': (-0.8524287550852074, 5.960446240102461e-10),
#  'TRIOSEPISOMERIZATION_RXN_c2': (-0.787402613079811, 8.959696855000647e-08),
#  'CYTOCHROME_C_OXIDASE_RXN_mc1': (0.33136104663943106, 0.06393766845169929),
#  'ACETATE_COA_LIGASE_RXN_p1': (0.37173939413841023, 0.036175558711911915),
#  'ACETATE_COA_LIGASE_RXN_p2': (0.2273880506105541, 0.2107164942364535),
#  'CYTOCHROME_C_OXIDASE_RXN_mc2': (-0.6278425048573225, 0.00011969799407904704),
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1': (nan, 1.0),
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2': (nan, 1.0),
#  'LEU_PROTON_rev_vc2': (nan, 1.0),
#  'FERULIC_ACID_pc2': (nan, 1.0),
#  'sLYS_biomass2': (nan, 1.0),
#  'sLYS_biomass1': (nan, 1.0),
#  'PREPHENATEDEHYDROG_RXN_p2': (nan, 1.0),
#  'PREPHENATEDEHYDROG_RXN_p1': (nan, 1.0),
#  'SEDOBISALDOL_RXN_p2': (nan, 1.0),
#  'sMET_biomass1': (nan, 1.0),
#  'sMET_biomass2': (nan, 1.0),
#  'RXN0_2301_m1': (nan, 1.0),
#  'Sucrose_ec1': (nan, 1.0),
#  'Sucrose_ec2': (nan, 1.0),
#  'Oleoyl_ACP_desaturase_p1': (nan, 1.0),
#  'Oleoyl_ACP_desaturase_p2': (nan, 1.0),
#  'ASPCARBTRANS_RXN_p1': (nan, 1.0),
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p2': (-0.4980513481587128, 0.0037217659350883346),
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p1': (-0.40170156642327426, 0.022672744720600838),
#  'ASPCARBTRANS_RXN_p2': (nan, 1.0),
#  'SUCROSE_PROTON_rev_vc2': (nan, 1.0),
#  'SUCROSE_PROTON_rev_vc1': (nan, 1.0),
#  'ISOCITRATE_ACONITATE_mc2': (nan, 1.0),
#  'ISOCITRATE_ACONITATE_mc1': (nan, 1.0),
#  '2OXOGLUTARATEDEH_RXN_m2': (nan, 1.0),
#  '2OXOGLUTARATEDEH_RXN_m1': (nan, 1.0),
#  'MYO_INOSITOL_OXYGENASE_RXN_c2': (nan, 1.0),
#  'MYO_INOSITOL_OXYGENASE_RXN_c1': (nan, 1.0),
#  'GLYCOGENSYN_RXN_p2': (nan, 1.0),
#  'SUC_CIT_mc1': (nan, 1.0),
#  'SUC_CIT_mc2': (nan, 1.0),
#  'GLYCOGENSYN_RXN_p1': (-0.6130549747461498, 0.0001911810923160899),
#  'RXN_12002_p2': (nan, 1.0),
#  'RXN_12002_p1': (nan, 1.0),
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2': (nan, 1.0),
#  'HISTIDINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'ACETYLORNTRANSAM_RXN_p1': (-0.6107801904783412, 0.00020503647991568482),
#  'ACETYLORNTRANSAM_RXN_p2': (nan, 1.0),
#  'OAA_CIT_mc2': (nan, 1.0),
#  'OAA_CIT_mc1': (nan, 1.0),
#  'Phytol_biosynthesis_p2': (nan, 1.0),
#  'Phytol_biosynthesis_p1': (nan, 1.0),
#  '3_ISOPROPYLMALISOM_RXN_p2': (-0.8708228135036095, 9.201937869464706e-11),
#  'CTPSYN_RXN_p1': (nan, 1.0),
#  'CTPSYN_RXN_p2': (nan, 1.0),
#  '3_ISOPROPYLMALISOM_RXN_p1': (-0.7277934164184738, 2.356434391787037e-06),
#  'AIRS_RXN_p2': (-0.6957983838629039, 9.813770045445885e-06),
#  'AIRS_RXN_p1': (-0.24691216332904295, 0.17307848239641),
#  'ISPH2_RXN_p2': (nan, 1.0),
#  'ISPH2_RXN_p1': (nan, 1.0),
#  'pLYS_biomass1': (nan, 1.0),
#  'pLYS_biomass2': (nan, 1.0),
#  'RXN_9518_p2': (nan, 1.0),
#  'RXN_9518_p1': (nan, 1.0),
#  'GLT_v_dielTransfer': (nan, 1.0),
#  'hexadecadienoate_biosynthesis_p2': (nan, 1.0),
#  'hexadecadienoate_biosynthesis_p1': (nan, 1.0),
#  'VAL_v_dielTransfer': (nan, 1.0),
#  'MALIC_NADP_RXN_c2': (-0.2987334952076483, 0.09674781041434258),
#  'MALIC_NADP_RXN_c1': (nan, 1.0),
#  'LEU_v_dielTransfer': (nan, 1.0),
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p2': (-0.34000276458209167,
#   0.0569119910666727),
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p1': (-0.12109729717553,
#   0.5091180470968111),
#  'UDPGLUCEPIM_RXN_c1': (nan, 1.0),
#  'UDPGLUCEPIM_RXN_c2': (nan, 1.0),
#  'SULFATE_ADENYLYLTRANS_RXN_p1': (-0.02003418287171704, 0.913335561791321),
#  'SULFATE_ADENYLYLTRANS_RXN_p2': (nan, 1.0),
#  'Phytol_degradation_p2': (nan, 1.0),
#  'Phytol_degradation_p1': (nan, 1.0),
#  'UREASE_RXN_c1': (nan, 1.0),
#  'UREASE_RXN_c2': (nan, 1.0),
#  'RXN_12541_c1': (nan, 1.0),
#  'RXN_12541_c2': (nan, 1.0),
#  'OROTATE_REDUCTASE_NADH_RXN_p2': (nan, 1.0),
#  'arachidate_biosynthesis_p1': (nan, 1.0),
#  'arachidate_biosynthesis_p2': (nan, 1.0),
#  'OROTATE_REDUCTASE_NADH_RXN_p1': (nan, 1.0),
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c2': (nan, 1.0),
#  'GPH_RXN_p2': (nan, 1.0),
#  'GPH_RXN_p1': (-0.6969402322981076, 9.356001583469458e-06),
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c1': (-0.7940965931826601, 5.81957651845515e-08),
#  'RXN_7984_p1': (nan, 1.0),
#  'RXN_7984_p2': (nan, 1.0),
#  'SUCROSE_PHOSPHATASE_RXN_c1': (-0.3932533451470359, 0.025970873552948755),
#  'SUCROSE_PHOSPHATASE_RXN_c2': (-0.3828402229867557, 0.030567181525926218),
#  'RXN_9623_p1': (nan, 1.0),
#  'Palmitate_biomass1': (nan, 1.0),
#  'Palmitate_biomass2': (nan, 1.0),
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c2': (nan, 1.0),
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c1': (nan, 1.0),
#  'TRP_pc1': (nan, 1.0),
#  'TRP_pc2': (nan, 1.0),
#  'MAL_PROTON_vc1': (nan, 1.0),
#  'MAL_PROTON_vc2': (nan, 1.0),
#  'HIS_v_dielTransfer': (nan, 1.0),
#  'LEU_PROTON_vc1': (nan, 1.0),
#  'LEU_PROTON_vc2': (nan, 1.0),
#  'Glycolate_xc1': (nan, 1.0),
#  'Glycolate_xc2': (nan, 1.0),
#  'ARG_v_dielTransfer': (nan, 1.0),
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c1': (nan, 1.0),
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c2': (nan, 1.0),
#  'OAA_ISOCITRATE_mc2': (nan, 1.0),
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p1': (-0.4892005662316682,
#   0.004491315955747099),
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p2': (nan, 1.0),
#  'VALINE_TRNA_LIGASE_RXN_c2': (0.5479217621288024, 0.00116949967256666),
#  'VALINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'Pi_tx2': (nan, 1.0),
#  'Pi_tx1': (nan, 1.0),
#  'F16ALDOLASE_RXN_c1': (-0.29464521673253014, 0.10162534805524817),
#  'F16ALDOLASE_RXN_c2': (-0.5263903521990075, 0.0019697618966521054),
#  'TRP_v_dielTransfer': (nan, 1.0),
#  'ACETOVANILLONE_HYDROXYLASE_c2': (nan, 1.0),
#  'RXN_13161_m1': (nan, 1.0),
#  'RXN_13161_m2': (nan, 1.0),
#  'MALATE_DEHYDROGENASE_NADP_RXN_p1': (0.10435184934659929, 0.5697817783975965),
#  'LYSINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'MANNPISOM_RXN_c2': (nan, 1.0),
#  'MANNPISOM_RXN_c1': (nan, 1.0),
#  'LYSINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  '3_HYDROXYPROPIONATE_DEHYDROGENASE_RXN_m1': (nan, 1.0),
#  'HISTCYCLOHYD_RXN_p2': (-0.521940233847401, 0.0021846492202787686),
#  'RXN_3422_c2': (nan, 1.0),
#  'RXN_3422_c1': (nan, 1.0),
#  'HISTCYCLOHYD_RXN_p1': (-0.27812118958269866, 0.12324722149047655),
#  'CPD_14927_xc2': (nan, 1.0),
#  'CPD_14927_xc1': (nan, 1.0),
#  'GLUTATHIONE_PEROXIDASE_RXN_p1': (nan, 1.0),
#  'PROTON_ATPase_c1': (nan, 1.0),
#  'PROTON_ATPase_c2': (nan, 1.0),
#  'FRUCTOKINASE_RXN_c2': (nan, 1.0),
#  'ACETOLACTREDUCTOISOM_RXN_p2': (nan, 1.0),
#  'ACETOLACTREDUCTOISOM_RXN_p1': (-0.8879306804961857, 1.2299856457202914e-11),
#  'FRUCTOKINASE_RXN_c1': (nan, 1.0),
#  'CYS_mc1': (nan, 1.0),
#  'CYS_mc2': (nan, 1.0),
#  'RXN_9539_p2': (nan, 1.0),
#  'RXN_9539_p1': (nan, 1.0),
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p1': (-0.6516576856615199,
#   5.3430582861328994e-05),
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p2': (nan, 1.0),
#  'WATER_vc2': (nan, 1.0),
#  'WATER_vc1': (nan, 1.0),
#  '6PGLUCONOLACT_RXN_c2': (0.5723987431086268, 0.0006187834986103325),
#  'PRPPSYN_RXN_p2': (-0.8611499906864887, 2.5408351190062513e-10),
#  'PRPPSYN_RXN_p1': (-0.8521570672885106, 6.115511929739356e-10),
#  'MET_pc1': (nan, 1.0),
#  'MET_pc2': (nan, 1.0),
#  'RXN_1827_p2': (-0.3247070287312131, 0.06979649453737233),
#  'RXN_1827_p1': (-0.0019039406320377629, 0.9917485876080223),
#  'TYROSINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'TYROSINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m1': (nan, 1.0),
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m2': (nan, 1.0),
#  'THREONINE_ALDOLASE_RXN_c1': (nan, 1.0),
#  'THREONINE_ALDOLASE_RXN_c2': (nan, 1.0),
#  'CYS_PROTON_rev_vc1': (nan, 1.0),
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c2': (nan, 1.0),
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'TRP_TRNA_LIGASE_RXN_c1': (nan, 1.0),
#  'sGLY_biomass2': (nan, 1.0),
#  'RXN1G_320_p2': (nan, 1.0),
#  'RXN1G_320_p1': (nan, 1.0),
#  'CYS_PROTON_rev_vc2': (nan, 1.0),
#  'HOMO_CYS_pc1': (nan, 1.0),
#  'HOMO_CYS_pc2': (nan, 1.0),
#  'ATPase_tx1': (nan, 1.0),
#  'ATPase_tx2': (nan, 1.0),
#  'pLEU_biomass2': (nan, 1.0),
#  'pLEU_biomass1': (nan, 1.0),
#  'ARGINASE_RXN_m2': (0.3647764648815487, 0.04009903053619148),
#  'ARGINASE_RXN_m1': (nan, 1.0),
#  'FERRIC_CHELATE_REDUCTASE_RXN_c1': (nan, 1.0),
#  'FERRIC_CHELATE_REDUCTASE_RXN_c2': (nan, 1.0),
#  'TIGLYLCOA_HYDROXY_RXN_m2': (nan, 1.0),
#  'TIGLYLCOA_HYDROXY_RXN_m1': (nan, 1.0),
#  'CYSTEINE_AMINOTRANSFERASE_RXN_m2': (nan, 1.0),
#  'ILE_PROTON_vc2': (nan, 1.0),
#  'ILE_PROTON_vc1': (nan, 1.0),
#  'CYSTEINE_AMINOTRANSFERASE_RXN_m1': (nan, 1.0),
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p1': (-0.7355718631212239,
#   1.6162804994744276e-06),
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p2': (nan, 1.0),
#  'HISTOLDEHYD_RXN_p1': (nan, 1.0),
#  'L_CITRULLINE_pc1': (nan, 1.0),
#  'RXN_7800_p2': (nan, 1.0),
#  'RXN_7800_p1': (nan, 1.0),
#  '5_METHYL_THF_pc2': (nan, 1.0),
#  '5_METHYL_THF_pc1': (nan, 1.0),
#  'NADPHoxm_tx2': (nan, 1.0),
#  'NITRATE_PROTON_rev_vc1': (nan, 1.0),
#  'NITRATE_PROTON_rev_vc2': (nan, 1.0),
#  'OAA_SO4_mc1': (nan, 1.0),
#  'OAA_SO4_mc2': (nan, 1.0),
#  'THRESYN_RXN_p2': (nan, 1.0),
#  'THRESYN_RXN_p1': (-0.40538938037522837, 0.021345539095741387),
#  'CA2_rev_vc1': (nan, 1.0),
#  'PROTONATP_rev_vc1': (nan, 1.0),
#  'PROTONATP_rev_vc2': (nan, 1.0),
#  ...}

# %%
fout = open("Data/PPC_transcripts_fluxes_lightNotForced_constMaint_notAverage_ignoreComp_27_12_19.tsv","w")

fout.write("Rxn ID\treaction\tPCC\tp-value\tfluxes\n")
for rxn in PCCdict.keys():
    xlist = list()
    ylist = list()
    for i in range(1,6):
        xlist.append(modelDictNonCompartmentalized[i][str(rxn[:rxn.rindex("_")]+rxn[len(rxn)-1]).replace("_NADP","").replace("_NAD","")])
        ylist.append(totalTranscriptDict[i][rxn])
    fout.write(rxn+"\t"+leaf_model.reactions.get_by_id(rxn).reaction+"\t"+str(PCCdict[rxn][0])+"\t"+str(PCCdict[rxn][1])+"\t"+str(xlist)+"\n")
fout.close()

# %%
rxn = leaf_model.reactions.get_by_id(rxn)
rxn.genes
# Out:
# frozenset({<Gene Glyma.14G009600 at 0x7fa1d6394550>,
#            <Gene Glyma.02G304200 at 0x7fa1d6394590>,
#            <Gene Glyma.04G173400 at 0x7fa1d63945d0>,
#            <Gene Glyma.04G144300 at 0x7fa1d6394610>,
#            <Gene Glyma.19G068500 at 0x7fa1d6394650>,
#            <Gene Glyma.04G157000 at 0x7fa1d6394690>,
#            <Gene Glyma.03G190500 at 0x7fa1d63946d0>,
#            <Gene Glyma.19G190900 at 0x7fa1d6394710>,
#            <Gene Glyma.15G235300 at 0x7fa1d6394750>,
#            <Gene Glyma.06G208200 at 0x7fa1d6394790>,
#            <Gene Glyma.16G204600 at 0x7fa1d63947d0>,
#            <Gene Glyma.09G153900 at 0x7fa1d6394810>,
#            <Gene Glyma.15G207600 at 0x7fa1d6394850>})

# %% [markdown]
# ### Plot fluxes which show +ve correlation with transcript levels

# %%
rxnlist = ["2PGADEHYDRAT_RXN_c1"]

colordict = ["white","black","blue","green","red","cyan"]

for rxn in rxnlist:
    max_x = 0
    min_x = 0
    for i in range(1,6):
        xlist = list()
        ylist = list()
        for j in range(0,len(totalTranscriptDict[i][rxn])):
            xlist.append(modelDictNonCompartmentalized[i][rxn[:rxn.rindex("_")]+rxn[len(rxn)-1].replace("NADP","").replace("NAD","")])
            ylist.append(totalTranscriptDict[i][rxn][j])
        import matplotlib.pyplot as plt
        plt.scatter(xlist,ylist,color=colordict[i],label="Scenario "+str(i))
        if max_x<max(xlist):
            max_x = max(xlist)
        if min_x>min(xlist):
            min_x = max(xlist)
    plt.title(rxn)
    plt.xlabel("predicted flux")
    plt.ylabel("transcript abundance")
    plt.legend()
    if abs(min_x) > abs(max_x):
        temp = min_x
    else:
        temp = max_x
    plt.xlim(min_x-(temp*(10.0/100)),max_x+(temp*(10.0/100)))
    plt.savefig("Data/Plots_27_12_2019/"+rxn+".svg")
    plt.close()

# %% [markdown]
# ## References
# - Kannan, K., Wang, Y., Lang, M., Challa, G. S., Long, S. P., & Marshall-Colon, A. (2019). Combining gene network, metabolic and leaf-level models shows means to future-proof soybean photosynthesis under rising CO2. In Silico Plants, 1(1), 1–18. https://doi.org/10.1093/insilicoplants/diz008
# - Haile, F. J., & Higley, L. G. (2003). Changes in Soybean Gas-Exchange After Moisture Stress and Spider Mite Injury. Environmental Entomology, 32(3), 433–440. https://doi.org/10.1603/0046-225x-32.3.433
# - Turner, G. W., Cuthbertson, D. J., Voo, S. S., Settles, M. L., Grimes, H. D., & Lange, B. M. (2012). Experimental sink removal induces stress responses, including shifts in amino acid and phenylpropanoid metabolism, in soybean leaves. Planta, 235(5), 939–954. https://doi.org/10.1007/s00425-011-1551-4
# - Leakey, A. D. B., Xu, F., Gillespie, K. M., McGrath, J. M., Ainsworth, E. A., & Ort, D. R. (2009). Genomic basis for stimulated respiration by plants growing under elevated carbon dioxide. Proceedings of the National Academy of Sciences of the United States of America, 106(9), 3597–3602. https://doi.org/10.1073/pnas.0810955106
# - Weston, D. J., Karve, A. A., Gunter, L. E., Jawdy, S. S., Yang, X., Allen, S. M., & Wullschleger, S. D. (2011). Comparative physiology and transcriptional networks underlying the heat shock response in Populus trichocarpa, Arabidopsis thaliana and Glycine max. Plant, Cell and Environment, 34(9), 1488–1506. https://doi.org/10.1111/j.1365-3040.2011.02347.x
# - Bunce, J. (2019). Consistent Differences in Field Leaf Water-Use Efficiency among Soybean Cultivars. Plants, 8(5), 123. https://doi.org/10.3390/plants8050123
