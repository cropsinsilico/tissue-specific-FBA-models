# %% [markdown]
# # Does any transcript levels correlate with FBA-predicted metabolic fluxes?
#
# ## Introduction
#
# Transcriptomics dataset collected from multiple scenarios and published in [Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008) was provided from UoI-UC. FBA was used to predict metabolic fluxes under different scenarios and then transcript levels are compared to flux.

# %% [markdown]
# ## Processing transcript data

# %%
import pandas as pd
df = pd.read_csv("/home/sanu/Downloads/gmax_leaf_CO2_normExprn_1.txt",sep="\t")
# Out:
# /home/sanu/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (0,2,3,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df.columns) -17
# Out:
# 229

# %% [markdown]
# ### Seperating out different studies
#
# Data on light intensity (PPFD) during plant growth was avialable for 5 (of 8) studies. When \[CO2\] is not avilable, ambient levels were assumed. Where day-length is not mentioned, as assumption that daylength is 12h was assumed. In the case of studies involving biotic and abiotic treatments (other than high \[CO2\] treatments), only the WT/control data was used in this analysis.

# %%
amb_list = list(df.columns[0:17])
ele_list = list(df.columns[0:17])
for x in df.columns:
    if "Amb" in x:
        amb_list.append(x)
    elif "Ele" in x:
        ele_list.append(x)
    else:
        continue

budRemove_list = list(df.columns[0:17])+["GSM569808.CEL","GSM569809.CEL","GSM569810.CEL",
                                         "GSM569811.CEL","GSM569812.CEL","GSM569813.CEL",
                                         "GSM569814.CEL"]
heatShock_list = list(df.columns[0:17])+["GSM643115.CEL","GSM643116.CEL","GSM643117.CEL","GSM643118.CEL"]
mycInfect_list = list(df.columns[0:17])+["GSM1088939_Schaar_19_wt_c1_S.CEL",
                                         "GSM1088940_Schaar_20_wt_c2_S.CEL",
                                         "GSM1088954_Schaar_25_nts_c1_S.CEL",
                                         "GSM1088955_Schaar_26_nts_c2_S.CEL",
                                         "GSM1088956_Schaar_27_nts_c3_S.CEL"]

# %%
df_amb = df[amb_list]
df_ele = df[ele_list]
df_budRemove = df[budRemove_list]
df_heatShock = df[heatShock_list]
df_mycInfect = df[mycInfect_list]

# %% [markdown]
# ## Set up leaf model and add gene-protein-reaction (GPR) associations from PlantCyc

# %%
from cobra import io
from cobra.core import Metabolite
from cobra import flux_analysis
from IPython import display
import logging
logging.basicConfig()
logger = logging.getLogger('logger')

#import sbml file
fname = "/home/sanu/Documents/Scripts/git/plantcoremetabolism-model/PlantCoreMetabolism_v1_3_0.xml"
model = io.sbml.read_sbml_model(fname)
display.clear_output()

from sweetlovegroup.transform import fixModelCompatibilityIssueCobra015
model = fixModelCompatibilityIssueCobra015(model,fname)

# %%
len(model.reactions)
# Out:
# 868

# %%
len(model.metabolites)
# Out:
# 829

# %%
import pythoncyc
from Functions import *

soy = pythoncyc.select_organism("soy")

# %%
model = addGPR2Models(model,soy)
# Out:
# --------------
# This list of metabolic reactions are ignored
# ['RXN_9650_p', '2_KETO_ADIPATE_DEHYDROG_RXN_m', 'Phytol_biosynthesis_p', 'CYSTEINE_AMINOTRANSFERASE_RXN_m', 'GLYCINE_TRNA_LIGASE_RXN_c', 'RXN66_1_c', 'RXN_9648_p', 'RXN-9651', 'Plastidial_ATP_Synthase_p', 'GGPP_biosynthesis_p', 'RXN_9653_p', 'lycopene_biosynthesis_p', 'RXN_2141_p', 'SUCCINYL_COA_HYDROLASE_RXN_m', 'PROTON_ATPase_c', 'MDA_Fd_Ascorbate_p', 'MercaptoPyruvateSulfurtransferase_m', 'Phytol_degradation_p', 'RXN_9652_p', 'A_B_oxidation_x', 'unlProtHYPO_c', 'Mitochondrial_ATP_Synthase_m', 'IPP_biosynthesis_c', 'Mehler_Reaction_p', 'Beta_Oxidation_x', 'HMBPP_synthesis_p', 'OROTATE_REDUCTASE_NADH_RXN_p', 'Ferredoxin_Plastoquinone_Reductase_p', 'RXN_9651_p', 'NADPH_Dehydrogenase_p', 'Plastoquinol_Oxidase_p', 'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m', 'RXN_1781_v', 'PREPHENATE_DEHYDROGENASE_NADP_RXN_p', 'PREPHENATEDEHYDROG_RXN_p', 'MALEYLACETOACETATE_ISOMERASE_RXN_c', 'RXN_9654_p', 'LCYSDESULF_RXN_c', 'RXN_9958_NAD_m', 'HEXOKINASE_RXN_MANNOSE_c', 'PYRUVDEH_RXN_p', 'PYRUVDEH_RXN_m']
# --------------
# hexadecenoate_biosynthesis_p
# RXN_12486_c
# hexadecadienoate_biosynthesis_p
# Oleoyl_ACP_desaturase_p
# Octadecadienoyl_ACP_hydrolase_p
# 6PGLUCONDEHYDROG_RXN_c
# palmitoyl_ACP_desaturase_p
# Octadecadienoyl_ACP_desaturase_p
# RXN1G_368_p
# RXN1G_445_p
# palmitoleoyl_ACP_desaturase_p
# arachidate_biosynthesis_p
# hexadecadienoate_ACP_desaturase_p
# docosanoate_biosynthesis_p
# gadoleic_acid_biosynthesis_p
# Arachidoyl_ACP_desaturase_p
# hexadecatrienoate_biosynthesis_p
# LPG_biosynthesis_c
# RXN_6884_m
# 6PGLUCONDEHYDROG_RXN_p
# RXN_1826_p
# Octadecatrienoyl_ACP_hydrolase_p
# RXN490_3650_p

# %% [markdown]
# ## Modelling fluxes under different scenarios
#
# Create leaf model

# %%
########################################################
#This function was used to set up a C3 leaf diel model #
########################################################
def setupC3DielModel(core_model,transferMets,starch_sucrose_ratio=90.0/100):
    from cobra.core import Metabolite, Reaction
    import re

    #create two copies of model elements for day and night
    cobra_model2 = core_model.copy()
    for met in cobra_model2.metabolites:
        met.id = met.id+"1"
        met.compartment = met.compartment+"1"
    for rxn in cobra_model2.reactions:
        rxn.id = rxn.id+"1"

    cobra_model3 = core_model.copy()
    for met in cobra_model3.metabolites:
        met.id = met.id+"2"
        met.compartment = met.compartment+"2"
    for rxn in cobra_model3.reactions:
        rxn.id = rxn.id+"2"

    #merge the day and night model
    cobra_model = cobra_model2+cobra_model3
    for met in cobra_model3.metabolites:
        if not cobra_model.metabolites.__contains__(met.id):
            cobra_model.add_metabolites(met.copy())

    met1 = Metabolite("X_Phloem_contribution_t1",name="Phloem output during the day")
    cobra_model.reactions.get_by_id("Phloem_output_tx1").add_metabolites({met1:1})
    met2 = Metabolite("X_Phloem_contribution_t2",name="Phloem output during at night")
    cobra_model.reactions.get_by_id("Phloem_output_tx2").add_metabolites({met2:1})

    rxn = Reaction("diel_biomass")
    rxn.add_metabolites({met1:-3,met2:-1})
    rxn.lower_bound = 0
    rxn.upper_bound = 1000
    cobra_model.add_reaction(rxn)

    #Adding reactions to allow for day-night metabolite accumulations
    tmfile = open(transferMets,"r")
    tmset=set()
    for line in tmfile:
        tmset.add(line.replace("\n",""))

    for met in tmset:
        if met == "AMMONIUM_v" or met=="FRUCTAN_v":
            continue
        tempRxn = Reaction(met+"_dielTransfer")
        tempRxn.add_metabolites({cobra_model.metabolites.get_by_id(met+"1"):-1,cobra_model.metabolites.get_by_id(met+"2"):1})
        tempRxn.lower_bound=-1000
        if not ((met == "STARCH_p") or (met == "SUCROSE_v") or (met == "MAL_v") or (met == "aMAL_v") or (met == "NITRATE_v") or (met == "CIT_v") or (met == "aCIT_v") or (met == "PROTON_v")):
            tempRxn.lower_bound=0
        tempRxn.upper_bound=1000
        cobra_model.add_reaction(tempRxn)

    fractionMets=dict()
    for rxn in cobra_model.reactions:
        for met in rxn.metabolites.keys():
            prefix=""
            a=re.search("^a{1,3}",met.id)
            anion=""
            if a:
                anion=a.group(0)
                prefix=anion
            b=re.search("^b{1,3}",met.id)
            basic=""
            if b:
                basic=b.group(0)
                prefix=basic
            if ((not prefix == "") and met.compartment == "v1"):
                fractionMets[met]=prefix

    temp=cobra_model.copy()
    for met in fractionMets.keys():
        for rxn in met.reactions:
            if rxn.id.__contains__("_dielTransfer"):
                continue
            else:
                mainMet = met.id[len(fractionMets[met]):]
                coeff1 = temp.reactions.get_by_id(rxn.id).metabolites.get(temp.metabolites.get_by_id(mainMet))
                coeff2 = temp.reactions.get_by_id(rxn.id).metabolites.get(temp.metabolites.get_by_id(met.id))
                if not coeff1:
                    coeff1=0
                if not coeff2:
                    coeff2=0
                total = coeff1 + coeff2
                coeff1 = float(coeff1)/total
                coeff2 = float(coeff2)/total
                if cobra_model.reactions.has_id(met.id[0:len(met.id)-1]+"_dielTransfer"):
                    ub = temp.reactions.get_by_id(met.id[0:len(met.id)-1]+"_dielTransfer").upper_bound
                    lb = temp.reactions.get_by_id(met.id[0:len(met.id)-1]+"_dielTransfer").lower_bound
                    temp.reactions.get_by_id(met.id[0:len(met.id)-1]+"_dielTransfer").remove_from_model()
                    temp.reactions.get_by_id(mainMet[0:len(mainMet)-1]+"_dielTransfer").remove_from_model()
                    Reac = Reaction(mainMet[0:len(mainMet)-1]+"_dielTransfer",name=mainMet+"_dielTransfer")
                    Reac.add_metabolites({temp.metabolites.get_by_id(met.id[0:len(met.id)-1]+"1"):-coeff2,temp.metabolites.get_by_id(met.id[0:len(met.id)-1]+"2"):coeff2,temp.metabolites.get_by_id(mainMet[0:len(mainMet)-1]+"1"):-coeff1,temp.metabolites.get_by_id(mainMet[0:len(mainMet)-1]+"2"):coeff1})
                    Reac.lower_bound=lb
                    Reac.upper_bound=ub
                    temp.add_reaction(Reac)
                    print Reac.reaction
                break
    ####ADD CONSTRAINTS TO MODEL####
    cobra_model = temp.copy()

    #objective function
    cobra_model.reactions.get_by_id("diel_biomass").objective_coefficient=1
    #Leaves - light
    cobra_model.reactions.get_by_id("Sucrose_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("Sucrose_tx1").upper_bound=0
    cobra_model.reactions.get_by_id("GLC_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("GLC_tx1").upper_bound=0
    cobra_model.reactions.get_by_id("CO2_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("NH4_tx1").lower_bound=0
    cobra_model.reactions.get_by_id("NH4_tx1").upper_bound=0
    #Leaves - dark
    cobra_model.reactions.get_by_id("Sucrose_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("Sucrose_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("GLC_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("GLC_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("Photon_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("Photon_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("NH4_tx2").lower_bound=0
    cobra_model.reactions.get_by_id("NH4_tx2").upper_bound=0
    cobra_model.reactions.get_by_id("CO2_tx2").upper_bound=0

    #Set pG6P transporter to 0
    cobra_model.reactions.get_by_id("G6P_Pi_pc1").lower_bound=0
    cobra_model.reactions.get_by_id("G6P_Pi_pc1").upper_bound=0
    cobra_model.reactions.get_by_id("G6P_Pi_pc2").lower_bound=0
    cobra_model.reactions.get_by_id("G6P_Pi_pc2").upper_bound=0

    #Turn off PTOX
    cobra_model.reactions.get_by_id("Plastoquinol_Oxidase_p1").lower_bound=0
    cobra_model.reactions.get_by_id("Plastoquinol_Oxidase_p1").upper_bound=0

    #nitrate uptake constrain
    Nitrate_balance = Metabolite("Nitrate_bal_c", name = "Weights to balance nitrate uptake", compartment = "c1")
    cobra_model.reactions.get_by_id("Nitrate_ec1").add_metabolites({Nitrate_balance:-2})
    cobra_model.reactions.get_by_id("Nitrate_ec2").add_metabolites({Nitrate_balance:3})

    #Rubisco balance
    Rubisco_balance = Metabolite("rubisco_bal_p1", name = "Weights to balance RuBP carboxygenase oxygenase balance", compartment = "p1")
    cobra_model.reactions.get_by_id("RXN_961_p1").add_metabolites({Rubisco_balance:3})
    cobra_model.reactions.get_by_id("RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p1").add_metabolites({Rubisco_balance:-1})

    #generic ATPase and NADPH oxidase
    Maintenance_constraint = Metabolite("ATPase_NADPHoxidase_constraint_c1",name =  "ATPase_NADPHoxidase_constraint_c1", compartment = "c1")
    Maintenance_constraint2 = Metabolite("ATPase_NADPHoxidase_constraint_c2",name =  "ATPase_NADPHoxidase_constraint_c2", compartment = "c2")
    Maintenance_constraint3 = Metabolite("Light_dark_maintainence_constraint",name =  "Light_dark_maintainence_constraint", compartment = "c1")
    cobra_model.reactions.get_by_id("ATPase_tx1").add_metabolites({Maintenance_constraint:1,Maintenance_constraint3:1})
    cobra_model.reactions.get_by_id("ATPase_tx2").add_metabolites({Maintenance_constraint2:1,Maintenance_constraint3:-1})
    cobra_model.reactions.get_by_id("NADPHoxc_tx1").add_metabolites({Maintenance_constraint:-3})
    cobra_model.reactions.get_by_id("NADPHoxc_tx2").add_metabolites({Maintenance_constraint2:-3})
    cobra_model.reactions.get_by_id("NADPHoxm_tx1").add_metabolites({Maintenance_constraint:-3})
    cobra_model.reactions.get_by_id("NADPHoxm_tx2").add_metabolites({Maintenance_constraint2:-3})
    cobra_model.reactions.get_by_id("NADPHoxp_tx1").add_metabolites({Maintenance_constraint:-3})
    cobra_model.reactions.get_by_id("NADPHoxp_tx2").add_metabolites({Maintenance_constraint2:-3})

    ##constrain sucrose and starch storage
    Sucorse_starch_balance = Metabolite("sucrose_starch_bal_c", name = "Weights to balance sucrose-starch uptake", compartment = "c1")
    cobra_model.reactions.get_by_id("SUCROSE_v_dielTransfer").add_metabolites({Sucorse_starch_balance:-1*starch_sucrose_ratio})
    cobra_model.reactions.get_by_id("STARCH_p_dielTransfer").add_metabolites({Sucorse_starch_balance:1})

    #Plastid enolase was not detected in Arabidopsis mesophyll tissue
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p1").lower_bound=0
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p1").upper_bound=0
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p2").lower_bound=0
    cobra_model.reactions.get_by_id("2PGADEHYDRAT_RXN_p2").upper_bound=0

    #Setting chloroplastic NADPH dehydrogenase to 0  ((Yamamoto et al., 2011)
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p1").lower_bound=0
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p1").upper_bound=0
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p2").lower_bound=0
    cobra_model.reactions.get_by_id("NADPH_Dehydrogenase_p2").upper_bound=0

    #ATP_ADP_Pi constrained to 0 because while there is evidence for its existance, it does not carry flux during the day
    cobra_model.reactions.get_by_id("ATP_ADP_Pi_pc1").lower_bound = 0
    cobra_model.reactions.get_by_id("ATP_ADP_Pi_pc1").upper_bound = 0

    return cobra_model

# %%
leaf_model = model.copy()

from sweetlovegroup import transform
leaf_model = setupC3DielModel(leaf_model,"MetabolitesToTransfer.txt",starch_sucrose_ratio=5)

for rxn in leaf_model.reactions:
    if rxn.lower_bound==-1000:
        rxn.lower_bound=-2000
    if rxn.upper_bound==1000:
        rxn.upper_bound=2000

leaf_model.reactions.diel_biomass.objective_coefficient=1
sol = flux_analysis.parsimonious.pfba(leaf_model)
# Out:
# 0.5 CIT_v1 + 0.5 aCIT_v1 <=> 0.5 CIT_v2 + 0.5 aCIT_v2
# 0.7 MAL_v1 + 0.3 aMAL_v1 <=> 0.7 MAL_v2 + 0.3 aMAL_v2
# bHIS_v1 --> bHIS_v2

# %% [markdown]
# ### Scenario 1
#
# PPFD = 1500
# \[CO2\] = 400
# net CO2 uptake rate = 21.645569620253173 ([Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008))

# %%
PPFD = 1500
ATPase = (0.0049*PPFD) + 2.7851

from sweetlovegroup import analysis
temp = leaf_model.copy()
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 4
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 4
out_400 = analysis.estimateOutputFromNetCO2(temp,21.645569620253173)

leaf_model_400 = leaf_model.copy()
leaf_model_400.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_400.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
leaf_model_400.reactions.get_by_id("ATPase_tx1").lower_bound = 4
leaf_model_400.reactions.get_by_id("ATPase_tx1").upper_bound = 4
leaf_model_400.reactions.diel_biomass.lower_bound = out_400
leaf_model_400.reactions.diel_biomass.upper_bound = out_400
sol = flux_analysis.parsimonious.pfba(leaf_model_400)
print("Phloem output = ")
print(leaf_model_400.reactions.diel_biomass.flux)
# Out:
# 1500
# 4
# 21.6455696203
# Phloem output =
# 0.499446983252

# %%
import numpy as np


totalTranscript_400 = dict()
for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(df_amb.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(df_amb["Glyma2.0"]):
            #print gene
            if count==0:
                x = df_amb[df_amb["Glyma2.0"]==gene.id][df_amb.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = df_amb[df_amb["Glyma2.0"]==gene.id][df_amb.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_400[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 2
#
# PPFD = 1500
# \[CO2\] = 550
# net CO2 uptake rate = 24.43037974683546 ([Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008))

# %%
PPFD = 1500
ATPase = (0.0049*PPFD) + 2.7851

from sweetlovegroup import analysis
temp = leaf_model.copy()
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 4
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 4
out_550 = analysis.estimateOutputFromNetCO2(temp,24.43037974683546)

leaf_model_550 = leaf_model.copy()
leaf_model_550.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_550.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
leaf_model_550.reactions.get_by_id("ATPase_tx1").lower_bound = 4
leaf_model_550.reactions.get_by_id("ATPase_tx1").upper_bound = 4
leaf_model_550.reactions.diel_biomass.lower_bound = out_550
leaf_model_550.reactions.diel_biomass.upper_bound = out_550
sol = flux_analysis.parsimonious.pfba(leaf_model_550)
print("Phloem output = ")
print(leaf_model_550.reactions.diel_biomass.flux)
# Out:
# 1500
# 4
# 24.4303797468
# Phloem output =
# 0.567924348284

# %%
totalTranscript_550 = dict()
temp = df_ele

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_550[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 3
#
# PPFD = 400
# \[CO2\] = 400
# net CO2 uptake rate = 21.645569620253173 ([Kannan et al 2019](https://doi.org/10.1093/insilicoplants/diz008))

# %%
PPFD = 400
ATPase = (0.0049*PPFD) + 2.7851

from sweetlovegroup import analysis
temp = leaf_model.copy()
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 4
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 4
out_400 = analysis.estimateOutputFromNetCO2(temp,21.645569620253173)

leaf_model_budRemove = leaf_model.copy()
leaf_model_budRemove.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_budRemove.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
leaf_model_budRemove.reactions.get_by_id("ATPase_tx1").lower_bound = 4
leaf_model_budRemove.reactions.get_by_id("ATPase_tx1").upper_bound = 4
leaf_model_budRemove.reactions.diel_biomass.lower_bound = out_400
leaf_model_budRemove.reactions.diel_biomass.upper_bound = out_400
sol = flux_analysis.parsimonious.pfba(leaf_model_budRemove)
print("Phloem output = ")
print(leaf_model_budRemove.reactions.diel_biomass.flux)
# Out:
# 400
# 4
# 21.6455696203
# Phloem output =
# 0.499446983252

# %%
totalTranscript_budRemove = dict()
temp = df_budRemove

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_budRemove[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 4
#
# PPFD = 350
# \[CO2\] = 380
# net CO2 uptake rate = 12 (\[CO2\]=370) ([Haile nd Higley 2003](https://doi.org/10.1603/0046-225x-32.3.433))

# %%
PPFD = 400
ATPase = (0.0049*PPFD) + 2.7851

from sweetlovegroup import analysis
temp = leaf_model.copy()
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 4
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 4
out_370 = analysis.estimateOutputFromNetCO2(temp,12)

leaf_model_heatShock = leaf_model.copy()
leaf_model_heatShock.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_heatShock.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
leaf_model_heatShock.reactions.get_by_id("ATPase_tx1").lower_bound = 4
leaf_model_heatShock.reactions.get_by_id("ATPase_tx1").upper_bound = 4
leaf_model_heatShock.reactions.diel_biomass.lower_bound = out_370
leaf_model_heatShock.reactions.diel_biomass.upper_bound = out_370
sol = flux_analysis.parsimonious.pfba(leaf_model_heatShock)
print("Phloem output = ")
print(leaf_model_heatShock.reactions.diel_biomass.flux)
# Out:
# 400
# 4
# 12
# Phloem output =
# 0.262112136056

# %%
totalTranscript_heatShock = dict()
temp = df_heatShock

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_heatShock[rxn.id]=x[0]

# %% [markdown]
# ### Scenario 5
#
# PPFD = 200
# \[CO2\] = ? , assuming 390 based on publication date and CO2 data from the year (https://www.co2.earth/monthly-co2)
# net CO2 uptake rate = 4.693877551020307 (\[CO2\]=390 and assuming Ci = 0.72\*390 = 280.8) ([Bunce et al 2019](https://doi.org/10.1093/insilicoplants/diz008))

# %%
PPFD = 200
ATPase = (0.0049*PPFD) + 2.7851

from sweetlovegroup import analysis
temp = leaf_model.copy()
temp.reactions.get_by_id("Photon_tx1").lower_bound = 0
temp.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
temp.reactions.get_by_id("ATPase_tx1").lower_bound = 4
temp.reactions.get_by_id("ATPase_tx1").upper_bound = 4
out_370 = analysis.estimateOutputFromNetCO2(temp,4.693877551020307)

leaf_model_mycInfect = leaf_model.copy()
leaf_model_mycInfect.reactions.get_by_id("Photon_tx1").lower_bound = 0
leaf_model_mycInfect.reactions.get_by_id("Photon_tx1").upper_bound = PPFD
leaf_model_mycInfect.reactions.get_by_id("ATPase_tx1").lower_bound = 4
leaf_model_mycInfect.reactions.get_by_id("ATPase_tx1").upper_bound = 4
leaf_model_mycInfect.reactions.diel_biomass.lower_bound = out_370
leaf_model_mycInfect.reactions.diel_biomass.upper_bound = out_370
sol = flux_analysis.parsimonious.pfba(leaf_model_mycInfect)
print("Phloem output = ")
print(leaf_model_mycInfect.reactions.diel_biomass.flux)
# Out:
# 200
# 4
# 4.69387755102
# Phloem output =
# 0.084150928083

# %%
totalTranscript_mycInfect = dict()
temp = df_mycInfect

for rxn in leaf_model.reactions:
    #print rxn.id
    count = 0
    x = np.zeros((1,len(temp.columns[17:])))
    for gene in rxn.genes:
        if gene.id in list(temp["Glyma2.0"]):
            #print gene
            if count==0:
                x = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(x)>1:
                    for i in range(0,len(x)):
                        if i == 0:
                            x2 = x[i]
                        else:
                            x2 = x2 + x[i]
                    x = np.array([x2])
                count = count+1
            else:
                #print x
                y = temp[temp["Glyma2.0"]==gene.id][temp.columns[17:]].values
                if len(y)>1:
                    for i in range(0,len(y)):
                        if i==0:
                            y2 = y[i]
                        else:
                            y2 = y2 + y[i]
                    y = np.array([y2])
                x = x + y
                count = count+1
                #print x
    #print count
    totalTranscript_mycInfect[rxn.id]=x[0]

# %%
modelDict = dict()
modelDict[1] = leaf_model_400
modelDict[2] = leaf_model_550
modelDict[3] = leaf_model_budRemove
modelDict[4] = leaf_model_heatShock
modelDict[5] = leaf_model_mycInfect

totalTranscriptDict = dict()
totalTranscriptDict[1] = totalTranscript_400
totalTranscriptDict[2] = totalTranscript_550
totalTranscriptDict[3] = totalTranscript_budRemove
totalTranscriptDict[4] = totalTranscript_heatShock
totalTranscriptDict[5] = totalTranscript_mycInfect

# %%
PCCdict=dict()

# %%
from scipy.stats import pearsonr


for rxn in totalTranscriptDict[1].keys():
    xlist = list()
    ylist = list()
    for i in range(1,6):
        print rxn
        for j in range(1,len(totalTranscriptDict[i][rxn])):
            xlist.append(modelDict[i].reactions.get_by_id(rxn).flux)
            ylist.append(totalTranscriptDict[i][rxn][j])
    ans = pearsonr(xlist,ylist)  
    PCCdict[rxn]=ans
# Out:
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m2
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m2
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m2
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m2
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m2
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m1
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m1
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m1
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m1
# METHYLCROTONYL_COA_CARBOXYLASE_RXN_m1
# H_mc1
# H_mc1
# H_mc1
# H_mc1
# H_mc1
# H_mc2
# H_mc2
# H_mc2
# H_mc2
# H_mc2
# Protein_Processing_c1
# Protein_Processing_c1
# Protein_Processing_c1
# Protein_Processing_c1
# Protein_Processing_c1
# Protein_Processing_c2
# Protein_Processing_c2
# Protein_Processing_c2
# Protein_Processing_c2
# Protein_Processing_c2
# Starch_biomass1
# Starch_biomass1
# Starch_biomass1
# Starch_biomass1
# Starch_biomass1
# Mg_biomass1
# Mg_biomass1
# Mg_biomass1
# Mg_biomass1
# Mg_biomass1
# AMP_pc1
# AMP_pc1
# AMP_pc1
# AMP_pc1
# AMP_pc1
# AMP_pc2
# AMP_pc2
# AMP_pc2
# AMP_pc2
# AMP_pc2
# RXN_6884_m1
# RXN_6884_m1
# RXN_6884_m1
# RXN_6884_m1
# RXN_6884_m1
# RXN_6884_m2
# RXN_6884_m2
# RXN_6884_m2
# RXN_6884_m2
# RXN_6884_m2
# pTYR_biomass2
# pTYR_biomass2
# pTYR_biomass2
# pTYR_biomass2
# pTYR_biomass2
# pTYR_biomass1
# pTYR_biomass1
# pTYR_biomass1
# pTYR_biomass1
# pTYR_biomass1
# MDA_Fd_Ascorbate_p2
# MDA_Fd_Ascorbate_p2
# MDA_Fd_Ascorbate_p2
# MDA_Fd_Ascorbate_p2
# MDA_Fd_Ascorbate_p2
# MDA_Fd_Ascorbate_p1
# MDA_Fd_Ascorbate_p1
# MDA_Fd_Ascorbate_p1
# MDA_Fd_Ascorbate_p1
# MDA_Fd_Ascorbate_p1
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p2
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p2
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p2
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p2
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p2
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p1
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p1
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p1
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p1
# 2_PERIOD_3_PERIOD_1_PERIOD_23_RXN_p1
# RXN_6902_m1
# RXN_6902_m1
# RXN_6902_m1
# RXN_6902_m1
# RXN_6902_m1
# RXN_6902_m2
# RXN_6902_m2
# RXN_6902_m2
# RXN_6902_m2
# RXN_6902_m2
# pTHR_biomass2
# pTHR_biomass2
# pTHR_biomass2
# pTHR_biomass2
# pTHR_biomass2
# pTHR_biomass1
# pTHR_biomass1
# pTHR_biomass1
# pTHR_biomass1
# pTHR_biomass1
# ASPARAGHYD_RXN_c1
# ASPARAGHYD_RXN_c1
# ASPARAGHYD_RXN_c1
# ASPARAGHYD_RXN_c1
# ASPARAGHYD_RXN_c1
# ASPARAGHYD_RXN_c2
# ASPARAGHYD_RXN_c2
# ASPARAGHYD_RXN_c2
# ASPARAGHYD_RXN_c2
# ASPARAGHYD_RXN_c2
# HIS_ORNITHINE_mc2
# HIS_ORNITHINE_mc2
# HIS_ORNITHINE_mc2
# HIS_ORNITHINE_mc2
# HIS_ORNITHINE_mc2
# HIS_ORNITHINE_mc1
# HIS_ORNITHINE_mc1
# HIS_ORNITHINE_mc1
# HIS_ORNITHINE_mc1
# HIS_ORNITHINE_mc1
# RXN_11832_m1
# RXN_11832_m1
# RXN_11832_m1
# RXN_11832_m1
# RXN_11832_m1
# RXN_11832_m2
# RXN_11832_m2
# RXN_11832_m2
# RXN_11832_m2
# RXN_11832_m2
# RXN66_1_c1
# RXN66_1_c1
# RXN66_1_c1
# RXN66_1_c1
# RXN66_1_c1
# GLYOHMETRANS_RXN_c1
# GLYOHMETRANS_RXN_c1
# GLYOHMETRANS_RXN_c1
# GLYOHMETRANS_RXN_c1
# GLYOHMETRANS_RXN_c1
# RXN66_1_c2
# RXN66_1_c2
# RXN66_1_c2
# RXN66_1_c2
# RXN66_1_c2
# GLYOHMETRANS_RXN_c2
# GLYOHMETRANS_RXN_c2
# GLYOHMETRANS_RXN_c2
# GLYOHMETRANS_RXN_c2
# GLYOHMETRANS_RXN_c2
# GLUTAMINE_TRNA_LIGASE_RXN_c2
# GLUTAMINE_TRNA_LIGASE_RXN_c2
# GLUTAMINE_TRNA_LIGASE_RXN_c2
# GLUTAMINE_TRNA_LIGASE_RXN_c2
# GLUTAMINE_TRNA_LIGASE_RXN_c2
# GLUTAMINE_TRNA_LIGASE_RXN_c1
# GLUTAMINE_TRNA_LIGASE_RXN_c1
# GLUTAMINE_TRNA_LIGASE_RXN_c1
# GLUTAMINE_TRNA_LIGASE_RXN_c1
# GLUTAMINE_TRNA_LIGASE_RXN_c1
# LYS_pc2
# LYS_pc2
# LYS_pc2
# LYS_pc2
# LYS_pc2
# LYS_pc1
# LYS_pc1
# LYS_pc1
# LYS_pc1
# LYS_pc1
# FORMATETHFLIG_RXN_p1
# FORMATETHFLIG_RXN_p1
# FORMATETHFLIG_RXN_p1
# FORMATETHFLIG_RXN_p1
# FORMATETHFLIG_RXN_p1
# FORMATETHFLIG_RXN_p2
# FORMATETHFLIG_RXN_p2
# FORMATETHFLIG_RXN_p2
# FORMATETHFLIG_RXN_p2
# FORMATETHFLIG_RXN_p2
# Photon_tx1
# Photon_tx1
# Photon_tx1
# Photon_tx1
# Photon_tx1
# FUMARYLACETOACETASE_RXN_c2
# FUMARYLACETOACETASE_RXN_c2
# FUMARYLACETOACETASE_RXN_c2
# FUMARYLACETOACETASE_RXN_c2
# FUMARYLACETOACETASE_RXN_c2
# FUMARYLACETOACETASE_RXN_c1
# FUMARYLACETOACETASE_RXN_c1
# FUMARYLACETOACETASE_RXN_c1
# FUMARYLACETOACETASE_RXN_c1
# FUMARYLACETOACETASE_RXN_c1
# Photon_tx2
# Photon_tx2
# Photon_tx2
# Photon_tx2
# Photon_tx2
# Mg_biomass2
# Mg_biomass2
# Mg_biomass2
# Mg_biomass2
# Mg_biomass2
# ACSERLY_RXN_c2
# ACSERLY_RXN_c2
# ACSERLY_RXN_c2
# ACSERLY_RXN_c2
# ACSERLY_RXN_c2
# ACSERLY_RXN_c1
# ACSERLY_RXN_c1
# ACSERLY_RXN_c1
# ACSERLY_RXN_c1
# ACSERLY_RXN_c1
# Starch_biomass2
# Starch_biomass2
# Starch_biomass2
# Starch_biomass2
# Starch_biomass2
# TRP_PROTON_vc1
# TRP_PROTON_vc1
# TRP_PROTON_vc1
# TRP_PROTON_vc1
# TRP_PROTON_vc1
# RXN_9958_NAD_m1
# RXN_9958_NAD_m1
# RXN_9958_NAD_m1
# RXN_9958_NAD_m1
# RXN_9958_NAD_m1
# TRP_PROTON_vc2
# TRP_PROTON_vc2
# TRP_PROTON_vc2
# TRP_PROTON_vc2
# TRP_PROTON_vc2
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c1
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c1
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c1
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c1
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c1
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c2
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c2
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c2
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c2
# 2_AMINOADIPATE_AMINOTRANSFERASE_RXN_c2
# O2_tx1
# O2_tx1
# O2_tx1
# O2_tx1
# O2_tx1
# O2_tx2
# O2_tx2
# O2_tx2
# O2_tx2
# O2_tx2
# RXN_9958_NAD_m2
# RXN_9958_NAD_m2
# RXN_9958_NAD_m2
# RXN_9958_NAD_m2
# RXN_9958_NAD_m2
# PRPPAMIDOTRANS_RXN_p1
# PRPPAMIDOTRANS_RXN_p1
# PRPPAMIDOTRANS_RXN_p1
# PRPPAMIDOTRANS_RXN_p1
# PRPPAMIDOTRANS_RXN_p1
# PRPPAMIDOTRANS_RXN_p2
# PRPPAMIDOTRANS_RXN_p2
# PRPPAMIDOTRANS_RXN_p2
# PRPPAMIDOTRANS_RXN_p2
# PRPPAMIDOTRANS_RXN_p2
# 3_ISOPROPYLMALDEHYDROG_RXN_p2
# 3_ISOPROPYLMALDEHYDROG_RXN_p2
# 3_ISOPROPYLMALDEHYDROG_RXN_p2
# 3_ISOPROPYLMALDEHYDROG_RXN_p2
# 3_ISOPROPYLMALDEHYDROG_RXN_p2
# THREDEHYD_RXN_p2
# THREDEHYD_RXN_p2
# THREDEHYD_RXN_p2
# THREDEHYD_RXN_p2
# THREDEHYD_RXN_p2
# THREDEHYD_RXN_p1
# THREDEHYD_RXN_p1
# THREDEHYD_RXN_p1
# THREDEHYD_RXN_p1
# THREDEHYD_RXN_p1
# DUMP_pc1
# DUMP_pc1
# DUMP_pc1
# DUMP_pc1
# DUMP_pc1
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m2
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m2
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m2
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m2
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m2
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m1
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m1
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m1
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m1
# 3_HYDROXYISOBUTYRYL_COA_HYDROLASE_RXN_m1
# INORGPYROPHOSPHAT_RXN_p1
# INORGPYROPHOSPHAT_RXN_p1
# INORGPYROPHOSPHAT_RXN_p1
# INORGPYROPHOSPHAT_RXN_p1
# INORGPYROPHOSPHAT_RXN_p1
# INORGPYROPHOSPHAT_RXN_p2
# INORGPYROPHOSPHAT_RXN_p2
# INORGPYROPHOSPHAT_RXN_p2
# INORGPYROPHOSPHAT_RXN_p2
# INORGPYROPHOSPHAT_RXN_p2
# H_pc1
# H_pc1
# H_pc1
# H_pc1
# H_pc1
# H_pc2
# H_pc2
# H_pc2
# H_pc2
# H_pc2
# pARG_biomass1
# pARG_biomass1
# pARG_biomass1
# pARG_biomass1
# pARG_biomass1
# pARG_biomass2
# pARG_biomass2
# pARG_biomass2
# pARG_biomass2
# pARG_biomass2
# RXN_9633_p2
# RXN_9633_p2
# RXN_9633_p2
# RXN_9633_p2
# RXN_9633_p2
# LYS_PROTON_vc2
# LYS_PROTON_vc2
# LYS_PROTON_vc2
# LYS_PROTON_vc2
# LYS_PROTON_vc2
# LYS_PROTON_vc1
# LYS_PROTON_vc1
# LYS_PROTON_vc1
# LYS_PROTON_vc1
# LYS_PROTON_vc1
# DIHYDROXYMETVALDEHYDRAT_RXN_p1
# DIHYDROXYMETVALDEHYDRAT_RXN_p1
# DIHYDROXYMETVALDEHYDRAT_RXN_p1
# DIHYDROXYMETVALDEHYDRAT_RXN_p1
# DIHYDROXYMETVALDEHYDRAT_RXN_p1
# PRIBFAICARPISOM_RXN_p1
# PRIBFAICARPISOM_RXN_p1
# PRIBFAICARPISOM_RXN_p1
# PRIBFAICARPISOM_RXN_p1
# PRIBFAICARPISOM_RXN_p1
# NH4_tx2
# NH4_tx2
# NH4_tx2
# NH4_tx2
# NH4_tx2
# sALA_biomass2
# sALA_biomass2
# sALA_biomass2
# sALA_biomass2
# sALA_biomass2
# sALA_biomass1
# sALA_biomass1
# sALA_biomass1
# sALA_biomass1
# sALA_biomass1
# RXN_1841_v1
# RXN_1841_v1
# RXN_1841_v1
# RXN_1841_v1
# RXN_1841_v1
# MALSYN_RXN_x2
# MALSYN_RXN_x2
# MALSYN_RXN_x2
# MALSYN_RXN_x2
# MALSYN_RXN_x2
# GLY_pc1
# GLY_pc1
# GLY_pc1
# GLY_pc1
# GLY_pc1
# GLY_pc2
# GLY_pc2
# GLY_pc2
# GLY_pc2
# GLY_pc2
# RXN0_5330_NADP_c2
# RXN0_5330_NADP_c2
# RXN0_5330_NADP_c2
# RXN0_5330_NADP_c2
# RXN0_5330_NADP_c2
# CO2_mc2
# CO2_mc2
# CO2_mc2
# CO2_mc2
# CO2_mc2
# RXN_15130_p1
# RXN_15130_p1
# RXN_15130_p1
# RXN_15130_p1
# RXN_15130_p1
# RXN_6383_x2
# RXN_6383_x2
# RXN_6383_x2
# RXN_6383_x2
# RXN_6383_x2
# RXN_6383_x1
# RXN_6383_x1
# RXN_6383_x1
# RXN_6383_x1
# RXN_6383_x1
# RIBULP3EPIM_RXN_p1
# RIBULP3EPIM_RXN_p1
# RIBULP3EPIM_RXN_p1
# RIBULP3EPIM_RXN_p1
# RIBULP3EPIM_RXN_p1
# RIBULP3EPIM_RXN_p2
# RIBULP3EPIM_RXN_p2
# RIBULP3EPIM_RXN_p2
# RIBULP3EPIM_RXN_p2
# RIBULP3EPIM_RXN_p2
# CYS_PROTON_rev_vc1
# CYS_PROTON_rev_vc1
# CYS_PROTON_rev_vc1
# CYS_PROTON_rev_vc1
# CYS_PROTON_rev_vc1
# CYS_PROTON_rev_vc2
# CYS_PROTON_rev_vc2
# CYS_PROTON_rev_vc2
# CYS_PROTON_rev_vc2
# CYS_PROTON_rev_vc2
# 2KG_MAL_mc2
# 2KG_MAL_mc2
# 2KG_MAL_mc2
# 2KG_MAL_mc2
# 2KG_MAL_mc2
# ASPAMINOTRANS_RXN_c1
# ASPAMINOTRANS_RXN_c1
# ASPAMINOTRANS_RXN_c1
# ASPAMINOTRANS_RXN_c1
# ASPAMINOTRANS_RXN_c1
# ACONITATEHYDR_RXN_c1
# ACONITATEHYDR_RXN_c1
# ACONITATEHYDR_RXN_c1
# ACONITATEHYDR_RXN_c1
# ACONITATEHYDR_RXN_c1
# ACONITATEHYDR_RXN_c2
# ACONITATEHYDR_RXN_c2
# ACONITATEHYDR_RXN_c2
# ACONITATEHYDR_RXN_c2
# ACONITATEHYDR_RXN_c2
# ASPAMINOTRANS_RXN_c2
# ASPAMINOTRANS_RXN_c2
# ASPAMINOTRANS_RXN_c2
# ASPAMINOTRANS_RXN_c2
# ASPAMINOTRANS_RXN_c2
# THREO_DS_ISO_CITRATE_xc2
# THREO_DS_ISO_CITRATE_xc2
# THREO_DS_ISO_CITRATE_xc2
# THREO_DS_ISO_CITRATE_xc2
# THREO_DS_ISO_CITRATE_xc2
# THREO_DS_ISO_CITRATE_xc1
# THREO_DS_ISO_CITRATE_xc1
# THREO_DS_ISO_CITRATE_xc1
# THREO_DS_ISO_CITRATE_xc1
# THREO_DS_ISO_CITRATE_xc1
# NADPHoxm_tx1
# NADPHoxm_tx1
# NADPHoxm_tx1
# NADPHoxm_tx1
# NADPHoxm_tx1
# PEPCARBOXYKIN_RXN_c1
# PEPCARBOXYKIN_RXN_c1
# PEPCARBOXYKIN_RXN_c1
# PEPCARBOXYKIN_RXN_c1
# PEPCARBOXYKIN_RXN_c1
# PEPCARBOXYKIN_RXN_c2
# PEPCARBOXYKIN_RXN_c2
# PEPCARBOXYKIN_RXN_c2
# PEPCARBOXYKIN_RXN_c2
# PEPCARBOXYKIN_RXN_c2
# ARG_pc2
# ARG_pc2
# ARG_pc2
# ARG_pc2
# ARG_pc2
# O2_xc1
# O2_xc1
# O2_xc1
# O2_xc1
# O2_xc1
# 6PGLUCONDEHYDROG_RXN_c1
# 6PGLUCONDEHYDROG_RXN_c1
# 6PGLUCONDEHYDROG_RXN_c1
# 6PGLUCONDEHYDROG_RXN_c1
# 6PGLUCONDEHYDROG_RXN_c1
# PYRUVDEH_RXN_p2
# PYRUVDEH_RXN_p2
# PYRUVDEH_RXN_p2
# PYRUVDEH_RXN_p2
# PYRUVDEH_RXN_p2
# PYRUVDEH_RXN_p1
# PYRUVDEH_RXN_p1
# PYRUVDEH_RXN_p1
# PYRUVDEH_RXN_p1
# PYRUVDEH_RXN_p1
# sMET_biomass1
# sMET_biomass1
# sMET_biomass1
# sMET_biomass1
# sMET_biomass1
# MANNPGUANYLTRANGDP_RXN_c2
# MANNPGUANYLTRANGDP_RXN_c2
# MANNPGUANYLTRANGDP_RXN_c2
# MANNPGUANYLTRANGDP_RXN_c2
# MANNPGUANYLTRANGDP_RXN_c2
# MANNPGUANYLTRANGDP_RXN_c1
# MANNPGUANYLTRANGDP_RXN_c1
# MANNPGUANYLTRANGDP_RXN_c1
# MANNPGUANYLTRANGDP_RXN_c1
# MANNPGUANYLTRANGDP_RXN_c1
# sMET_biomass2
# sMET_biomass2
# sMET_biomass2
# sMET_biomass2
# sMET_biomass2
# GAP_Pi_pc1
# GAP_Pi_pc1
# GAP_Pi_pc1
# GAP_Pi_pc1
# GAP_Pi_pc1
# GAP_Pi_pc2
# GAP_Pi_pc2
# GAP_Pi_pc2
# GAP_Pi_pc2
# GAP_Pi_pc2
# PRAISOM_RXN_p1
# PRAISOM_RXN_p1
# PRAISOM_RXN_p1
# PRAISOM_RXN_p1
# PRAISOM_RXN_p1
# sTHR_biomass1
# sTHR_biomass1
# sTHR_biomass1
# sTHR_biomass1
# sTHR_biomass1
# sTHR_biomass2
# sTHR_biomass2
# sTHR_biomass2
# sTHR_biomass2
# sTHR_biomass2
# GCVMULTI_RXN_m1
# GCVMULTI_RXN_m1
# GCVMULTI_RXN_m1
# GCVMULTI_RXN_m1
# GCVMULTI_RXN_m1
# GCVMULTI_RXN_m2
# GCVMULTI_RXN_m2
# GCVMULTI_RXN_m2
# GCVMULTI_RXN_m2
# GCVMULTI_RXN_m2
# 1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2
# 1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2
# 1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2
# 1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2
# 1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2
# hexadecadienoate_biosynthesis_p1
# hexadecadienoate_biosynthesis_p1
# hexadecadienoate_biosynthesis_p1
# hexadecadienoate_biosynthesis_p1
# hexadecadienoate_biosynthesis_p1
# ASNSYNA_RXN_c2
# ASNSYNA_RXN_c2
# ASNSYNA_RXN_c2
# ASNSYNA_RXN_c2
# ASNSYNA_RXN_c2
# CYSPH_RXN_p1
# CYSPH_RXN_p1
# CYSPH_RXN_p1
# CYSPH_RXN_p1
# CYSPH_RXN_p1
# CYSPH_RXN_p2
# CYSPH_RXN_p2
# CYSPH_RXN_p2
# CYSPH_RXN_p2
# CYSPH_RXN_p2
# ADPREDUCT_RXN_p2
# ADPREDUCT_RXN_p2
# ADPREDUCT_RXN_p2
# ADPREDUCT_RXN_p2
# ADPREDUCT_RXN_p2
# ADPREDUCT_RXN_p1
# ADPREDUCT_RXN_p1
# ADPREDUCT_RXN_p1
# ADPREDUCT_RXN_p1
# ADPREDUCT_RXN_p1
# L_ASCORBATE_PEROXIDASE_RXN_m1
# L_ASCORBATE_PEROXIDASE_RXN_m1
# L_ASCORBATE_PEROXIDASE_RXN_m1
# L_ASCORBATE_PEROXIDASE_RXN_m1
# L_ASCORBATE_PEROXIDASE_RXN_m1
# L_ASCORBATE_PEROXIDASE_RXN_m2
# L_ASCORBATE_PEROXIDASE_RXN_m2
# L_ASCORBATE_PEROXIDASE_RXN_m2
# L_ASCORBATE_PEROXIDASE_RXN_m2
# L_ASCORBATE_PEROXIDASE_RXN_m2
# TYR_PROTON_rev_vc2
# TYR_PROTON_rev_vc2
# TYR_PROTON_rev_vc2
# TYR_PROTON_rev_vc2
# TYR_PROTON_rev_vc2
# TYR_PROTON_rev_vc1
# TYR_PROTON_rev_vc1
# TYR_PROTON_rev_vc1
# TYR_PROTON_rev_vc1
# TYR_PROTON_rev_vc1
# pGLU_biomass2
# pGLU_biomass2
# pGLU_biomass2
# pGLU_biomass2
# pGLU_biomass2
# pGLU_biomass1
# pGLU_biomass1
# pGLU_biomass1
# pGLU_biomass1
# pGLU_biomass1
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p1
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p1
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p1
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p1
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p1
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p2
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p2
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p2
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p2
# ACETYL_COA_CARBOXYLTRANSFER_RXN_p2
# NADH_DEHYDROG_A_RXN_mi2
# NADH_DEHYDROG_A_RXN_mi2
# NADH_DEHYDROG_A_RXN_mi2
# NADH_DEHYDROG_A_RXN_mi2
# NADH_DEHYDROG_A_RXN_mi2
# NADH_DEHYDROG_A_RXN_mi1
# NADH_DEHYDROG_A_RXN_mi1
# NADH_DEHYDROG_A_RXN_mi1
# NADH_DEHYDROG_A_RXN_mi1
# NADH_DEHYDROG_A_RXN_mi1
# ACSERLY_RXN_p2
# ACSERLY_RXN_p2
# ACSERLY_RXN_p2
# ACSERLY_RXN_p2
# ACSERLY_RXN_p2
# ACSERLY_RXN_p1
# ACSERLY_RXN_p1
# ACSERLY_RXN_p1
# ACSERLY_RXN_p1
# ACSERLY_RXN_p1
# 10_FORMYL_THF_pc1
# 10_FORMYL_THF_pc1
# 10_FORMYL_THF_pc1
# 10_FORMYL_THF_pc1
# 10_FORMYL_THF_pc1
# GGPP_biosynthesis_p1
# GGPP_biosynthesis_p1
# GGPP_biosynthesis_p1
# GGPP_biosynthesis_p1
# GGPP_biosynthesis_p1
# GGPP_biosynthesis_p2
# GGPP_biosynthesis_p2
# GGPP_biosynthesis_p2
# GGPP_biosynthesis_p2
# GGPP_biosynthesis_p2
# 10_FORMYL_THF_pc2
# 10_FORMYL_THF_pc2
# 10_FORMYL_THF_pc2
# 10_FORMYL_THF_pc2
# 10_FORMYL_THF_pc2
# ADP_pc2
# ADP_pc2
# ADP_pc2
# ADP_pc2
# ADP_pc2
# ADP_pc1
# ADP_pc1
# ADP_pc1
# ADP_pc1
# ADP_pc1
# pVAL_biomass2
# pVAL_biomass2
# pVAL_biomass2
# pVAL_biomass2
# pVAL_biomass2
# pVAL_biomass1
# pVAL_biomass1
# pVAL_biomass1
# pVAL_biomass1
# pVAL_biomass1
# Mitochondrial_ATP_Synthase_m1
# Mitochondrial_ATP_Synthase_m1
# Mitochondrial_ATP_Synthase_m1
# Mitochondrial_ATP_Synthase_m1
# Mitochondrial_ATP_Synthase_m1
# Mitochondrial_ATP_Synthase_m2
# Mitochondrial_ATP_Synthase_m2
# Mitochondrial_ATP_Synthase_m2
# Mitochondrial_ATP_Synthase_m2
# Mitochondrial_ATP_Synthase_m2
# LPG_biosynthesis_c2
# LPG_biosynthesis_c2
# LPG_biosynthesis_c2
# LPG_biosynthesis_c2
# LPG_biosynthesis_c2
# LPG_biosynthesis_c1
# LPG_biosynthesis_c1
# LPG_biosynthesis_c1
# LPG_biosynthesis_c1
# LPG_biosynthesis_c1
# GART_RXN_p1
# GART_RXN_p1
# GART_RXN_p1
# GART_RXN_p1
# GART_RXN_p1
# GART_RXN_p2
# GART_RXN_p2
# GART_RXN_p2
# GART_RXN_p2
# GART_RXN_p2
# MALONYL_COA_ACP_TRANSACYL_RXN_p2
# MALONYL_COA_ACP_TRANSACYL_RXN_p2
# MALONYL_COA_ACP_TRANSACYL_RXN_p2
# MALONYL_COA_ACP_TRANSACYL_RXN_p2
# MALONYL_COA_ACP_TRANSACYL_RXN_p2
# MALONYL_COA_ACP_TRANSACYL_RXN_p1
# MALONYL_COA_ACP_TRANSACYL_RXN_p1
# MALONYL_COA_ACP_TRANSACYL_RXN_p1
# MALONYL_COA_ACP_TRANSACYL_RXN_p1
# MALONYL_COA_ACP_TRANSACYL_RXN_p1
# AIRCARBOXY_RXN_p2
# AIRCARBOXY_RXN_p2
# AIRCARBOXY_RXN_p2
# AIRCARBOXY_RXN_p2
# AIRCARBOXY_RXN_p2
# AIRCARBOXY_RXN_p1
# AIRCARBOXY_RXN_p1
# AIRCARBOXY_RXN_p1
# AIRCARBOXY_RXN_p1
# AIRCARBOXY_RXN_p1
# Oleoyl_ACP_desaturase_p1
# Oleoyl_ACP_desaturase_p1
# Oleoyl_ACP_desaturase_p1
# Oleoyl_ACP_desaturase_p1
# Oleoyl_ACP_desaturase_p1
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x1
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x1
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x1
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x1
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x1
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x2
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x2
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x2
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x2
# GLUTACONYL_COA_DECARBOXYLASE_RXN_x2
# Oleoyl_ACP_desaturase_p2
# Oleoyl_ACP_desaturase_p2
# Oleoyl_ACP_desaturase_p2
# Oleoyl_ACP_desaturase_p2
# Oleoyl_ACP_desaturase_p2
# ADENOSYLHOMOCYSTEINASE_RXN_c1
# ADENOSYLHOMOCYSTEINASE_RXN_c1
# ADENOSYLHOMOCYSTEINASE_RXN_c1
# ADENOSYLHOMOCYSTEINASE_RXN_c1
# ADENOSYLHOMOCYSTEINASE_RXN_c1
# ADENOSYLHOMOCYSTEINASE_RXN_c2
# ADENOSYLHOMOCYSTEINASE_RXN_c2
# ADENOSYLHOMOCYSTEINASE_RXN_c2
# ADENOSYLHOMOCYSTEINASE_RXN_c2
# ADENOSYLHOMOCYSTEINASE_RXN_c2
# FORMATE_pc1
# FORMATE_pc1
# FORMATE_pc1
# FORMATE_pc1
# FORMATE_pc1
# FORMATE_pc2
# FORMATE_pc2
# FORMATE_pc2
# FORMATE_pc2
# FORMATE_pc2
# GLUCURONOKINASE_RXN_c1
# GLUCURONOKINASE_RXN_c1
# GLUCURONOKINASE_RXN_c1
# GLUCURONOKINASE_RXN_c1
# GLUCURONOKINASE_RXN_c1
# GLUCURONOKINASE_RXN_c2
# GLUCURONOKINASE_RXN_c2
# GLUCURONOKINASE_RXN_c2
# GLUCURONOKINASE_RXN_c2
# GLUCURONOKINASE_RXN_c2
# DUDPKIN_RXN_p1
# DUDPKIN_RXN_p1
# DUDPKIN_RXN_p1
# DUDPKIN_RXN_p1
# DUDPKIN_RXN_p1
# DUDPKIN_RXN_p2
# DUDPKIN_RXN_p2
# DUDPKIN_RXN_p2
# DUDPKIN_RXN_p2
# DUDPKIN_RXN_p2
# THR_PROTON_rev_vc2
# THR_PROTON_rev_vc2
# THR_PROTON_rev_vc2
# THR_PROTON_rev_vc2
# THR_PROTON_rev_vc2
# THR_PROTON_rev_vc1
# THR_PROTON_rev_vc1
# THR_PROTON_rev_vc1
# THR_PROTON_rev_vc1
# THR_PROTON_rev_vc1
# PEPDEPHOS_RXN_p1
# PEPDEPHOS_RXN_p1
# PEPDEPHOS_RXN_p1
# PEPDEPHOS_RXN_p1
# PEPDEPHOS_RXN_p1
# PEPDEPHOS_RXN_p2
# PEPDEPHOS_RXN_p2
# PEPDEPHOS_RXN_p2
# PEPDEPHOS_RXN_p2
# PEPDEPHOS_RXN_p2
# ORNCARBAMTRANSFER_RXN_p1
# ORNCARBAMTRANSFER_RXN_p1
# ORNCARBAMTRANSFER_RXN_p1
# ORNCARBAMTRANSFER_RXN_p1
# ORNCARBAMTRANSFER_RXN_p1
# L_ALPHA_ALANINE_PROTON_vc1
# L_ALPHA_ALANINE_PROTON_vc1
# L_ALPHA_ALANINE_PROTON_vc1
# L_ALPHA_ALANINE_PROTON_vc1
# L_ALPHA_ALANINE_PROTON_vc1
# SUC_ISOCITRATE_mc2
# SUC_ISOCITRATE_mc2
# SUC_ISOCITRATE_mc2
# SUC_ISOCITRATE_mc2
# SUC_ISOCITRATE_mc2
# SUC_ISOCITRATE_mc1
# SUC_ISOCITRATE_mc1
# SUC_ISOCITRATE_mc1
# SUC_ISOCITRATE_mc1
# SUC_ISOCITRATE_mc1
# H2O_ec2
# H2O_ec2
# H2O_ec2
# H2O_ec2
# H2O_ec2
# GAPOXNPHOSPHN_RXN_c2
# GAPOXNPHOSPHN_RXN_c2
# GAPOXNPHOSPHN_RXN_c2
# GAPOXNPHOSPHN_RXN_c2
# GAPOXNPHOSPHN_RXN_c2
# RXN0_5330_NAD_mi1
# RXN0_5330_NAD_mi1
# RXN0_5330_NAD_mi1
# RXN0_5330_NAD_mi1
# RXN0_5330_NAD_mi1
# RXN0_5330_NAD_mi2
# RXN0_5330_NAD_mi2
# RXN0_5330_NAD_mi2
# RXN0_5330_NAD_mi2
# RXN0_5330_NAD_mi2
# ISOCITDEH_RXN_x1
# ISOCITDEH_RXN_x1
# ISOCITDEH_RXN_x1
# ISOCITDEH_RXN_x1
# ISOCITDEH_RXN_x1
# ISOCITDEH_RXN_x2
# ISOCITDEH_RXN_x2
# ISOCITDEH_RXN_x2
# ISOCITDEH_RXN_x2
# ISOCITDEH_RXN_x2
# NH4_ec1
# NH4_ec1
# NH4_ec1
# NH4_ec1
# NH4_ec1
# NH4_ec2
# NH4_ec2
# NH4_ec2
# NH4_ec2
# NH4_ec2
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m1
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m1
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m1
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m1
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m1
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m2
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m2
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m2
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m2
# 2KETO_4METHYL_PENTANOATE_DEHYDROG_RXN_m2
# HOMOCYSMETB12_RXN_c1
# HOMOCYSMETB12_RXN_c1
# HOMOCYSMETB12_RXN_c1
# HOMOCYSMETB12_RXN_c1
# HOMOCYSMETB12_RXN_c1
# 2_KETO_ADIPATE_DEHYDROG_RXN_m1
# 2_KETO_ADIPATE_DEHYDROG_RXN_m1
# 2_KETO_ADIPATE_DEHYDROG_RXN_m1
# 2_KETO_ADIPATE_DEHYDROG_RXN_m1
# 2_KETO_ADIPATE_DEHYDROG_RXN_m1
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1
# 1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1
# GLUCOKIN_RXN_p1
# GLUCOKIN_RXN_p1
# GLUCOKIN_RXN_p1
# GLUCOKIN_RXN_p1
# GLUCOKIN_RXN_p1
# LEUCINE_TRNA_LIGASE_RXN_c1
# LEUCINE_TRNA_LIGASE_RXN_c1
# LEUCINE_TRNA_LIGASE_RXN_c1
# LEUCINE_TRNA_LIGASE_RXN_c1
# LEUCINE_TRNA_LIGASE_RXN_c1
# LEUCINE_TRNA_LIGASE_RXN_c2
# LEUCINE_TRNA_LIGASE_RXN_c2
# LEUCINE_TRNA_LIGASE_RXN_c2
# LEUCINE_TRNA_LIGASE_RXN_c2
# LEUCINE_TRNA_LIGASE_RXN_c2
# GLUCOKIN_RXN_p2
# GLUCOKIN_RXN_p2
# GLUCOKIN_RXN_p2
# GLUCOKIN_RXN_p2
# GLUCOKIN_RXN_p2
# RXN_3523_p2
# RXN_3523_p2
# RXN_3523_p2
# RXN_3523_p2
# RXN_3523_p2
# RXN_3523_p1
# RXN_3523_p1
# RXN_3523_p1
# RXN_3523_p1
# RXN_3523_p1
# RXN_9549_p1
# RXN_9549_p1
# RXN_9549_p1
# RXN_9549_p1
# RXN_9549_p1
# RXN_9549_p2
# RXN_9549_p2
# RXN_9549_p2
# RXN_9549_p2
# RXN_9549_p2
# CHORISMATEMUT_RXN_p2
# CHORISMATEMUT_RXN_p2
# CHORISMATEMUT_RXN_p2
# CHORISMATEMUT_RXN_p2
# CHORISMATEMUT_RXN_p2
# CHORISMATEMUT_RXN_p1
# CHORISMATEMUT_RXN_p1
# CHORISMATEMUT_RXN_p1
# CHORISMATEMUT_RXN_p1
# CHORISMATEMUT_RXN_p1
# GLUTAMIDOTRANS_RXN_p1
# GLUTAMIDOTRANS_RXN_p1
# GLUTAMIDOTRANS_RXN_p1
# GLUTAMIDOTRANS_RXN_p1
# GLUTAMIDOTRANS_RXN_p1
# GLUTAMIDOTRANS_RXN_p2
# GLUTAMIDOTRANS_RXN_p2
# GLUTAMIDOTRANS_RXN_p2
# GLUTAMIDOTRANS_RXN_p2
# GLUTAMIDOTRANS_RXN_p2
# ACETOLACTSYN_RXN_p2
# ACETOLACTSYN_RXN_p2
# ACETOLACTSYN_RXN_p2
# ACETOLACTSYN_RXN_p2
# ACETOLACTSYN_RXN_p2
# RXN_9659_p1
# RXN_9659_p1
# RXN_9659_p1
# RXN_9659_p1
# RXN_9659_p1
# RXN_9659_p2
# RXN_9659_p2
# RXN_9659_p2
# RXN_9659_p2
# RXN_9659_p2
# HIS_PROTON_vc2
# HIS_PROTON_vc2
# HIS_PROTON_vc2
# HIS_PROTON_vc2
# HIS_PROTON_vc2
# HIS_PROTON_vc1
# HIS_PROTON_vc1
# HIS_PROTON_vc1
# HIS_PROTON_vc1
# HIS_PROTON_vc1
# GLUTAMATE_SYNTHASE_NADH_RXN_p2
# GLUTAMATE_SYNTHASE_NADH_RXN_p2
# GLUTAMATE_SYNTHASE_NADH_RXN_p2
# GLUTAMATE_SYNTHASE_NADH_RXN_p2
# GLUTAMATE_SYNTHASE_NADH_RXN_p2
# ACET_pc1
# ACET_pc1
# ACET_pc1
# ACET_pc1
# ACET_pc1
# sFUM_biomass2
# sFUM_biomass2
# sFUM_biomass2
# sFUM_biomass2
# sFUM_biomass2
# sFUM_biomass1
# sFUM_biomass1
# sFUM_biomass1
# sFUM_biomass1
# sFUM_biomass1
# IMIDPHOSDEHYD_RXN_p1
# IMIDPHOSDEHYD_RXN_p1
# IMIDPHOSDEHYD_RXN_p1
# IMIDPHOSDEHYD_RXN_p1
# IMIDPHOSDEHYD_RXN_p1
# RXN1G_349_p2
# RXN1G_349_p2
# RXN1G_349_p2
# RXN1G_349_p2
# RXN1G_349_p2
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1
# HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1
# ARG_LYS_mc2
# ARG_LYS_mc2
# ARG_LYS_mc2
# ARG_LYS_mc2
# ARG_LYS_mc2
# 3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x2
# 3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x2
# 3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x2
# 3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x2
# 3_HYDROXBUTYRYL_COA_DEHYDRATASE_RXN_x2
# 2KG_CIT_mc1
# 2KG_CIT_mc1
# 2KG_CIT_mc1
# 2KG_CIT_mc1
# 2KG_CIT_mc1
# N_ACETYLGLUTPREDUCT_RXN_p1
# N_ACETYLGLUTPREDUCT_RXN_p1
# N_ACETYLGLUTPREDUCT_RXN_p1
# N_ACETYLGLUTPREDUCT_RXN_p1
# N_ACETYLGLUTPREDUCT_RXN_p1
# N_ACETYLGLUTPREDUCT_RXN_p2
# N_ACETYLGLUTPREDUCT_RXN_p2
# N_ACETYLGLUTPREDUCT_RXN_p2
# N_ACETYLGLUTPREDUCT_RXN_p2
# N_ACETYLGLUTPREDUCT_RXN_p2
# L_ALPHA_ALANINE_v_dielTransfer
# L_ALPHA_ALANINE_v_dielTransfer
# L_ALPHA_ALANINE_v_dielTransfer
# L_ALPHA_ALANINE_v_dielTransfer
# L_ALPHA_ALANINE_v_dielTransfer
# PALMITATE_pc1
# PALMITATE_pc1
# PALMITATE_pc1
# PALMITATE_pc1
# PALMITATE_pc1
# PALMITATE_pc2
# PALMITATE_pc2
# PALMITATE_pc2
# PALMITATE_pc2
# PALMITATE_pc2
# SULFITE_REDUCTASE_FERREDOXIN_RXN_p1
# SULFITE_REDUCTASE_FERREDOXIN_RXN_p1
# SULFITE_REDUCTASE_FERREDOXIN_RXN_p1
# SULFITE_REDUCTASE_FERREDOXIN_RXN_p1
# SULFITE_REDUCTASE_FERREDOXIN_RXN_p1
# Phloem_output_tx2
# Phloem_output_tx2
# Phloem_output_tx2
# Phloem_output_tx2
# Phloem_output_tx2
# Phloem_output_tx1
# Phloem_output_tx1
# Phloem_output_tx1
# Phloem_output_tx1
# Phloem_output_tx1
# FGAMSYN_RXN_p2
# FGAMSYN_RXN_p2
# FGAMSYN_RXN_p2
# FGAMSYN_RXN_p2
# FGAMSYN_RXN_p2
# FGAMSYN_RXN_p1
# FGAMSYN_RXN_p1
# FGAMSYN_RXN_p1
# FGAMSYN_RXN_p1
# FGAMSYN_RXN_p1
# RXN_9651_p1
# RXN_9651_p1
# RXN_9651_p1
# RXN_9651_p1
# RXN_9651_p1
# RXN_9651_p2
# RXN_9651_p2
# RXN_9651_p2
# RXN_9651_p2
# RXN_9651_p2
# MAL_CIT_mc2
# MAL_CIT_mc2
# MAL_CIT_mc2
# MAL_CIT_mc2
# MAL_CIT_mc2
# PHOSGLYPHOS_RXN_p1
# PHOSGLYPHOS_RXN_p1
# PHOSGLYPHOS_RXN_p1
# PHOSGLYPHOS_RXN_p1
# PHOSGLYPHOS_RXN_p1
# PHOSGLYPHOS_RXN_p2
# PHOSGLYPHOS_RXN_p2
# PHOSGLYPHOS_RXN_p2
# PHOSGLYPHOS_RXN_p2
# PHOSGLYPHOS_RXN_p2
# 3PGAREARR_RXN_c1
# 3PGAREARR_RXN_c1
# 3PGAREARR_RXN_c1
# 3PGAREARR_RXN_c1
# 3PGAREARR_RXN_c1
# 3PGAREARR_RXN_c2
# 3PGAREARR_RXN_c2
# 3PGAREARR_RXN_c2
# 3PGAREARR_RXN_c2
# 3PGAREARR_RXN_c2
# RXN_3521_p1
# RXN_3521_p1
# RXN_3521_p1
# RXN_3521_p1
# RXN_3521_p1
# OROTPDECARB_RXN_p1
# OROTPDECARB_RXN_p1
# OROTPDECARB_RXN_p1
# OROTPDECARB_RXN_p1
# OROTPDECARB_RXN_p1
# ASPARAGINE_TRNA_LIGASE_RXN_c2
# ASPARAGINE_TRNA_LIGASE_RXN_c2
# ASPARAGINE_TRNA_LIGASE_RXN_c2
# ASPARAGINE_TRNA_LIGASE_RXN_c2
# ASPARAGINE_TRNA_LIGASE_RXN_c2
# ALANINE_AMINOTRANSFERASE_RXN_c2
# ALANINE_AMINOTRANSFERASE_RXN_c2
# ALANINE_AMINOTRANSFERASE_RXN_c2
# ALANINE_AMINOTRANSFERASE_RXN_c2
# ALANINE_AMINOTRANSFERASE_RXN_c2
# ALANINE_AMINOTRANSFERASE_RXN_c1
# ALANINE_AMINOTRANSFERASE_RXN_c1
# ALANINE_AMINOTRANSFERASE_RXN_c1
# ALANINE_AMINOTRANSFERASE_RXN_c1
# ALANINE_AMINOTRANSFERASE_RXN_c1
# RXN_6883_mc1
# RXN_6883_mc1
# RXN_6883_mc1
# RXN_6883_mc1
# RXN_6883_mc1
# Ferredoxin_Plastoquinone_Reductase_p2
# Ferredoxin_Plastoquinone_Reductase_p2
# Ferredoxin_Plastoquinone_Reductase_p2
# Ferredoxin_Plastoquinone_Reductase_p2
# Ferredoxin_Plastoquinone_Reductase_p2
# RXN_9540_p2
# RXN_9540_p2
# RXN_9540_p2
# RXN_9540_p2
# RXN_9540_p2
# RXN_9540_p1
# RXN_9540_p1
# RXN_9540_p1
# RXN_9540_p1
# RXN_9540_p1
# Ferredoxin_Plastoquinone_Reductase_p1
# Ferredoxin_Plastoquinone_Reductase_p1
# Ferredoxin_Plastoquinone_Reductase_p1
# Ferredoxin_Plastoquinone_Reductase_p1
# Ferredoxin_Plastoquinone_Reductase_p1
# DIHYDROPICRED_RXN_NADP_p2
# DIHYDROPICRED_RXN_NADP_p2
# DIHYDROPICRED_RXN_NADP_p2
# DIHYDROPICRED_RXN_NADP_p2
# DIHYDROPICRED_RXN_NADP_p2
# DIHYDROPICRED_RXN_NADP_p1
# DIHYDROPICRED_RXN_NADP_p1
# DIHYDROPICRED_RXN_NADP_p1
# DIHYDROPICRED_RXN_NADP_p1
# DIHYDROPICRED_RXN_NADP_p1
# PRO_v_dielTransfer
# PRO_v_dielTransfer
# PRO_v_dielTransfer
# PRO_v_dielTransfer
# PRO_v_dielTransfer
# ARG_PROTON_vc2
# ARG_PROTON_vc2
# ARG_PROTON_vc2
# ARG_PROTON_vc2
# ARG_PROTON_vc2
# RXN0_2382_p1
# RXN0_2382_p1
# RXN0_2382_p1
# RXN0_2382_p1
# RXN0_2382_p1
# SUC_SO4_mc2
# SUC_SO4_mc2
# SUC_SO4_mc2
# SUC_SO4_mc2
# SUC_SO4_mc2
# SUC_SO4_mc1
# SUC_SO4_mc1
# SUC_SO4_mc1
# SUC_SO4_mc1
# SUC_SO4_mc1
# RXN_9650_p2
# RXN_9650_p2
# RXN_9650_p2
# RXN_9650_p2
# RXN_9650_p2
# RXN_9650_p1
# RXN_9650_p1
# RXN_9650_p1
# RXN_9650_p1
# RXN_9650_p1
# Octadecadienoyl_ACP_hydrolase_p1
# Octadecadienoyl_ACP_hydrolase_p1
# Octadecadienoyl_ACP_hydrolase_p1
# Octadecadienoyl_ACP_hydrolase_p1
# Octadecadienoyl_ACP_hydrolase_p1
# Octadecadienoyl_ACP_hydrolase_p2
# Octadecadienoyl_ACP_hydrolase_p2
# Octadecadienoyl_ACP_hydrolase_p2
# Octadecadienoyl_ACP_hydrolase_p2
# Octadecadienoyl_ACP_hydrolase_p2
# ARG_ORNITHINE_mc2
# ARG_ORNITHINE_mc2
# ARG_ORNITHINE_mc2
# ARG_ORNITHINE_mc2
# ARG_ORNITHINE_mc2
# ARG_ORNITHINE_mc1
# ARG_ORNITHINE_mc1
# ARG_ORNITHINE_mc1
# ARG_ORNITHINE_mc1
# ARG_ORNITHINE_mc1
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2
# RXN0_5330_NADP_mi1
# RXN0_5330_NADP_mi1
# RXN0_5330_NADP_mi1
# RXN0_5330_NADP_mi1
# RXN0_5330_NADP_mi1
# MYO_INOSITOL_OXYGENASE_RXN_c2
# MYO_INOSITOL_OXYGENASE_RXN_c2
# MYO_INOSITOL_OXYGENASE_RXN_c2
# MYO_INOSITOL_OXYGENASE_RXN_c2
# MYO_INOSITOL_OXYGENASE_RXN_c2
# ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2
# ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2
# ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2
# ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2
# ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2
# Glycerate_xc1
# Glycerate_xc1
# Glycerate_xc1
# Glycerate_xc1
# Glycerate_xc1
# hexadecadienoate_biosynthesis_p2
# hexadecadienoate_biosynthesis_p2
# hexadecadienoate_biosynthesis_p2
# hexadecadienoate_biosynthesis_p2
# hexadecadienoate_biosynthesis_p2
# Glycerate_xc2
# Glycerate_xc2
# Glycerate_xc2
# Glycerate_xc2
# Glycerate_xc2
# RXN_9653_p2
# RXN_9653_p2
# RXN_9653_p2
# RXN_9653_p2
# RXN_9653_p2
# RXN_9653_p1
# RXN_9653_p1
# RXN_9653_p1
# RXN_9653_p1
# RXN_9653_p1
# LEU_mc1
# LEU_mc1
# LEU_mc1
# LEU_mc1
# LEU_mc1
# LEU_mc2
# LEU_mc2
# LEU_mc2
# LEU_mc2
# LEU_mc2
# RXN_9657_p2
# RXN_9657_p2
# RXN_9657_p2
# RXN_9657_p2
# RXN_9657_p2
# RXN_9657_p1
# RXN_9657_p1
# RXN_9657_p1
# RXN_9657_p1
# RXN_9657_p1
# GLT_xc1
# GLT_xc1
# GLT_xc1
# GLT_xc1
# GLT_xc1
# GLT_xc2
# GLT_xc2
# GLT_xc2
# GLT_xc2
# GLT_xc2
# RXN_9654_p2
# RXN_9654_p2
# RXN_9654_p2
# RXN_9654_p2
# RXN_9654_p2
# RXN_9654_p1
# RXN_9654_p1
# RXN_9654_p1
# RXN_9654_p1
# RXN_9654_p1
# RXN_12002_p2
# RXN_12002_p2
# RXN_12002_p2
# RXN_12002_p2
# RXN_12002_p2
# Fatty_Acids_pc1
# Fatty_Acids_pc1
# Fatty_Acids_pc1
# Fatty_Acids_pc1
# Fatty_Acids_pc1
# Fatty_Acids_pc2
# Fatty_Acids_pc2
# Fatty_Acids_pc2
# Fatty_Acids_pc2
# Fatty_Acids_pc2
# PALMITATE_xc2
# PALMITATE_xc2
# PALMITATE_xc2
# PALMITATE_xc2
# PALMITATE_xc2
# RXN_9655_p1
# RXN_9655_p1
# RXN_9655_p1
# RXN_9655_p1
# RXN_9655_p1
# ARG_pc1
# ARG_pc1
# ARG_pc1
# ARG_pc1
# ARG_pc1
# SO4_pc1
# SO4_pc1
# SO4_pc1
# SO4_pc1
# SO4_pc1
# SO4_pc2
# SO4_pc2
# SO4_pc2
# SO4_pc2
# SO4_pc2
# RXN_9528_p1
# RXN_9528_p1
# RXN_9528_p1
# RXN_9528_p1
# RXN_9528_p1
# RXN_9528_p2
# RXN_9528_p2
# RXN_9528_p2
# RXN_9528_p2
# RXN_9528_p2
# THR_pc1
# THR_pc1
# THR_pc1
# THR_pc1
# THR_pc1
# THR_pc2
# THR_pc2
# THR_pc2
# THR_pc2
# THR_pc2
# Cellulose_biomass1
# Cellulose_biomass1
# Cellulose_biomass1
# Cellulose_biomass1
# Cellulose_biomass1
# METHYLACYLYLCOA_HYDROXY_RXN_m2
# METHYLACYLYLCOA_HYDROXY_RXN_m2
# METHYLACYLYLCOA_HYDROXY_RXN_m2
# METHYLACYLYLCOA_HYDROXY_RXN_m2
# METHYLACYLYLCOA_HYDROXY_RXN_m2
# METHYLACYLYLCOA_HYDROXY_RXN_m1
# METHYLACYLYLCOA_HYDROXY_RXN_m1
# METHYLACYLYLCOA_HYDROXY_RXN_m1
# METHYLACYLYLCOA_HYDROXY_RXN_m1
# METHYLACYLYLCOA_HYDROXY_RXN_m1
# Cellulose_biomass2
# Cellulose_biomass2
# Cellulose_biomass2
# Cellulose_biomass2
# Cellulose_biomass2
# GLY_xc1
# GLY_xc1
# GLY_xc1
# GLY_xc1
# GLY_xc1
# 2_METHYL_ACETO_ACETYL_COA_mc1
# 2_METHYL_ACETO_ACETYL_COA_mc1
# 2_METHYL_ACETO_ACETYL_COA_mc1
# 2_METHYL_ACETO_ACETYL_COA_mc1
# 2_METHYL_ACETO_ACETYL_COA_mc1
# 2_METHYL_ACETO_ACETYL_COA_mc2
# 2_METHYL_ACETO_ACETYL_COA_mc2
# 2_METHYL_ACETO_ACETYL_COA_mc2
# 2_METHYL_ACETO_ACETYL_COA_mc2
# 2_METHYL_ACETO_ACETYL_COA_mc2
# GLY_xc2
# GLY_xc2
# GLY_xc2
# GLY_xc2
# GLY_xc2
# DUTP_PYROP_RXN_p1
# DUTP_PYROP_RXN_p1
# DUTP_PYROP_RXN_p1
# DUTP_PYROP_RXN_p1
# DUTP_PYROP_RXN_p1
# DUTP_PYROP_RXN_p2
# DUTP_PYROP_RXN_p2
# DUTP_PYROP_RXN_p2
# DUTP_PYROP_RXN_p2
# DUTP_PYROP_RXN_p2
# ADENYLOSUCCINATE_SYNTHASE_RXN_p1
# ADENYLOSUCCINATE_SYNTHASE_RXN_p1
# ADENYLOSUCCINATE_SYNTHASE_RXN_p1
# ADENYLOSUCCINATE_SYNTHASE_RXN_p1
# ADENYLOSUCCINATE_SYNTHASE_RXN_p1
# ADENYLOSUCCINATE_SYNTHASE_RXN_p2
# ADENYLOSUCCINATE_SYNTHASE_RXN_p2
# ADENYLOSUCCINATE_SYNTHASE_RXN_p2
# ADENYLOSUCCINATE_SYNTHASE_RXN_p2
# ADENYLOSUCCINATE_SYNTHASE_RXN_p2
# CO2_tx2
# CO2_tx2
# CO2_tx2
# CO2_tx2
# CO2_tx2
# ACETYL_COA_ACETYLTRANSFER_RXN_x1
# ACETYL_COA_ACETYLTRANSFER_RXN_x1
# ACETYL_COA_ACETYLTRANSFER_RXN_x1
# ACETYL_COA_ACETYLTRANSFER_RXN_x1
# ACETYL_COA_ACETYLTRANSFER_RXN_x1
# ACETYL_COA_ACETYLTRANSFER_RXN_x2
# ACETYL_COA_ACETYLTRANSFER_RXN_x2
# ACETYL_COA_ACETYLTRANSFER_RXN_x2
# ACETYL_COA_ACETYLTRANSFER_RXN_x2
# ACETYL_COA_ACETYLTRANSFER_RXN_x2
# CO2_tx1
# CO2_tx1
# CO2_tx1
# CO2_tx1
# CO2_tx1
# MercaptoPyruvateSulfurtransferase_m2
# MercaptoPyruvateSulfurtransferase_m2
# MercaptoPyruvateSulfurtransferase_m2
# MercaptoPyruvateSulfurtransferase_m2
# MercaptoPyruvateSulfurtransferase_m2
# MercaptoPyruvateSulfurtransferase_m1
# MercaptoPyruvateSulfurtransferase_m1
# MercaptoPyruvateSulfurtransferase_m1
# MercaptoPyruvateSulfurtransferase_m1
# MercaptoPyruvateSulfurtransferase_m1
# AMP_DEAMINASE_RXN_c1
# AMP_DEAMINASE_RXN_c1
# AMP_DEAMINASE_RXN_c1
# AMP_DEAMINASE_RXN_c1
# AMP_DEAMINASE_RXN_c1
# AMP_DEAMINASE_RXN_c2
# AMP_DEAMINASE_RXN_c2
# AMP_DEAMINASE_RXN_c2
# AMP_DEAMINASE_RXN_c2
# AMP_DEAMINASE_RXN_c2
# RXN0_5224_c2
# RXN0_5224_c2
# RXN0_5224_c2
# RXN0_5224_c2
# RXN0_5224_c2
# RXN0_5224_c1
# RXN0_5224_c1
# RXN0_5224_c1
# RXN0_5224_c1
# RXN0_5224_c1
# DSERDEAM_RXN_c1
# DSERDEAM_RXN_c1
# DSERDEAM_RXN_c1
# DSERDEAM_RXN_c1
# DSERDEAM_RXN_c1
# RXN1G_349_p1
# RXN1G_349_p1
# RXN1G_349_p1
# RXN1G_349_p1
# RXN1G_349_p1
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m1
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m1
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m1
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m1
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m1
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m2
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m2
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m2
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m2
# HYDROXYMETHYLGLUTARYL_COA_LYASE_RXN_m2
# MALEYLACETOACETATE_ISOMERASE_RXN_c2
# MALEYLACETOACETATE_ISOMERASE_RXN_c2
# MALEYLACETOACETATE_ISOMERASE_RXN_c2
# MALEYLACETOACETATE_ISOMERASE_RXN_c2
# MALEYLACETOACETATE_ISOMERASE_RXN_c2
# HOMOSERKIN_RXN_p1
# HOMOSERKIN_RXN_p1
# HOMOSERKIN_RXN_p1
# HOMOSERKIN_RXN_p1
# HOMOSERKIN_RXN_p1
# HOMOSERKIN_RXN_p2
# HOMOSERKIN_RXN_p2
# HOMOSERKIN_RXN_p2
# HOMOSERKIN_RXN_p2
# HOMOSERKIN_RXN_p2
# MALEYLACETOACETATE_ISOMERASE_RXN_c1
# MALEYLACETOACETATE_ISOMERASE_RXN_c1
# MALEYLACETOACETATE_ISOMERASE_RXN_c1
# MALEYLACETOACETATE_ISOMERASE_RXN_c1
# MALEYLACETOACETATE_ISOMERASE_RXN_c1
# PEPDEPHOS_RXN_c1
# PEPDEPHOS_RXN_c1
# PEPDEPHOS_RXN_c1
# PEPDEPHOS_RXN_c1
# PEPDEPHOS_RXN_c1
# DUMP_pc2
# DUMP_pc2
# DUMP_pc2
# DUMP_pc2
# DUMP_pc2
# PEPDEPHOS_RXN_c2
# PEPDEPHOS_RXN_c2
# PEPDEPHOS_RXN_c2
# PEPDEPHOS_RXN_c2
# PEPDEPHOS_RXN_c2
# GLUC1PURIDYLTRANS_RXN_p1
# GLUC1PURIDYLTRANS_RXN_p1
# GLUC1PURIDYLTRANS_RXN_p1
# GLUC1PURIDYLTRANS_RXN_p1
# GLUC1PURIDYLTRANS_RXN_p1
# GLUC1PURIDYLTRANS_RXN_p2
# GLUC1PURIDYLTRANS_RXN_p2
# GLUC1PURIDYLTRANS_RXN_p2
# GLUC1PURIDYLTRANS_RXN_p2
# GLUC1PURIDYLTRANS_RXN_p2
# H2O_xc2
# H2O_xc2
# H2O_xc2
# H2O_xc2
# H2O_xc2
# RXN1G_445_p2
# RXN1G_445_p2
# RXN1G_445_p2
# RXN1G_445_p2
# RXN1G_445_p2
# RXN1G_445_p1
# RXN1G_445_p1
# RXN1G_445_p1
# RXN1G_445_p1
# RXN1G_445_p1
# H2O_xc1
# H2O_xc1
# H2O_xc1
# H2O_xc1
# H2O_xc1
# MAL_PROTON_rev_vc2
# MAL_PROTON_rev_vc2
# MAL_PROTON_rev_vc2
# MAL_PROTON_rev_vc2
# MAL_PROTON_rev_vc2
# MAL_PROTON_rev_vc1
# MAL_PROTON_rev_vc1
# MAL_PROTON_rev_vc1
# MAL_PROTON_rev_vc1
# MAL_PROTON_rev_vc1
# 3_ISOPROPYLMALDEHYDROG_RXN_p1
# 3_ISOPROPYLMALDEHYDROG_RXN_p1
# 3_ISOPROPYLMALDEHYDROG_RXN_p1
# 3_ISOPROPYLMALDEHYDROG_RXN_p1
# 3_ISOPROPYLMALDEHYDROG_RXN_p1
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERILEU_RXN_m1
# Nitrate_tx1
# Nitrate_tx1
# Nitrate_tx1
# Nitrate_tx1
# Nitrate_tx1
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x2
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x2
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x2
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x2
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x2
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x1
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x1
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x1
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x1
# 1_PERIOD_1_PERIOD_1_PERIOD_178_RXN_x1
# Nitrate_tx2
# Nitrate_tx2
# Nitrate_tx2
# Nitrate_tx2
# Nitrate_tx2
# FUM_PROTON_vc2
# FUM_PROTON_vc2
# FUM_PROTON_vc2
# FUM_PROTON_vc2
# FUM_PROTON_vc2
# FUM_PROTON_vc1
# FUM_PROTON_vc1
# FUM_PROTON_vc1
# FUM_PROTON_vc1
# FUM_PROTON_vc1
# NADPHoxc_tx2
# NADPHoxc_tx2
# NADPHoxc_tx2
# NADPHoxc_tx2
# NADPHoxc_tx2
# NADPHoxc_tx1
# NADPHoxc_tx1
# NADPHoxc_tx1
# NADPHoxc_tx1
# NADPHoxc_tx1
# HOMOCYSMETB12_RXN_p1
# HOMOCYSMETB12_RXN_p1
# HOMOCYSMETB12_RXN_p1
# HOMOCYSMETB12_RXN_p1
# HOMOCYSMETB12_RXN_p1
# HOMOCYSMETB12_RXN_p2
# HOMOCYSMETB12_RXN_p2
# HOMOCYSMETB12_RXN_p2
# HOMOCYSMETB12_RXN_p2
# HOMOCYSMETB12_RXN_p2
# METHYLENE_THF_mc2
# METHYLENE_THF_mc2
# METHYLENE_THF_mc2
# METHYLENE_THF_mc2
# METHYLENE_THF_mc2
# RXN_13202_p1
# RXN_13202_p1
# RXN_13202_p1
# RXN_13202_p1
# RXN_13202_p1
# RXN_13202_p2
# RXN_13202_p2
# RXN_13202_p2
# RXN_13202_p2
# RXN_13202_p2
# METHYLENE_THF_mc1
# METHYLENE_THF_mc1
# METHYLENE_THF_mc1
# METHYLENE_THF_mc1
# METHYLENE_THF_mc1
# SER_v_dielTransfer
# SER_v_dielTransfer
# SER_v_dielTransfer
# SER_v_dielTransfer
# SER_v_dielTransfer
# PYRUVATE_pc1
# PYRUVATE_pc1
# PYRUVATE_pc1
# PYRUVATE_pc1
# PYRUVATE_pc1
# PYRUVATE_pc2
# PYRUVATE_pc2
# PYRUVATE_pc2
# PYRUVATE_pc2
# PYRUVATE_pc2
# SHIKIMATE_KINASE_RXN_p2
# SHIKIMATE_KINASE_RXN_p2
# SHIKIMATE_KINASE_RXN_p2
# SHIKIMATE_KINASE_RXN_p2
# SHIKIMATE_KINASE_RXN_p2
# SHIKIMATE_KINASE_RXN_p1
# SHIKIMATE_KINASE_RXN_p1
# SHIKIMATE_KINASE_RXN_p1
# SHIKIMATE_KINASE_RXN_p1
# SHIKIMATE_KINASE_RXN_p1
# SUPEROX_DISMUT_RXN_c2
# SUPEROX_DISMUT_RXN_c2
# SUPEROX_DISMUT_RXN_c2
# SUPEROX_DISMUT_RXN_c2
# SUPEROX_DISMUT_RXN_c2
# SUPEROX_DISMUT_RXN_c1
# SUPEROX_DISMUT_RXN_c1
# SUPEROX_DISMUT_RXN_c1
# SUPEROX_DISMUT_RXN_c1
# SUPEROX_DISMUT_RXN_c1
# DIHYDROXYISOVALDEHYDRAT_RXN_p1
# DIHYDROXYISOVALDEHYDRAT_RXN_p1
# DIHYDROXYISOVALDEHYDRAT_RXN_p1
# DIHYDROXYISOVALDEHYDRAT_RXN_p1
# DIHYDROXYISOVALDEHYDRAT_RXN_p1
# pTRP_biomass1
# pTRP_biomass1
# pTRP_biomass1
# pTRP_biomass1
# pTRP_biomass1
# RXN_9660_p1
# RXN_9660_p1
# RXN_9660_p1
# RXN_9660_p1
# RXN_9660_p1
# ARG_mc2
# ARG_mc2
# ARG_mc2
# ARG_mc2
# ARG_mc2
# Pi_PROTON_mc1
# Pi_PROTON_mc1
# Pi_PROTON_mc1
# Pi_PROTON_mc1
# Pi_PROTON_mc1
# Pi_PROTON_mc2
# Pi_PROTON_mc2
# Pi_PROTON_mc2
# Pi_PROTON_mc2
# Pi_PROTON_mc2
# ARG_mc1
# ARG_mc1
# ARG_mc1
# ARG_mc1
# ARG_mc1
# ASPAMINOTRANS_RXN_m2
# ASPAMINOTRANS_RXN_m2
# ASPAMINOTRANS_RXN_m2
# ASPAMINOTRANS_RXN_m2
# ASPAMINOTRANS_RXN_m2
# ASPAMINOTRANS_RXN_m1
# ASPAMINOTRANS_RXN_m1
# ASPAMINOTRANS_RXN_m1
# ASPAMINOTRANS_RXN_m1
# ASPAMINOTRANS_RXN_m1
# RXN_9520_p1
# RXN_9520_p1
# RXN_9520_p1
# RXN_9520_p1
# RXN_9520_p1
# RXN_9520_p2
# RXN_9520_p2
# RXN_9520_p2
# RXN_9520_p2
# RXN_9520_p2
# RXN_6384_x2
# RXN_6384_x2
# RXN_6384_x2
# RXN_6384_x2
# RXN_6384_x2
# RXN_12486_c1
# RXN_12486_c1
# RXN_12486_c1
# RXN_12486_c1
# RXN_12486_c1
# RXN_9635_p1
# RXN_9635_p1
# RXN_9635_p1
# RXN_9635_p1
# RXN_9635_p1
# 2_METHYL_ACETO_ACETYL_COA_xc1
# 2_METHYL_ACETO_ACETYL_COA_xc1
# 2_METHYL_ACETO_ACETYL_COA_xc1
# 2_METHYL_ACETO_ACETYL_COA_xc1
# 2_METHYL_ACETO_ACETYL_COA_xc1
# 2_METHYL_ACETO_ACETYL_COA_xc2
# 2_METHYL_ACETO_ACETYL_COA_xc2
# 2_METHYL_ACETO_ACETYL_COA_xc2
# 2_METHYL_ACETO_ACETYL_COA_xc2
# 2_METHYL_ACETO_ACETYL_COA_xc2
# IPP_biosynthesis_c1
# IPP_biosynthesis_c1
# IPP_biosynthesis_c1
# IPP_biosynthesis_c1
# IPP_biosynthesis_c1
# IPP_biosynthesis_c2
# IPP_biosynthesis_c2
# IPP_biosynthesis_c2
# IPP_biosynthesis_c2
# IPP_biosynthesis_c2
# ARGSUCCINLYA_RXN_p2
# ARGSUCCINLYA_RXN_p2
# ARGSUCCINLYA_RXN_p2
# ARGSUCCINLYA_RXN_p2
# ARGSUCCINLYA_RXN_p2
# pALA_biomass1
# pALA_biomass1
# pALA_biomass1
# pALA_biomass1
# pALA_biomass1
# pALA_biomass2
# pALA_biomass2
# pALA_biomass2
# pALA_biomass2
# pALA_biomass2
# ARGSUCCINLYA_RXN_p1
# ARGSUCCINLYA_RXN_p1
# ARGSUCCINLYA_RXN_p1
# ARGSUCCINLYA_RXN_p1
# ARGSUCCINLYA_RXN_p1
# DIHYDROOROT_RXN_p2
# DIHYDROOROT_RXN_p2
# DIHYDROOROT_RXN_p2
# DIHYDROOROT_RXN_p2
# DIHYDROOROT_RXN_p2
# DIHYDROOROT_RXN_p1
# DIHYDROOROT_RXN_p1
# DIHYDROOROT_RXN_p1
# DIHYDROOROT_RXN_p1
# DIHYDROOROT_RXN_p1
# GLUTAMINESYN_RXN_p2
# GLUTAMINESYN_RXN_p2
# GLUTAMINESYN_RXN_p2
# GLUTAMINESYN_RXN_p2
# GLUTAMINESYN_RXN_p2
# GLUTAMINESYN_RXN_p1
# GLUTAMINESYN_RXN_p1
# GLUTAMINESYN_RXN_p1
# GLUTAMINESYN_RXN_p1
# GLUTAMINESYN_RXN_p1
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c2
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c2
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c2
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c2
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c2
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c1
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c1
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c1
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c1
# HOMOGENTISATE_12_DIOXYGENASE_RXN_c1
# IMPCYCLOHYDROLASE_RXN_p2
# IMPCYCLOHYDROLASE_RXN_p2
# IMPCYCLOHYDROLASE_RXN_p2
# IMPCYCLOHYDROLASE_RXN_p2
# IMPCYCLOHYDROLASE_RXN_p2
# IMPCYCLOHYDROLASE_RXN_p1
# IMPCYCLOHYDROLASE_RXN_p1
# IMPCYCLOHYDROLASE_RXN_p1
# IMPCYCLOHYDROLASE_RXN_p1
# IMPCYCLOHYDROLASE_RXN_p1
# 3PGAREARR_RXN_p1
# 3PGAREARR_RXN_p1
# 3PGAREARR_RXN_p1
# 3PGAREARR_RXN_p1
# 3PGAREARR_RXN_p1
# 3PGAREARR_RXN_p2
# 3PGAREARR_RXN_p2
# 3PGAREARR_RXN_p2
# 3PGAREARR_RXN_p2
# 3PGAREARR_RXN_p2
# RXN_7978_p2
# RXN_7978_p2
# RXN_7978_p2
# RXN_7978_p2
# RXN_7978_p2
# RXN_7978_p1
# RXN_7978_p1
# RXN_7978_p1
# RXN_7978_p1
# RXN_7978_p1
# TYROSINE_AMINOTRANSFERASE_RXN_p2
# TYROSINE_AMINOTRANSFERASE_RXN_p2
# TYROSINE_AMINOTRANSFERASE_RXN_p2
# TYROSINE_AMINOTRANSFERASE_RXN_p2
# TYROSINE_AMINOTRANSFERASE_RXN_p2
# TYROSINE_AMINOTRANSFERASE_RXN_p1
# TYROSINE_AMINOTRANSFERASE_RXN_p1
# TYROSINE_AMINOTRANSFERASE_RXN_p1
# TYROSINE_AMINOTRANSFERASE_RXN_p1
# TYROSINE_AMINOTRANSFERASE_RXN_p1
# RXN_9623_p1
# RXN_9623_p1
# RXN_9623_p1
# RXN_9623_p1
# RXN_9623_p1
# METHENYLTHFCYCLOHYDRO_RXN_c2
# METHENYLTHFCYCLOHYDRO_RXN_c2
# METHENYLTHFCYCLOHYDRO_RXN_c2
# METHENYLTHFCYCLOHYDRO_RXN_c2
# METHENYLTHFCYCLOHYDRO_RXN_c2
# RXN_11213_m2
# RXN_11213_m2
# RXN_11213_m2
# RXN_11213_m2
# RXN_11213_m2
# RXN_11213_m1
# RXN_11213_m1
# RXN_11213_m1
# RXN_11213_m1
# RXN_11213_m1
# GLYC3PDEHYDROGBIOSYN_RXN_c2
# GLYC3PDEHYDROGBIOSYN_RXN_c2
# GLYC3PDEHYDROGBIOSYN_RXN_c2
# GLYC3PDEHYDROGBIOSYN_RXN_c2
# GLYC3PDEHYDROGBIOSYN_RXN_c2
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p1
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p1
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p1
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p1
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p1
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p2
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p2
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p2
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p2
# 2_PERIOD_4_PERIOD_1_PERIOD_46_RXN_p2
# GLYC3PDEHYDROGBIOSYN_RXN_c1
# GLYC3PDEHYDROGBIOSYN_RXN_c1
# GLYC3PDEHYDROGBIOSYN_RXN_c1
# GLYC3PDEHYDROGBIOSYN_RXN_c1
# GLYC3PDEHYDROGBIOSYN_RXN_c1
# sGLN_biomass1
# sGLN_biomass1
# sGLN_biomass1
# sGLN_biomass1
# sGLN_biomass1
# sGLN_biomass2
# sGLN_biomass2
# sGLN_biomass2
# sGLN_biomass2
# sGLN_biomass2
# RXN0_5224_p2
# RXN0_5224_p2
# RXN0_5224_p2
# RXN0_5224_p2
# RXN0_5224_p2
# RXN0_5224_p1
# RXN0_5224_p1
# RXN0_5224_p1
# RXN0_5224_p1
# RXN0_5224_p1
# PREPHENATE_TRANSAMINE_RXN_p1
# PREPHENATE_TRANSAMINE_RXN_p1
# PREPHENATE_TRANSAMINE_RXN_p1
# PREPHENATE_TRANSAMINE_RXN_p1
# PREPHENATE_TRANSAMINE_RXN_p1
# PRO_mc2
# PRO_mc2
# PRO_mc2
# PRO_mc2
# PRO_mc2
# PRO_mc1
# PRO_mc1
# PRO_mc1
# PRO_mc1
# PRO_mc1
# PREPHENATE_TRANSAMINE_RXN_p2
# PREPHENATE_TRANSAMINE_RXN_p2
# PREPHENATE_TRANSAMINE_RXN_p2
# PREPHENATE_TRANSAMINE_RXN_p2
# PREPHENATE_TRANSAMINE_RXN_p2
# 1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_25_RXN_m2
# H2O_mc1
# H2O_mc1
# H2O_mc1
# H2O_mc1
# H2O_mc1
# GLYCERATE_GLYCOLLATE_pc2
# GLYCERATE_GLYCOLLATE_pc2
# GLYCERATE_GLYCOLLATE_pc2
# GLYCERATE_GLYCOLLATE_pc2
# GLYCERATE_GLYCOLLATE_pc2
# GLYCERATE_GLYCOLLATE_pc1
# GLYCERATE_GLYCOLLATE_pc1
# GLYCERATE_GLYCOLLATE_pc1
# GLYCERATE_GLYCOLLATE_pc1
# GLYCERATE_GLYCOLLATE_pc1
# IMP_DEHYDROG_RXN_c1
# IMP_DEHYDROG_RXN_c1
# IMP_DEHYDROG_RXN_c1
# IMP_DEHYDROG_RXN_c1
# IMP_DEHYDROG_RXN_c1
# HIS_pc2
# HIS_pc2
# HIS_pc2
# HIS_pc2
# HIS_pc2
# HIS_pc1
# HIS_pc1
# HIS_pc1
# HIS_pc1
# HIS_pc1
# IMP_DEHYDROG_RXN_c2
# IMP_DEHYDROG_RXN_c2
# IMP_DEHYDROG_RXN_c2
# IMP_DEHYDROG_RXN_c2
# IMP_DEHYDROG_RXN_c2
# HISTIDPHOS_RXN_p2
# HISTIDPHOS_RXN_p2
# HISTIDPHOS_RXN_p2
# HISTIDPHOS_RXN_p2
# HISTIDPHOS_RXN_p2
# HISTIDPHOS_RXN_p1
# HISTIDPHOS_RXN_p1
# HISTIDPHOS_RXN_p1
# HISTIDPHOS_RXN_p1
# HISTIDPHOS_RXN_p1
# 3PGA_Pi_pc2
# 3PGA_Pi_pc2
# 3PGA_Pi_pc2
# 3PGA_Pi_pc2
# 3PGA_Pi_pc2
# 3PGA_Pi_pc1
# 3PGA_Pi_pc1
# 3PGA_Pi_pc1
# 3PGA_Pi_pc1
# 3PGA_Pi_pc1
# SUC_FUM_mc1
# SUC_FUM_mc1
# SUC_FUM_mc1
# SUC_FUM_mc1
# SUC_FUM_mc1
# SUC_FUM_mc2
# SUC_FUM_mc2
# SUC_FUM_mc2
# SUC_FUM_mc2
# SUC_FUM_mc2
# VAL_PROTON_rev_vc2
# VAL_PROTON_rev_vc2
# VAL_PROTON_rev_vc2
# VAL_PROTON_rev_vc2
# VAL_PROTON_rev_vc2
# DHAP_3PGA_pc2
# DHAP_3PGA_pc2
# DHAP_3PGA_pc2
# DHAP_3PGA_pc2
# DHAP_3PGA_pc2
# UREA_mc1
# UREA_mc1
# UREA_mc1
# UREA_mc1
# UREA_mc1
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m1
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m1
# SUCROSE_SYNTHASE_RXN_c1
# SUCROSE_SYNTHASE_RXN_c1
# SUCROSE_SYNTHASE_RXN_c1
# SUCROSE_SYNTHASE_RXN_c1
# SUCROSE_SYNTHASE_RXN_c1
# SUCROSE_SYNTHASE_RXN_c2
# SUCROSE_SYNTHASE_RXN_c2
# SUCROSE_SYNTHASE_RXN_c2
# SUCROSE_SYNTHASE_RXN_c2
# SUCROSE_SYNTHASE_RXN_c2
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m2
# BRANCHED_CHAINAMINOTRANSFERVAL_RXN_m2
# 6PFRUCTPHOS_RXN_c2
# 6PFRUCTPHOS_RXN_c2
# 6PFRUCTPHOS_RXN_c2
# 6PFRUCTPHOS_RXN_c2
# 6PFRUCTPHOS_RXN_c2
# 6PFRUCTPHOS_RXN_c1
# 6PFRUCTPHOS_RXN_c1
# 6PFRUCTPHOS_RXN_c1
# 6PFRUCTPHOS_RXN_c1
# 6PFRUCTPHOS_RXN_c1
# RXN_1781_v1
# RXN_1781_v1
# RXN_1781_v1
# RXN_1781_v1
# RXN_1781_v1
# RXN_1781_v2
# RXN_1781_v2
# RXN_1781_v2
# RXN_1781_v2
# RXN_1781_v2
# sGABA_biomass2
# sGABA_biomass2
# sGABA_biomass2
# sGABA_biomass2
# sGABA_biomass2
# sGABA_biomass1
# sGABA_biomass1
# sGABA_biomass1
# sGABA_biomass1
# sGABA_biomass1
# GDPKIN_RXN_c1
# GDPKIN_RXN_c1
# GDPKIN_RXN_c1
# GDPKIN_RXN_c1
# GDPKIN_RXN_c1
# CIT_xc2
# CIT_xc2
# CIT_xc2
# CIT_xc2
# CIT_xc2
# CIT_xc1
# CIT_xc1
# CIT_xc1
# CIT_xc1
# CIT_xc1
# gadoleic_acid_biosynthesis_p1
# gadoleic_acid_biosynthesis_p1
# gadoleic_acid_biosynthesis_p1
# gadoleic_acid_biosynthesis_p1
# gadoleic_acid_biosynthesis_p1
# GDPKIN_RXN_c2
# GDPKIN_RXN_c2
# GDPKIN_RXN_c2
# GDPKIN_RXN_c2
# GDPKIN_RXN_c2
# GDPREDUCT_RXN_p1
# GDPREDUCT_RXN_p1
# GDPREDUCT_RXN_p1
# GDPREDUCT_RXN_p1
# GDPREDUCT_RXN_p1
# GDPREDUCT_RXN_p2
# GDPREDUCT_RXN_p2
# GDPREDUCT_RXN_p2
# GDPREDUCT_RXN_p2
# GDPREDUCT_RXN_p2
# PHE_PROTON_rev_vc2
# PHE_PROTON_rev_vc2
# PHE_PROTON_rev_vc2
# PHE_PROTON_rev_vc2
# PHE_PROTON_rev_vc2
# PHE_PROTON_rev_vc1
# PHE_PROTON_rev_vc1
# PHE_PROTON_rev_vc1
# PHE_PROTON_rev_vc1
# PHE_PROTON_rev_vc1
# MANNITOL_1_PHOSPHATASE_RXN_c1
# MANNITOL_1_PHOSPHATASE_RXN_c1
# MANNITOL_1_PHOSPHATASE_RXN_c1
# MANNITOL_1_PHOSPHATASE_RXN_c1
# MANNITOL_1_PHOSPHATASE_RXN_c1
# MANNITOL_1_PHOSPHATASE_RXN_c2
# MANNITOL_1_PHOSPHATASE_RXN_c2
# MANNITOL_1_PHOSPHATASE_RXN_c2
# MANNITOL_1_PHOSPHATASE_RXN_c2
# MANNITOL_1_PHOSPHATASE_RXN_c2
# sGLU_biomass1
# sGLU_biomass1
# sGLU_biomass1
# sGLU_biomass1
# sGLU_biomass1
# sGLU_biomass2
# sGLU_biomass2
# sGLU_biomass2
# sGLU_biomass2
# sGLU_biomass2
# ASN_v_dielTransfer
# ASN_v_dielTransfer
# ASN_v_dielTransfer
# ASN_v_dielTransfer
# ASN_v_dielTransfer
# RXN_1381_p2
# RXN_1381_p2
# RXN_1381_p2
# RXN_1381_p2
# RXN_1381_p2
# RXN_1381_p1
# RXN_1381_p1
# RXN_1381_p1
# RXN_1381_p1
# RXN_1381_p1
# RXN_14903_mi2
# RXN_14903_mi2
# RXN_14903_mi2
# RXN_14903_mi2
# RXN_14903_mi2
# DIHYDROPICRED_RXN_NAD_p1
# DIHYDROPICRED_RXN_NAD_p1
# DIHYDROPICRED_RXN_NAD_p1
# DIHYDROPICRED_RXN_NAD_p1
# DIHYDROPICRED_RXN_NAD_p1
# DIHYDROPICRED_RXN_NAD_p2
# DIHYDROPICRED_RXN_NAD_p2
# DIHYDROPICRED_RXN_NAD_p2
# DIHYDROPICRED_RXN_NAD_p2
# DIHYDROPICRED_RXN_NAD_p2
# AICARSYN_RXN_p1
# AICARSYN_RXN_p1
# AICARSYN_RXN_p1
# AICARSYN_RXN_p1
# AICARSYN_RXN_p1
# AICARSYN_RXN_p2
# AICARSYN_RXN_p2
# AICARSYN_RXN_p2
# AICARSYN_RXN_p2
# AICARSYN_RXN_p2
# ACETOOHBUTSYN_RXN_p2
# ACETOOHBUTSYN_RXN_p2
# ACETOOHBUTSYN_RXN_p2
# ACETOOHBUTSYN_RXN_p2
# ACETOOHBUTSYN_RXN_p2
# K_ec2
# K_ec2
# K_ec2
# K_ec2
# K_ec2
# K_ec1
# K_ec1
# K_ec1
# K_ec1
# K_ec1
# ACETOOHBUTSYN_RXN_p1
# ACETOOHBUTSYN_RXN_p1
# ACETOOHBUTSYN_RXN_p1
# ACETOOHBUTSYN_RXN_p1
# ACETOOHBUTSYN_RXN_p1
# SUPEROX_DISMUT_RXN_p2
# SUPEROX_DISMUT_RXN_p2
# SUPEROX_DISMUT_RXN_p2
# SUPEROX_DISMUT_RXN_p2
# SUPEROX_DISMUT_RXN_p2
# SUPEROX_DISMUT_RXN_p1
# SUPEROX_DISMUT_RXN_p1
# SUPEROX_DISMUT_RXN_p1
# SUPEROX_DISMUT_RXN_p1
# SUPEROX_DISMUT_RXN_p1
# RXN_8001_p2
# RXN_8001_p2
# RXN_8001_p2
# RXN_8001_p2
# RXN_8001_p2
# RXN_8001_p1
# RXN_8001_p1
# RXN_8001_p1
# RXN_8001_p1
# RXN_8001_p1
# H_tx1
# H_tx1
# H_tx1
# H_tx1
# H_tx1
# H_tx2
# H_tx2
# H_tx2
# H_tx2
# H_tx2
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p2
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p2
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p2
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p2
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p2
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p1
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p1
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p1
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p1
# DIACYLGLYCEROL_O_ACYLTRANSFERASE_RXN_p1
# GLT_PROTON_vc2
# GLT_PROTON_vc2
# GLT_PROTON_vc2
# GLT_PROTON_vc2
# GLT_PROTON_vc2
# GLT_PROTON_vc1
# GLT_PROTON_vc1
# GLT_PROTON_vc1
# GLT_PROTON_vc1
# GLT_PROTON_vc1
# RXN66_3_m1
# RXN66_3_m1
# RXN66_3_m1
# RXN66_3_m1
# RXN66_3_m1
# RXN66_3_m2
# RXN66_3_m2
# RXN66_3_m2
# RXN66_3_m2
# RXN66_3_m2
# sSUCROSE_biomass1
# sSUCROSE_biomass1
# sSUCROSE_biomass1
# sSUCROSE_biomass1
# sSUCROSE_biomass1
# hexadecadienoate_ACP_desaturase_p1
# hexadecadienoate_ACP_desaturase_p1
# hexadecadienoate_ACP_desaturase_p1
# hexadecadienoate_ACP_desaturase_p1
# hexadecadienoate_ACP_desaturase_p1
# hexadecadienoate_ACP_desaturase_p2
# hexadecadienoate_ACP_desaturase_p2
# hexadecadienoate_ACP_desaturase_p2
# hexadecadienoate_ACP_desaturase_p2
# hexadecadienoate_ACP_desaturase_p2
# sSUCROSE_biomass2
# sSUCROSE_biomass2
# sSUCROSE_biomass2
# sSUCROSE_biomass2
# sSUCROSE_biomass2
# pTRP_biomass2
# pTRP_biomass2
# pTRP_biomass2
# pTRP_biomass2
# pTRP_biomass2
# MAL_ISOCITRATE_mc1
# MAL_ISOCITRATE_mc1
# MAL_ISOCITRATE_mc1
# MAL_ISOCITRATE_mc1
# MAL_ISOCITRATE_mc1
# ACET_xc2
# ACET_xc2
# ACET_xc2
# ACET_xc2
# ACET_xc2
# ACET_xc1
# ACET_xc1
# ACET_xc1
# ACET_xc1
# ACET_xc1
# MAL_ISOCITRATE_mc2
# MAL_ISOCITRATE_mc2
# MAL_ISOCITRATE_mc2
# MAL_ISOCITRATE_mc2
# MAL_ISOCITRATE_mc2
# lycopene_biosynthesis_p2
# lycopene_biosynthesis_p2
# lycopene_biosynthesis_p2
# lycopene_biosynthesis_p2
# lycopene_biosynthesis_p2
# lycopene_biosynthesis_p1
# lycopene_biosynthesis_p1
# lycopene_biosynthesis_p1
# lycopene_biosynthesis_p1
# lycopene_biosynthesis_p1
# DIHYDROXYISOVALDEHYDRAT_RXN_p2
# DIHYDROXYISOVALDEHYDRAT_RXN_p2
# DIHYDROXYISOVALDEHYDRAT_RXN_p2
# DIHYDROXYISOVALDEHYDRAT_RXN_p2
# DIHYDROXYISOVALDEHYDRAT_RXN_p2
# TYR_v_dielTransfer
# TYR_v_dielTransfer
# TYR_v_dielTransfer
# TYR_v_dielTransfer
# TYR_v_dielTransfer
# 4_AMINO_BUTYRATE_PROTON_rev_vc2
# 4_AMINO_BUTYRATE_PROTON_rev_vc2
# 4_AMINO_BUTYRATE_PROTON_rev_vc2
# 4_AMINO_BUTYRATE_PROTON_rev_vc2
# 4_AMINO_BUTYRATE_PROTON_rev_vc2
# 4_AMINO_BUTYRATE_PROTON_rev_vc1
# 4_AMINO_BUTYRATE_PROTON_rev_vc1
# 4_AMINO_BUTYRATE_PROTON_rev_vc1
# 4_AMINO_BUTYRATE_PROTON_rev_vc1
# 4_AMINO_BUTYRATE_PROTON_rev_vc1
# RXN_9655_p2
# RXN_9655_p2
# RXN_9655_p2
# RXN_9655_p2
# RXN_9655_p2
# RXN_6883_mi1
# RXN_6883_mi1
# RXN_6883_mi1
# RXN_6883_mi1
# RXN_6883_mi1
# RXN_6883_mi2
# RXN_6883_mi2
# RXN_6883_mi2
# RXN_6883_mi2
# RXN_6883_mi2
# ASPARTATEKIN_RXN_p1
# ASPARTATEKIN_RXN_p1
# ASPARTATEKIN_RXN_p1
# ASPARTATEKIN_RXN_p1
# ASPARTATEKIN_RXN_p1
# ASPARTATEKIN_RXN_p2
# ASPARTATEKIN_RXN_p2
# ASPARTATEKIN_RXN_p2
# ASPARTATEKIN_RXN_p2
# ASPARTATEKIN_RXN_p2
# RXN_7677_p2
# RXN_7677_p2
# RXN_7677_p2
# RXN_7677_p2
# RXN_7677_p2
# RXN_7677_p1
# RXN_7677_p1
# RXN_7677_p1
# RXN_7677_p1
# RXN_7677_p1
# pHIS_biomass2
# pHIS_biomass2
# pHIS_biomass2
# pHIS_biomass2
# pHIS_biomass2
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc2
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc2
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc2
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc2
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc2
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc1
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc1
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc1
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc1
# 2_METHYL_3_HYDROXY_BUTYRYL_COA_xc1
# RXN0_5260_m1
# RXN0_5260_m1
# RXN0_5260_m1
# RXN0_5260_m1
# RXN0_5260_m1
# RXN0_5260_m2
# RXN0_5260_m2
# RXN0_5260_m2
# RXN0_5260_m2
# RXN0_5260_m2
# 3_PERIOD_1_PERIOD_2_PERIOD_14_RXN_p1
# 3_PERIOD_1_PERIOD_2_PERIOD_14_RXN_p1
# 3_PERIOD_1_PERIOD_2_PERIOD_14_RXN_p1
# 3_PERIOD_1_PERIOD_2_PERIOD_14_RXN_p1
# 3_PERIOD_1_PERIOD_2_PERIOD_14_RXN_p1
# GLYCINE_AMINOTRANSFERASE_RXN_x1
# GLYCINE_AMINOTRANSFERASE_RXN_x1
# GLYCINE_AMINOTRANSFERASE_RXN_x1
# GLYCINE_AMINOTRANSFERASE_RXN_x1
# GLYCINE_AMINOTRANSFERASE_RXN_x1
# RXN_7676_p1
# RXN_7676_p1
# RXN_7676_p1
# RXN_7676_p1
# RXN_7676_p1
# RXN_7676_p2
# RXN_7676_p2
# RXN_7676_p2
# RXN_7676_p2
# RXN_7676_p2
# sMAL_biomass1
# sMAL_biomass1
# sMAL_biomass1
# sMAL_biomass1
# sMAL_biomass1
# sMAL_biomass2
# sMAL_biomass2
# sMAL_biomass2
# sMAL_biomass2
# sMAL_biomass2
# pGLY_biomass2
# pGLY_biomass2
# pGLY_biomass2
# pGLY_biomass2
# pGLY_biomass2
# pGLY_biomass1
# pGLY_biomass1
# pGLY_biomass1
# pGLY_biomass1
# pGLY_biomass1
# RXN_7674_p2
# RXN_7674_p2
# RXN_7674_p2
# RXN_7674_p2
# RXN_7674_p2
# RXN_7674_p1
# RXN_7674_p1
# RXN_7674_p1
# RXN_7674_p1
# RXN_7674_p1
# 3_PERIOD_2_PERIOD_1_PERIOD_48_RXN_v1
# 3_PERIOD_2_PERIOD_1_PERIOD_48_RXN_v1
# ...
# ISOLEUCINE_TRNA_LIGASE_RXN_c2
# ISOLEUCINE_TRNA_LIGASE_RXN_c2
# ISOLEUCINE_TRNA_LIGASE_RXN_c2
# 2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2
# 2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2
# 2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2
# 2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2
# 2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2
# HISTIDINE_TRNA_LIGASE_RXN_c2
# HISTIDINE_TRNA_LIGASE_RXN_c2
# HISTIDINE_TRNA_LIGASE_RXN_c2
# HISTIDINE_TRNA_LIGASE_RXN_c2
# HISTIDINE_TRNA_LIGASE_RXN_c2
# pGLN_biomass2
# pGLN_biomass2
# pGLN_biomass2
# pGLN_biomass2
# pGLN_biomass2
# pGLN_biomass1
# pGLN_biomass1
# pGLN_biomass1
# pGLN_biomass1
# pGLN_biomass1
# CYTOCHROME_C_OXIDASE_RXN_mi2
# CYTOCHROME_C_OXIDASE_RXN_mi2
# CYTOCHROME_C_OXIDASE_RXN_mi2
# CYTOCHROME_C_OXIDASE_RXN_mi2
# CYTOCHROME_C_OXIDASE_RXN_mi2
# CYTOCHROME_C_OXIDASE_RXN_mi1
# CYTOCHROME_C_OXIDASE_RXN_mi1
# CYTOCHROME_C_OXIDASE_RXN_mi1
# CYTOCHROME_C_OXIDASE_RXN_mi1
# CYTOCHROME_C_OXIDASE_RXN_mi1
# HOMOSERDEHYDROG_RXN_NAD_p2
# HOMOSERDEHYDROG_RXN_NAD_p2
# HOMOSERDEHYDROG_RXN_NAD_p2
# HOMOSERDEHYDROG_RXN_NAD_p2
# HOMOSERDEHYDROG_RXN_NAD_p2
# HOMOSERDEHYDROG_RXN_NAD_p1
# HOMOSERDEHYDROG_RXN_NAD_p1
# HOMOSERDEHYDROG_RXN_NAD_p1
# HOMOSERDEHYDROG_RXN_NAD_p1
# HOMOSERDEHYDROG_RXN_NAD_p1
# RXN490_3650_p2
# RXN490_3650_p2
# RXN490_3650_p2
# RXN490_3650_p2
# RXN490_3650_p2
# FORMYLTHFDEFORMYL_RXN_p2
# FORMYLTHFDEFORMYL_RXN_p2
# FORMYLTHFDEFORMYL_RXN_p2
# FORMYLTHFDEFORMYL_RXN_p2
# FORMYLTHFDEFORMYL_RXN_p2
# FORMYLTHFDEFORMYL_RXN_p1
# FORMYLTHFDEFORMYL_RXN_p1
# FORMYLTHFDEFORMYL_RXN_p1
# FORMYLTHFDEFORMYL_RXN_p1
# FORMYLTHFDEFORMYL_RXN_p1
# GLUCOKIN_RXN_c1
# GLUCOKIN_RXN_c1
# GLUCOKIN_RXN_c1
# GLUCOKIN_RXN_c1
# GLUCOKIN_RXN_c1
# GLUCOKIN_RXN_c2
# GLUCOKIN_RXN_c2
# GLUCOKIN_RXN_c2
# GLUCOKIN_RXN_c2
# GLUCOKIN_RXN_c2
# RIB5PISOM_RXN_p1
# RIB5PISOM_RXN_p1
# RIB5PISOM_RXN_p1
# RIB5PISOM_RXN_p1
# RIB5PISOM_RXN_p1
# OAA_ISOCITRATE_mc2
# OAA_ISOCITRATE_mc2
# OAA_ISOCITRATE_mc2
# OAA_ISOCITRATE_mc2
# OAA_ISOCITRATE_mc2
# OROTPDECARB_RXN_p2
# OROTPDECARB_RXN_p2
# OROTPDECARB_RXN_p2
# OROTPDECARB_RXN_p2
# OROTPDECARB_RXN_p2
# MAL_SUC_mc2
# MAL_SUC_mc2
# MAL_SUC_mc2
# MAL_SUC_mc2
# MAL_SUC_mc2
# OROPRIBTRANS_RXN_p1
# OROPRIBTRANS_RXN_p1
# OROPRIBTRANS_RXN_p1
# OROPRIBTRANS_RXN_p1
# OROPRIBTRANS_RXN_p1
# OROPRIBTRANS_RXN_p2
# OROPRIBTRANS_RXN_p2
# OROPRIBTRANS_RXN_p2
# OROPRIBTRANS_RXN_p2
# OROPRIBTRANS_RXN_p2
# MAL_SUC_mc1
# MAL_SUC_mc1
# MAL_SUC_mc1
# MAL_SUC_mc1
# MAL_SUC_mc1
# RXN_3521_p2
# RXN_3521_p2
# RXN_3521_p2
# RXN_3521_p2
# RXN_3521_p2
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c2
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c2
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c2
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c2
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c2
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c1
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c1
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c1
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c1
# CONIFERIN_BETA_GLUCOSIDASE_RXN_c1
# RXN_9648_p2
# RXN_9648_p2
# RXN_9648_p2
# RXN_9648_p2
# RXN_9648_p2
# ACETATE_COA_LIGASE_RXN_x1
# ACETATE_COA_LIGASE_RXN_x1
# ACETATE_COA_LIGASE_RXN_x1
# ACETATE_COA_LIGASE_RXN_x1
# ACETATE_COA_LIGASE_RXN_x1
# RXN_9523_p2
# RXN_9523_p2
# RXN_9523_p2
# RXN_9523_p2
# RXN_9523_p2
# RXN_9648_p1
# RXN_9648_p1
# RXN_9648_p1
# RXN_9648_p1
# RXN_9648_p1
# docosanoate_biosynthesis_p1
# docosanoate_biosynthesis_p1
# docosanoate_biosynthesis_p1
# docosanoate_biosynthesis_p1
# docosanoate_biosynthesis_p1
# docosanoate_biosynthesis_p2
# docosanoate_biosynthesis_p2
# docosanoate_biosynthesis_p2
# docosanoate_biosynthesis_p2
# docosanoate_biosynthesis_p2
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c2
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c2
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c2
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c2
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c2
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c1
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c1
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c1
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c1
# MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c1
# RXN1G_395_p1
# RXN1G_395_p1
# RXN1G_395_p1
# RXN1G_395_p1
# RXN1G_395_p1
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m1
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m1
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m1
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m1
# 2_PERIOD_7_PERIOD_7_PERIOD_15_RXN_m1
# PRIBFAICARPISOM_RXN_p2
# PRIBFAICARPISOM_RXN_p2
# PRIBFAICARPISOM_RXN_p2
# PRIBFAICARPISOM_RXN_p2
# PRIBFAICARPISOM_RXN_p2
# CIT_v_dielTransfer
# CIT_v_dielTransfer
# CIT_v_dielTransfer
# CIT_v_dielTransfer
# CIT_v_dielTransfer
# GAPOXNPHOSPHN_RXN_p1
# GAPOXNPHOSPHN_RXN_p1
# GAPOXNPHOSPHN_RXN_p1
# GAPOXNPHOSPHN_RXN_p1
# GAPOXNPHOSPHN_RXN_p1
# GAPOXNPHOSPHN_RXN_p2
# GAPOXNPHOSPHN_RXN_p2
# GAPOXNPHOSPHN_RXN_p2
# GAPOXNPHOSPHN_RXN_p2
# GAPOXNPHOSPHN_RXN_p2
# 2KG_OAA_mc2
# 2KG_OAA_mc2
# 2KG_OAA_mc2
# 2KG_OAA_mc2
# 2KG_OAA_mc2
# 6PGLUCONOLACT_RXN_p2
# 6PGLUCONOLACT_RXN_p2
# 6PGLUCONOLACT_RXN_p2
# 6PGLUCONOLACT_RXN_p2
# 6PGLUCONOLACT_RXN_p2
# sCYS_biomass2
# sCYS_biomass2
# sCYS_biomass2
# sCYS_biomass2
# sCYS_biomass2
# SUCCINYL_COA_HYDROLASE_RXN_m2
# SUCCINYL_COA_HYDROLASE_RXN_m2
# SUCCINYL_COA_HYDROLASE_RXN_m2
# SUCCINYL_COA_HYDROLASE_RXN_m2
# SUCCINYL_COA_HYDROLASE_RXN_m2
# SUCCINYL_COA_HYDROLASE_RXN_m1
# SUCCINYL_COA_HYDROLASE_RXN_m1
# SUCCINYL_COA_HYDROLASE_RXN_m1
# SUCCINYL_COA_HYDROLASE_RXN_m1
# SUCCINYL_COA_HYDROLASE_RXN_m1
# RXN0_5330_NADP_c1
# RXN0_5330_NADP_c1
# RXN0_5330_NADP_c1
# RXN0_5330_NADP_c1
# RXN0_5330_NADP_c1
# K_rev_vc1
# K_rev_vc1
# K_rev_vc1
# K_rev_vc1
# K_rev_vc1
# pSER_biomass2
# pSER_biomass2
# pSER_biomass2
# pSER_biomass2
# pSER_biomass2
# pSER_biomass1
# pSER_biomass1
# pSER_biomass1
# pSER_biomass1
# pSER_biomass1
# RXN_9524_p1
# RXN_9524_p1
# RXN_9524_p1
# RXN_9524_p1
# RXN_9524_p1
# RXN_9524_p2
# RXN_9524_p2
# RXN_9524_p2
# RXN_9524_p2
# RXN_9524_p2
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p2
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p2
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p2
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p2
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p2
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p1
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p1
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p1
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p1
# SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p1
# ARG_CITRULLINE_mc2
# ARG_CITRULLINE_mc2
# ARG_CITRULLINE_mc2
# ARG_CITRULLINE_mc2
# ARG_CITRULLINE_mc2
# ARG_CITRULLINE_mc1
# ARG_CITRULLINE_mc1
# ARG_CITRULLINE_mc1
# ARG_CITRULLINE_mc1
# ARG_CITRULLINE_mc1
# RXN_9662_p2
# RXN_9662_p2
# RXN_9662_p2
# RXN_9662_p2
# RXN_9662_p2
# RXN_9662_p1
# RXN_9662_p1
# RXN_9662_p1
# RXN_9662_p1
# RXN_9662_p1
# PHOSGLYPHOS_RXN_c1
# PHOSGLYPHOS_RXN_c1
# PHOSGLYPHOS_RXN_c1
# PHOSGLYPHOS_RXN_c1
# PHOSGLYPHOS_RXN_c1
# PHOSGLYPHOS_RXN_c2
# PHOSGLYPHOS_RXN_c2
# PHOSGLYPHOS_RXN_c2
# PHOSGLYPHOS_RXN_c2
# PHOSGLYPHOS_RXN_c2
# 4_AMINO_BUTYRATE_v_dielTransfer
# 4_AMINO_BUTYRATE_v_dielTransfer
# 4_AMINO_BUTYRATE_v_dielTransfer
# 4_AMINO_BUTYRATE_v_dielTransfer
# 4_AMINO_BUTYRATE_v_dielTransfer
# HIS_PROTON_rev_vc2
# HIS_PROTON_rev_vc2
# HIS_PROTON_rev_vc2
# HIS_PROTON_rev_vc2
# HIS_PROTON_rev_vc2
# RXN0_2382_p2
# RXN0_2382_p2
# RXN0_2382_p2
# RXN0_2382_p2
# RXN0_2382_p2
# ARG_PROTON_vc1
# ARG_PROTON_vc1
# ARG_PROTON_vc1
# ARG_PROTON_vc1
# ARG_PROTON_vc1
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p1
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p1
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p1
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p1
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p1
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p2
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p2
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p2
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p2
# 3_DEHYDROQUINATE_SYNTHASE_RXN_p2
# RXN_9527_p1
# RXN_9527_p1
# RXN_9527_p1
# RXN_9527_p1
# RXN_9527_p1
# RXN_9527_p2
# RXN_9527_p2
# RXN_9527_p2
# RXN_9527_p2
# RXN_9527_p2
# RXN_7979_p1
# RXN_7979_p1
# RXN_7979_p1
# RXN_7979_p1
# RXN_7979_p1
# RXN_7979_p2
# RXN_7979_p2
# RXN_7979_p2
# RXN_7979_p2
# RXN_7979_p2
# Arachidoyl_ACP_desaturase_p2
# Arachidoyl_ACP_desaturase_p2
# Arachidoyl_ACP_desaturase_p2
# Arachidoyl_ACP_desaturase_p2
# Arachidoyl_ACP_desaturase_p2
# AMP_ATP_xc1
# AMP_ATP_xc1
# AMP_ATP_xc1
# AMP_ATP_xc1
# AMP_ATP_xc1
# AMP_ATP_xc2
# AMP_ATP_xc2
# AMP_ATP_xc2
# AMP_ATP_xc2
# AMP_ATP_xc2
# FRU_vc1
# FRU_vc1
# FRU_vc1
# FRU_vc1
# FRU_vc1
# FRU_vc2
# FRU_vc2
# FRU_vc2
# FRU_vc2
# FRU_vc2
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p1
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p1
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p1
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p1
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p1
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p2
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p2
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p2
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p2
# 1_ACYLGLYCEROL_3_P_ACYLTRANSFER_RXN_p2
# pASN_biomass1
# pASN_biomass1
# pASN_biomass1
# pASN_biomass1
# pASN_biomass1
# PYRROLINECARBREDUCT_RXN_NADP_c1
# PYRROLINECARBREDUCT_RXN_NADP_c1
# PYRROLINECARBREDUCT_RXN_NADP_c1
# PYRROLINECARBREDUCT_RXN_NADP_c1
# PYRROLINECARBREDUCT_RXN_NADP_c1
# CHORISMATE_SYNTHASE_RXN_p2
# CHORISMATE_SYNTHASE_RXN_p2
# CHORISMATE_SYNTHASE_RXN_p2
# CHORISMATE_SYNTHASE_RXN_p2
# CHORISMATE_SYNTHASE_RXN_p2
# CHORISMATE_SYNTHASE_RXN_p1
# CHORISMATE_SYNTHASE_RXN_p1
# CHORISMATE_SYNTHASE_RXN_p1
# CHORISMATE_SYNTHASE_RXN_p1
# CHORISMATE_SYNTHASE_RXN_p1
# PYRROLINECARBREDUCT_RXN_NADP_c2
# PYRROLINECARBREDUCT_RXN_NADP_c2
# PYRROLINECARBREDUCT_RXN_NADP_c2
# PYRROLINECARBREDUCT_RXN_NADP_c2
# PYRROLINECARBREDUCT_RXN_NADP_c2
# GDPKIN_RXN_p1
# GDPKIN_RXN_p1
# GDPKIN_RXN_p1
# GDPKIN_RXN_p1
# GDPKIN_RXN_p1
# GDPKIN_RXN_p2
# GDPKIN_RXN_p2
# GDPKIN_RXN_p2
# GDPKIN_RXN_p2
# GDPKIN_RXN_p2
# RXN1G_363_p1
# RXN1G_363_p1
# RXN1G_363_p1
# RXN1G_363_p1
# RXN1G_363_p1
# SER_xc1
# SER_xc1
# SER_xc1
# SER_xc1
# SER_xc1
# SER_xc2
# SER_xc2
# SER_xc2
# SER_xc2
# SER_xc2
# RXN_9661_p2
# RXN_9661_p2
# RXN_9661_p2
# RXN_9661_p2
# RXN_9661_p2
# RXN_9661_p1
# RXN_9661_p1
# RXN_9661_p1
# RXN_9661_p1
# RXN_9661_p1
# LYS_ORNITHINE_mc2
# LYS_ORNITHINE_mc2
# LYS_ORNITHINE_mc2
# LYS_ORNITHINE_mc2
# LYS_ORNITHINE_mc2
# LYS_ORNITHINE_mc1
# LYS_ORNITHINE_mc1
# LYS_ORNITHINE_mc1
# LYS_ORNITHINE_mc1
# LYS_ORNITHINE_mc1
# DGDPKIN_RXN_p1
# DGDPKIN_RXN_p1
# DGDPKIN_RXN_p1
# DGDPKIN_RXN_p1
# DGDPKIN_RXN_p1
# RXN_5781_r1
# RXN_5781_r1
# RXN_5781_r1
# RXN_5781_r1
# RXN_5781_r1
# RXN_5781_r2
# RXN_5781_r2
# RXN_5781_r2
# RXN_5781_r2
# RXN_5781_r2
# SO4_tx1
# SO4_tx1
# SO4_tx1
# SO4_tx1
# SO4_tx1
# SO4_tx2
# SO4_tx2
# SO4_tx2
# SO4_tx2
# SO4_tx2
# PRTRANS_RXN_p2
# PRTRANS_RXN_p2
# PRTRANS_RXN_p2
# PRTRANS_RXN_p2
# PRTRANS_RXN_p2
# PRTRANS_RXN_p1
# PRTRANS_RXN_p1
# PRTRANS_RXN_p1
# PRTRANS_RXN_p1
# PRTRANS_RXN_p1
# DIACYLGLYCEROL_pr2
# DIACYLGLYCEROL_pr2
# DIACYLGLYCEROL_pr2
# DIACYLGLYCEROL_pr2
# DIACYLGLYCEROL_pr2
# DIACYLGLYCEROL_pr1
# DIACYLGLYCEROL_pr1
# DIACYLGLYCEROL_pr1
# DIACYLGLYCEROL_pr1
# DIACYLGLYCEROL_pr1
# ARG_PROTON_rev_vc1
# ARG_PROTON_rev_vc1
# ARG_PROTON_rev_vc1
# ARG_PROTON_rev_vc1
# ARG_PROTON_rev_vc1
# STARCH_p_dielTransfer
# STARCH_p_dielTransfer
# STARCH_p_dielTransfer
# STARCH_p_dielTransfer
# STARCH_p_dielTransfer
# ARG_PROTON_rev_vc2
# ARG_PROTON_rev_vc2
# ARG_PROTON_rev_vc2
# ARG_PROTON_rev_vc2
# ARG_PROTON_rev_vc2
# RXN1F_66_p1
# RXN1F_66_p1
# RXN1F_66_p1
# RXN1F_66_p1
# RXN1F_66_p1
# RXN1F_66_p2
# RXN1F_66_p2
# RXN1F_66_p2
# RXN1F_66_p2
# RXN1F_66_p2
# OAA_MAL_mc1
# OAA_MAL_mc1
# OAA_MAL_mc1
# OAA_MAL_mc1
# OAA_MAL_mc1
# OAA_MAL_mc2
# OAA_MAL_mc2
# OAA_MAL_mc2
# OAA_MAL_mc2
# OAA_MAL_mc2
# NADPHoxp_tx1
# NADPHoxp_tx1
# NADPHoxp_tx1
# NADPHoxp_tx1
# NADPHoxp_tx1
# FORMATE_mc1
# FORMATE_mc1
# FORMATE_mc1
# FORMATE_mc1
# FORMATE_mc1
# FORMATE_mc2
# FORMATE_mc2
# FORMATE_mc2
# FORMATE_mc2
# FORMATE_mc2
# L_CITRULLINE_pc1
# L_CITRULLINE_pc1
# L_CITRULLINE_pc1
# L_CITRULLINE_pc1
# L_CITRULLINE_pc1
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p2
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p2
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p2
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p2
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p2
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p1
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p1
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p1
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p1
# CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p1
# ILE_PROTON_rev_vc2
# ILE_PROTON_rev_vc2
# ILE_PROTON_rev_vc2
# ILE_PROTON_rev_vc2
# ILE_PROTON_rev_vc2
# L_CITRULLINE_pc2
# L_CITRULLINE_pc2
# L_CITRULLINE_pc2
# L_CITRULLINE_pc2
# L_CITRULLINE_pc2
# RXN_7678_NAD_p2
# RXN_7678_NAD_p2
# RXN_7678_NAD_p2
# RXN_7678_NAD_p2
# RXN_7678_NAD_p2
# RXN_7678_NAD_p1
# RXN_7678_NAD_p1
# RXN_7678_NAD_p1
# RXN_7678_NAD_p1
# RXN_7678_NAD_p1
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m2
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m2
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m2
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m2
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m2
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m1
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m1
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m1
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m1
# 3_HYDROXYISOBUTYRATE_DEHYDROGENASE_RXN_m1
# Plastidial_ATP_Synthase_p2
# Plastidial_ATP_Synthase_p2
# Plastidial_ATP_Synthase_p2
# Plastidial_ATP_Synthase_p2
# Plastidial_ATP_Synthase_p2
# Plastidial_ATP_Synthase_p1
# Plastidial_ATP_Synthase_p1
# Plastidial_ATP_Synthase_p1
# Plastidial_ATP_Synthase_p1
# Plastidial_ATP_Synthase_p1
# VAL_mc2
# VAL_mc2
# VAL_mc2
# VAL_mc2
# VAL_mc2
# VAL_mc1
# VAL_mc1
# VAL_mc1
# VAL_mc1
# VAL_mc1
# CO2_xc2
# CO2_xc2
# CO2_xc2
# CO2_xc2
# CO2_xc2
# CO2_xc1
# CO2_xc1
# CO2_xc1
# CO2_xc1
# CO2_xc1
# RXN0_5330_NADP_mi2
# RXN0_5330_NADP_mi2
# RXN0_5330_NADP_mi2
# RXN0_5330_NADP_mi2
# RXN0_5330_NADP_mi2
# ATP_pc2
# ATP_pc2
# ATP_pc2
# ATP_pc2
# ATP_pc2
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1
# SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1
# 2_PERIOD_7_PERIOD_7_PERIOD_14_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_14_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_14_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_14_RXN_m2
# 2_PERIOD_7_PERIOD_7_PERIOD_14_RXN_m2
# DAHPSYN_RXN_p1
# DAHPSYN_RXN_p1
# DAHPSYN_RXN_p1
# DAHPSYN_RXN_p1
# DAHPSYN_RXN_p1
# 4_AMINO_BUTYRATE_mc1
# 4_AMINO_BUTYRATE_mc1
# 4_AMINO_BUTYRATE_mc1
# 4_AMINO_BUTYRATE_mc1
# 4_AMINO_BUTYRATE_mc1
# DAHPSYN_RXN_p2
# DAHPSYN_RXN_p2
# DAHPSYN_RXN_p2
# DAHPSYN_RXN_p2
# DAHPSYN_RXN_p2
# METHYLACETOACETYLCOATHIOL_RXN_m2
# METHYLACETOACETYLCOATHIOL_RXN_m2
# METHYLACETOACETYLCOATHIOL_RXN_m2
# METHYLACETOACETYLCOATHIOL_RXN_m2
# METHYLACETOACETYLCOATHIOL_RXN_m2
# METHYLACETOACETYLCOATHIOL_RXN_m1
# METHYLACETOACETYLCOATHIOL_RXN_m1
# METHYLACETOACETYLCOATHIOL_RXN_m1
# METHYLACETOACETYLCOATHIOL_RXN_m1
# METHYLACETOACETYLCOATHIOL_RXN_m1
# CARBAMATE_KINASE_RXN_p1
# CARBAMATE_KINASE_RXN_p1
# CARBAMATE_KINASE_RXN_p1
# CARBAMATE_KINASE_RXN_p1
# CARBAMATE_KINASE_RXN_p1
# pPRO_biomass2
# pPRO_biomass2
# pPRO_biomass2
# pPRO_biomass2
# pPRO_biomass2
# pPRO_biomass1
# pPRO_biomass1
# pPRO_biomass1
# pPRO_biomass1
# pPRO_biomass1
# CARBAMATE_KINASE_RXN_p2
# CARBAMATE_KINASE_RXN_p2
# CARBAMATE_KINASE_RXN_p2
# CARBAMATE_KINASE_RXN_p2
# CARBAMATE_KINASE_RXN_p2
# HIS_PROTON_rev_vc1
# HIS_PROTON_rev_vc1
# HIS_PROTON_rev_vc1
# HIS_PROTON_rev_vc1
# HIS_PROTON_rev_vc1
# RXN_9104_c1
# RXN_9104_c1
# RXN_9104_c1
# RXN_9104_c1
# RXN_9104_c1
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m1
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m1
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m1
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m1
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m1
# Octadecadienoyl_ACP_desaturase_p1
# Octadecadienoyl_ACP_desaturase_p1
# Octadecadienoyl_ACP_desaturase_p1
# Octadecadienoyl_ACP_desaturase_p1
# Octadecadienoyl_ACP_desaturase_p1
# ATP_ADP_Pi_pc2
# ATP_ADP_Pi_pc2
# ATP_ADP_Pi_pc2
# ATP_ADP_Pi_pc2
# ATP_ADP_Pi_pc2
# ATP_ADP_Pi_pc1
# ATP_ADP_Pi_pc1
# ATP_ADP_Pi_pc1
# ATP_ADP_Pi_pc1
# ATP_ADP_Pi_pc1
# Octadecadienoyl_ACP_desaturase_p2
# Octadecadienoyl_ACP_desaturase_p2
# Octadecadienoyl_ACP_desaturase_p2
# Octadecadienoyl_ACP_desaturase_p2
# Octadecadienoyl_ACP_desaturase_p2
# ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m1
# ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m1
# ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m1
# ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m1
# ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m1
# ILE_PROTON_rev_vc1
# ILE_PROTON_rev_vc1
# ILE_PROTON_rev_vc1
# ILE_PROTON_rev_vc1
# ILE_PROTON_rev_vc1
# RXN1G_363_p2
# RXN1G_363_p2
# RXN1G_363_p2
# RXN1G_363_p2
# RXN1G_363_p2
# 2KETO_3METHYLVALERATE_RXN_m2
# 2KETO_3METHYLVALERATE_RXN_m2
# 2KETO_3METHYLVALERATE_RXN_m2
# 2KETO_3METHYLVALERATE_RXN_m2
# 2KETO_3METHYLVALERATE_RXN_m2
# GLU6PDEHYDROG_RXN_p2
# GLU6PDEHYDROG_RXN_p2
# GLU6PDEHYDROG_RXN_p2
# GLU6PDEHYDROG_RXN_p2
# GLU6PDEHYDROG_RXN_p2
# PSII_RXN_p1
# PSII_RXN_p1
# PSII_RXN_p1
# PSII_RXN_p1
# PSII_RXN_p1
# PSII_RXN_p2
# PSII_RXN_p2
# PSII_RXN_p2
# PSII_RXN_p2
# PSII_RXN_p2
# 2KETO_3METHYLVALERATE_RXN_m1
# 2KETO_3METHYLVALERATE_RXN_m1
# 2KETO_3METHYLVALERATE_RXN_m1
# 2KETO_3METHYLVALERATE_RXN_m1
# 2KETO_3METHYLVALERATE_RXN_m1
# ASPAMINOTRANS_RXN_p1
# ASPAMINOTRANS_RXN_p1
# ASPAMINOTRANS_RXN_p1
# ASPAMINOTRANS_RXN_p1
# ASPAMINOTRANS_RXN_p1
# ASPAMINOTRANS_RXN_p2
# ASPAMINOTRANS_RXN_p2
# ASPAMINOTRANS_RXN_p2
# ASPAMINOTRANS_RXN_p2
# ASPAMINOTRANS_RXN_p2
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m2
# 1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m2
# CIT_PROTON_rev_vc1
# CIT_PROTON_rev_vc1
# CIT_PROTON_rev_vc1
# CIT_PROTON_rev_vc1
# CIT_PROTON_rev_vc1
# CIT_PROTON_rev_vc2
# CIT_PROTON_rev_vc2
# CIT_PROTON_rev_vc2
# CIT_PROTON_rev_vc2
# CIT_PROTON_rev_vc2

# %%
fout = open("Data/PPC_transcripts_fluxes_lightNotForced_constMaint_notAverage_11_10_19.csv","w")

for rxn in PCCdict.keys():
    fout.write(rxn+","+str(PCCdict[rxn][0])+","+str(PCCdict[rxn][1])+"\n")
fout.close()

# %%
rxn = "SUCROSE_SYNTHASE_RXN_c1"
xlist = list()
ylist = list()
for i in range(1,6):
    xlist.append(modelDict[i].reactions.get_by_id(rxn).flux)
    ylist.append(totalTranscriptDict[i][rxn])

# %%
xlist
# Out:
# [0.014835058910007371,
#  0.0168690400497365,
#  0.014835058909959667,
#  0.007785508992527683,
#  0.0024995325175661436]

# %%
ylist
# Out:
# [16.244093349375,
#  15.220867541718752,
#  16.92877199385714,
#  21.772953956249996,
#  26.22324397875]

# %% [markdown]
# ## References
# - Kannan, K., Wang, Y., Lang, M., Challa, G. S., Long, S. P., & Marshall-Colon, A. (2019). Combining gene network, metabolic and leaf-level models shows means to future-proof soybean photosynthesis under rising CO2. In Silico Plants, 1(1), 1–18. https://doi.org/10.1093/insilicoplants/diz008
# - Haile, F. J., & Higley, L. G. (2003). Changes in Soybean Gas-Exchange After Moisture Stress and Spider Mite Injury. Environmental Entomology, 32(3), 433–440. https://doi.org/10.1603/0046-225x-32.3.433
