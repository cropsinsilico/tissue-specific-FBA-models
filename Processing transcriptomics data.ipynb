# %%
import pandas as pd
df = pd.read_csv("/home/sanu/Documents/Scripts/git/Data/Soy/gmax_leaf_CO2_normExprn_1.txt",sep="\t")
# Out:
# /home/sanu/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (0,2,3,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2 = pd.read_excel("/home/sanu/Documents/Scripts/git/Data/Soy/Transcriptomics_key.xlsx")

# %%
import re
ColIDdict = dict()
for x in df.columns[33:]:
    y = re.search("^GSM[0-9]*",x)
    z = y.group()
    print z
    ColIDdict[z]=x

ColIDlist = list()
for x in df2["Sample ID"]:
    if x in ColIDdict.keys():
        ColIDlist.append(ColIDdict[x])
    else:
        ColIDlist.append("-")
ColIDlist
# Out:
# GSM1088939
# GSM1088940
# GSM1088948
# GSM1088949
# GSM1088950
# GSM1088954
# GSM1088955
# GSM1088956
# GSM1088963
# GSM1088964
# GSM209574
# GSM209575
# GSM209576
# GSM209577
# GSM209580
# GSM209581
# GSM209582
# GSM209583
# GSM209584
# GSM209585
# GSM209586
# GSM209587
# GSM209588
# GSM209590
# GSM209591
# GSM209592
# GSM209593
# GSM209594
# GSM209595
# GSM209596
# GSM209597
# GSM209598
# GSM209599
# GSM569808
# GSM569809
# GSM569810
# GSM569811
# GSM569812
# GSM569813
# GSM569814
# GSM569815
# GSM569816
# GSM569817
# GSM569818
# GSM569819
# GSM569820
# GSM569821
# GSM569822
# GSM569824
# GSM569825
# GSM569826
# GSM569827
# GSM569828
# GSM569829
# GSM643111
# GSM643112
# GSM643113
# GSM643114
# GSM643115
# GSM643116
# GSM643117
# GSM643118
# GSM643119
# GSM643120
# GSM643121
# GSM643123
# GSM643124
# GSM643125
# GSM643126
# GSM737244
# GSM737245
# GSM737246
# GSM737247
# GSM737248
# GSM737249
# GSM737250
# GSM737251
# GSM737252
# GSM737253
# GSM737254
# GSM737255
# GSM737256
# ...

# %%
df2["Transcriptomics dataset ID"] = ColIDlist

# %%
df2.to_excel("/home/sanu/Documents/Scripts/git/Data/Soy/Transcriptomics_key_with_columnnames.xlsx")
